# %%
import pandas as pd
from collections import defaultdict
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# ## This is for certification data analysis of the following states: New Mexico, North Carolina, Minnesota, Indiana, Kansas, Mississippi and Illinois

# %% [markdown]
# ### The questions to answer:
# #### 1. How far back does the data go?
# #### 2. How many currently-active officers have had 3+ employers? 5+? More?
# #### 3. How many currently-active officers were previously listed as having been fired or terminated?
# #### 4. For officers who were previously terminated, and/or officers who have 3/5+ former employers, are there agencies where they seem to end up more often than not?

# %% [markdown]
# ***

# %% [markdown]
# #### **Some functions that are used repeatedly**

# %%
# getting number of departments each officer has been a part of and creating a new column that lists that count
# INPUTS
# df: the state's cert data dataframe
# id_column: the name of the column in this dataframe that refers to an officer's unique id
# agency_column: the name of the column that refers to the department name
def get_dept_counts(df, id_column, agency_column):
    officer_dept_counts = df.value_counts(id_column)
    dept_counts_dict = pd.DataFrame({id_column:officer_dept_counts.index, 'number_of_depts':officer_dept_counts.values}).set_index(id_column)['number_of_depts'].to_dict()
    df['number_of_depts'] = df[id_column].map(dept_counts_dict)

    # getting number of UNIQUE depts in case officer was moved within a dept
    df['number_of_unique_depts'] = df.groupby([id_column])[agency_column].transform("nunique")

# %%
# getting active officers here
# function that will:
# 1: filter dataframe to have all officers where employment_status is "Active"
# 2: get list of unique ids from this filtered dataframe (this gives us the unique ids of all currently active officers
# 3: create final dataframe that has full employment history of those active officers
# INPUTS
# df: the state's cert data dataframe
# id_column: the name of the column in this dataframe that refers to an officer's unique id
# status_column: the name of the column that refers to officer's status
# active_word: word used in the data to indicate officer is active
# returns: dataframe of the currently active officers' employment history sorted by chronologically by their start dates
def get_active_officers(df, id_column, status_column, active_word):
    active_full_hist = pd.DataFrame()
    active_only = df.loc[df[status_column] == active_word].copy()
    active_ids = active_only[id_column].unique()
    for active in active_ids:
        temp_df = df.loc[df[id_column] == active].copy().sort_values(by='start_date')
        active_full_hist = pd.concat([active_full_hist, temp_df])
    # active_full_hist = df.loc[df[id_column].isin(active_ids)].copy().sort_values([id_column, "start_date"])
    return active_full_hist

# %%
# this function returns the same as above function except
# it's in cases where there is no "status" column so we use
# the end date to determine what officers are active. if an officer
# does not have an end date, we assume that they are still active
def get_active_officers_no_status(df, id_column):
    # clean up the end_date column before using it
    df['end_date'] = df['end_date'].fillna('')
    df['start_date'] = df['start_date'].fillna('')

    # now will do similar stuff as with new mexico but using None value rather than Active in status one
    active_full_hist = pd.DataFrame()
    # making dataframe that only has officers who have 'None' in at least one of their end dates
    active_only = df.loc[(df['end_date'] == '') & (df['start_date'] != '')].copy()
    active_ids = active_only[id_column].unique()
    # looping thru list of active ids and getting full employment history of those officers
    for active in active_ids:
        temp_df = df.loc[df[id_column] == active].copy().sort_values(by='start_date')
        active_full_hist = pd.concat([active_full_hist, temp_df])
    return active_full_hist

# %%
# this function does the following:
# 1: filters data set to get officers from currently active df that have been terminated
# 2: gets unique ids from that filtered dataframe
# INPUTS
# df: the state's cert data dataframe
# id_column: the name of the column in this dataframe that refers to an officer's unique id
# status_column: the name of the column that refers to officer's status
# term_word: word used in the data to indicate officer was terminated
# returns: dataframe that has full employment history of officers who are currently active
# but have been terminated from a department at some point
def get_terminated_active(active_df, id_column, status_column, term_word):
    terminated_active = active_df.loc[active_df[status_column] == term_word].copy()
    terminated_ids = terminated_active[id_column].unique()
    terminated_active_hist = active_df.loc[active_df[id_column].isin(terminated_ids)].copy()
    return terminated_active_hist

# %% [markdown]
# ### the two functions below, i use specifically for New Mexico

# %%
# looking into what departments come up a lot for terminated active officers
# this function returns dataframe where an officer:
# - was active sometime in the past 5 years
# - had a termination at some point in their career (if there is 1 termination in their history, making sure it's not the last thing)
# the dataframe is sorted by the end date within each officer's employment history
def terminated_active_5yrs(input_df):
    term_active_5yrs = pd.DataFrame()
    final_df = pd.DataFrame()
    input_df['end_date'] = input_df['end_date'].fillna('')
    input_df['end_date'] = pd.to_datetime(input_df['end_date'])
    # dataframe of officers who are either listed as Active or have end date that is 2019 or later
    # we need to filter this down to officers who have ever been Terminated
    active_5_years_back = input_df.loc[(input_df['employment_status'] == 'Active') | (input_df['end_date'].dt.year >= 2019)].copy()
    # unique ids of officers from above dataframe
    ids_active_5_yrs = active_5_years_back['person_nbr'].unique()
    # now we'll look at original new mexico dataframe but only for the ids in the above list and get the ones that have Terminated
    for officer in ids_active_5_yrs:
        temp_df = input_df.loc[(input_df['person_nbr'] == officer) & (input_df['employment_status'] == 'Termination')].copy()
        term_active_5yrs = pd.concat([term_active_5yrs, temp_df])

    # get unique ids of officers who fit the criteria (termination in their employment too)
    ids_active_term = term_active_5yrs['person_nbr'].unique()
    # now we'll look at original new mexico dataframe to get full employment history of officers who have been active at some point
    # in the past 5 years and also have a termination in their career
    for officer in ids_active_term:
        temp_df = (input_df.loc[input_df['person_nbr'] == officer]).sort_values(by='end_date')
        terminations = (temp_df['employment_status'] == 'Termination').sum()
        if (terminations == 1):
            last_row = temp_df.iloc[[-1]]
            if (last_row.iloc[[0]]['employment_status'] != 'Termination').any():
                final_df = pd.concat([final_df, temp_df])
        else:
            final_df = pd.concat([final_df, temp_df])

    return final_df

# %%
# looking into what departments come up a lot for terminated active officers
# this function returns dataframe where an officer:
# - was active sometime in the past 5 years
# - had a termination at some point in their career (if there is 1 termination in their history, making sure it's not the last thing)
# the dataframe is sorted by the end date within each officer's employment history
def terminated_active_5yrs_ill(input_df):
    term_active_5yrs = pd.DataFrame()
    final_df = pd.DataFrame()
    input_df['end_date'] = input_df['end_date'].fillna('')
    input_df['end_date'] = pd.to_datetime(input_df['end_date'], format='mixed', errors='coerce')
    # dataframe of officers who either do not have end date (so active) or have end date that is 2019 or later
    # we need to filter this down to officers who have ever been Terminated
    active_5_years_back = input_df.loc[(input_df['end_date'] == '') | (input_df['end_date'].dt.year >= 2019)].copy()
    # unique ids of officers from above dataframe
    ids_active_5_yrs = active_5_years_back['person_nbr'].unique()
    # now we'll look at original illinois dataframe but only for the ids in the above list and get the ones that have Terminated For Cause
    for officer in ids_active_5_yrs:
        temp_df = input_df.loc[(input_df['person_nbr'] == officer) & (input_df['separation_reason'] == 'Terminated For Cause')].copy()
        term_active_5yrs = pd.concat([term_active_5yrs, temp_df])

    # get unique ids of officers who fit the criteria (termination in their employment too)
    ids_active_term = term_active_5yrs['person_nbr'].unique()
    # now we'll look at original illinois dataframe to get full employment history of officers who have been active at some point
    # in the past 5 years and also have a termination in their career
    for officer in ids_active_term:
        temp_df = (input_df.loc[input_df['person_nbr'] == officer]).sort_values(by='end_date')
        terminations = (temp_df['separation_reason'] == 'Terminated For Cause').sum()
        if (terminations == 1):
            last_row = temp_df.iloc[[-1]]
            if (last_row.iloc[[0]]['separation_reason'] != 'Terminated For Cause').any():
                final_df = pd.concat([final_df, temp_df])
        else:
            final_df = pd.concat([final_df, temp_df])

    return final_df

# %%
# this function returns a tuple with two dictionaries
# dictionary 1 has the following:
# key: name of police department
# value: how many times this was the department an officer went to as their next law enforcement job
# after being terminated from a department
# dictionary 2 has the following:
# key: name of police department
# value: list of officers that went there after being terminated from somewhere else
def departments_after_termination(final_df):
    officer_ids = final_df['person_nbr'].unique()
    dept_after_term = defaultdict(int)
    officers_after_term = defaultdict(list)
    final_df['start_date'] = final_df['start_date'].fillna('')
    final_df['start_date'] = pd.to_datetime(final_df['start_date'])

    for officer in officer_ids:
        officer_history = final_df.loc[final_df['person_nbr'] == officer].copy()
        officer_history = officer_history.reset_index(drop=True)
        officer_history = officer_history.sort_values(by='end_date')
        print (officer_history)
        term_spots = officer_history.index[officer_history['employment_status'] == 'Termination']
        print ('TERMINATION INDEX: ', term_spots)

        for term_spot in term_spots:
            # this is seeing if the termination spot is the last one in the officer's history
            # if it is, we are skipping this index because there is no department after in
            # the officer's employment history
            print ('CURRENT TERM SPOT: ', term_spot)
            if (term_spot == officer_history.tail(1).index[0]):
                print ('TERMINATION IS LAST THING IN OFFICERS HISTORY')
            else:
                # making sure officer started at next spot after termination at previous one
                if (officer_history['end_date'].iloc[term_spot] < officer_history['start_date'].iloc[term_spot+1]):
                    department_after_termination = officer_history['agency_name'].iloc[term_spot+1]
                    print ('AGENCY AFTER TERM: ', officer_history['agency_name'].iloc[term_spot+1])
                    dept_after_term[department_after_termination] += 1  
                    officers_after_term[department_after_termination].append(officer)  
                else:
                    print ('OFFICER START DATE AT NEXT PLACE IS BEFORE END DATE AT TERMINATED PLACE') 

    dept_after_term = {k: v for k, v in sorted(dept_after_term.items(), key=lambda item: item[1], reverse=True)}

    return (dept_after_term, officers_after_term)

# %%
# this function returns a tuple with two dictionaries
# dictionary 1 has the following:
# key: name of police department
# value: how many times this was the department an officer went to as their next law enforcement job
# after being terminated from a department
# dictionary 2 has the following:
# key: name of police department
# value: list of officers that went there after being terminated from somewhere else
def departments_after_termination_ill(final_df):
    officer_ids = final_df['person_nbr'].unique()
    dept_after_term = defaultdict(int)
    officers_after_term = defaultdict(list)
    final_df['start_date'] = final_df['start_date'].fillna('')
    final_df['start_date'] = pd.to_datetime(final_df['start_date'])

    for officer in officer_ids:
        officer_history = final_df.loc[final_df['person_nbr'] == officer].copy()
        officer_history = officer_history.reset_index(drop=True)
        officer_history = officer_history.sort_values(by='end_date')
        print (officer_history)
        term_spots = officer_history.index[officer_history['separation_reason'] == 'Terminated For Cause']
        print ('TERMINATION INDEX: ', term_spots)

        for term_spot in term_spots:
            # this is seeing if the termination spot is the last one in the officer's history
            # if it is, we are skipping this index because there is no department after in
            # the officer's employment history
            print ('CURRENT TERM SPOT: ', term_spot)
            if (term_spot == officer_history.tail(1).index[0]):
                print ('TERMINATION IS LAST THING IN OFFICERS HISTORY')
            else:
                # making sure officer started at next spot after termination at previous one
                if (officer_history['end_date'].iloc[term_spot] < officer_history['start_date'].iloc[term_spot+1]):
                    department_after_termination = officer_history['agency_name'].iloc[term_spot+1]
                    print ('AGENCY AFTER TERM: ', officer_history['agency_name'].iloc[term_spot+1])
                    dept_after_term[department_after_termination] += 1  
                    officers_after_term[department_after_termination].append(officer)  
                else:
                    print ('OFFICER START DATE AT NEXT PLACE IS BEFORE END DATE AT TERMINATED PLACE') 

    dept_after_term = {k: v for k, v in sorted(dept_after_term.items(), key=lambda item: item[1], reverse=True)}

    return (dept_after_term, officers_after_term)

# %% [markdown]
# ***

# %% [markdown]
# ### __New Mexico Analysis__

# %%
new_mexico = pd.read_csv('../npi_lookup/national-post-db/nm/input/new-mexico-preprocessed.csv')

# %%
new_mexico.sort_values(by='start_date').head(10)
# Out:
#       person_nbr first_name middle_name   last_name suffix   sex  \
# 4516   19-0138-P      Steve           C       Boren    NaN  Male
# 8407   96-0113-P     Joshua         NaN  Valenzuela    NaN  Male
# 15735  78-0200-P      Glenn           G      Kelsey    Sr.  Male
# 7305   78-0048-P    Richard           G      Melton    NaN  Male
# 10864  81-0077-P    Anselmo           M       Giron    NaN  Male
# 185    03-0277-P        Ian           P      Conway    NaN  Male
# 2905   95-0043-P      Jerry           T      Powell    NaN  Male
# 1614   03-0269-P       John           R        Dear    NaN  Male
# 2501   92-0270-P        Joe           F      Garcia    NaN  Male
# 13320  64-1007-P       Jose         NaN  Mascarenas    NaN  Male
#
#       year_of_birth             race   start_date     end_date  \
# 4516           1980            white   01/23/1208  2022-10-21
# 8407           1973  Native American  1911-01-01   1911-01-01
# 15735          1951  Native American  1951-03-01           NaN
# 7305           1957            white  1957-04-14   2004-08-07
# 10864          1921         Hispanic  1957-08-09   1999-06-15
# 185            1974            white  1958-09-30   2005-09-30
# 2905           1936            white  1962-10-18   1988-06-17
# 1614           1944            white  1963-06-01   2019-06-21
# 2501           1939         Hispanic  1964-09-01   1986-12-31
# 13320          1939         Hispanic  1964-10-07   1997-06-30
#
#       employment_type            rank employment_status  \
# 4516        Full Time           Cadet          Resigned
# 8407              NaN  Patrol Officer       Termination
# 15735       Full Time           Chief            Active
# 7305              NaN           Chief          Resigned
# 10864             NaN           Chief           Retired
# 185               NaN  Patrol Officer          Resigned
# 2905              NaN    Deputy Chief           Retired
# 1614              NaN         Unknown          Resigned
# 2501              NaN       Detective           Retired
# 13320             NaN        Sergeant           Retired
#
#                                      agency_name             agency_type
# 4516                Bernalillo Police Department  Law Enforcement Agency
# 8407   Jicarilla Apache Tribal Police Department  Law Enforcement Agency
# 15735         Pueblo Of Laguna Police Department  Law Enforcement Agency
# 7305         Los Alamos County Police Department  Law Enforcement Agency
# 10864               New Mexico State Fair Police                     NaN
# 185                 Alamogordo Police Department  Law Enforcement Agency
# 2905               Albuquerque Police Department  Law Enforcement Agency
# 1614               Albuquerque Police Department  Law Enforcement Agency
# 2501               Albuquerque Police Department  Law Enforcement Agency
# 13320                    New Mexico State Police  Law Enforcement Agency

# %%
new_mexico_sorted = new_mexico.sort_values(by=['person_nbr', 'end_date'])

# %% [markdown]
# Data goes back to around the 1960s, but important to note the data is messy so it's actually not clear

# %% [markdown]
# #### getting active officers

# %%
# using previously written function to get # of departments officer has been a part of
get_dept_counts(df=new_mexico, id_column='person_nbr', agency_column='agency_name')

# %% [markdown]
# ## THIS IS ME TESTING THE FUNCTION TO SEE IF OFFICERS GO TO CERTAIN DEPARTMENTS FREQUENTLY AFTER BEING FIRED

# %%
nm_test = terminated_active_5yrs(new_mexico_sorted)

# %%
nm_test.head()
# Out:
#       person_nbr first_name middle_name last_name suffix   sex year_of_birth  \
# 14854  00-0022-P     Marvin           L     Paulk    NaN  Male          1967
# 14853  00-0022-P     Marvin           L     Paulk    NaN  Male          1967
# 14852  00-0022-P     Marvin           L     Paulk    NaN  Male          1967
# 17701  00-0034-P      Harry           C      Betz    NaN  Male          1948
# 17702  00-0034-P      Harry           C      Betz    NaN  Male          1948
#
#                    race   start_date   end_date employment_type  \
# 14854  African American  1998-08-03  1998-08-14             NaN
# 14853  African American  1999-10-04  2000-06-23             NaN
# 14852  African American  2000-06-24  2019-01-31             NaN
# 17701             white  1999-06-28  2001-06-05             NaN
# 17702             white  2001-07-23  2006-12-08             NaN
#
#                  rank employment_status                           agency_name  \
# 14854  Deputy Sheriff       Termination      Santa Fe County Sheriff'S Office
# 14853  Patrol Officer          Resigned            Espanola Police Department
# 14852         Captain           Retired            Santa Fe Police Department
# 17701           Agent          Resigned               New Mexico State Police
# 17702   Special Agent          Resigned  New Mexico Attorney General'S Office
#
#                   agency_type  number_of_depts  number_of_unique_depts
# 14854  Law Enforcement Agency                3                       3
# 14853  Law Enforcement Agency                3                       3
# 14852  Law Enforcement Agency                3                       3
# 17701  Law Enforcement Agency                7                       7
# 17702  Law Enforcement Agency                7                       7

# %%
nm_depts_after_term = departments_after_termination(nm_test)
# Out:
#   person_nbr first_name middle_name last_name suffix   sex year_of_birth  \
# 0  00-0022-P     Marvin           L     Paulk    NaN  Male          1967
# 1  00-0022-P     Marvin           L     Paulk    NaN  Male          1967
# 2  00-0022-P     Marvin           L     Paulk    NaN  Male          1967
#
#                race start_date   end_date employment_type            rank  \
# 0  African American 1998-08-03 1998-08-14             NaN  Deputy Sheriff
# 1  African American 1999-10-04 2000-06-23             NaN  Patrol Officer
# 2  African American 2000-06-24 2019-01-31             NaN         Captain
#
#   employment_status                       agency_name             agency_type  \
# 0       Termination  Santa Fe County Sheriff'S Office  Law Enforcement Agency
# 1          Resigned        Espanola Police Department  Law Enforcement Agency
# 2           Retired        Santa Fe Police Department  Law Enforcement Agency
#
#    number_of_depts  number_of_unique_depts
# 0                3                       3
# 1                3                       3
# 2                3                       3
# TERMINATION INDEX:  Index([0], dtype='int64')
# CURRENT TERM SPOT:  0
# AGENCY AFTER TERM:  Espanola Police Department
#   person_nbr first_name middle_name last_name suffix   sex year_of_birth  \
# 0  00-0034-P      Harry           C      Betz    NaN  Male          1948
# 1  00-0034-P      Harry           C      Betz    NaN  Male          1948
# 2  00-0034-P      Harry           C      Betz    NaN  Male          1948
# 3  00-0034-P      Harry           C      Betz    NaN  Male          1948
# 4  00-0034-P      Harry           C      Betz    NaN  Male          1948
# 5  00-0034-P      Harry           C      Betz    NaN  Male          1948
# 6  00-0034-P      Harry           C      Betz    NaN  Male          1948
#
#     race start_date   end_date employment_type           rank  \
# 0  white 1999-06-28 2001-06-05             NaN          Agent
# 1  white 2001-07-23 2006-12-08             NaN  Special Agent
# 2  white 2008-08-05 2015-03-25             NaN          Chief
# 3  white 2020-11-03 2021-04-05       Full Time          Chief
# 4  white 2019-03-10 2022-05-05       Full Time          Chief
# 5  white 2015-04-23 2022-11-02       Full Time     Lieutenant
# 6  white 2022-11-07        NaT       Full Time       Sergeant
#
#   employment_status                           agency_name  \
# 0          Resigned               New Mexico State Police
# 1          Resigned  New Mexico Attorney General'S Office
# 2          Resigned    Santa Ana Tribal Police Department
# 3       Termination        Jemez Pueblo Police Department
# 4          Resigned                Cuba Police Department
# 5          Resigned       Jemez Springs Police Department
# 6            Active            Corrales Police Department
#
#               agency_type  number_of_depts  number_of_unique_depts
# 0  Law Enforcement Agency                7                       7
# 1  Law Enforcement Agency                7                       7
# 2  Law Enforcement Agency                7                       7
# 3  Law Enforcement Agency                7                       7
# 4  Law Enforcement Agency                7                       7
# 5  Law Enforcement Agency                7                       7
# 6  Law Enforcement Agency                7                       7
# TERMINATION INDEX:  Index([3], dtype='int64')
# CURRENT TERM SPOT:  3
# OFFICER START DATE AT NEXT PLACE IS BEFORE END DATE AT TERMINATED PLACE
#   person_nbr first_name middle_name last_name suffix   sex year_of_birth  \
# 0  00-0046-P    Gilbert           E  Gonzales    Jr.  Male          1976
# 1  00-0046-P    Gilbert           E  Gonzales    Jr.  Male          1976
# 2  00-0046-P    Gilbert           E  Gonzales    Jr.  Male          1976
# 3  00-0046-P    Gilbert           E  Gonzales    Jr.  Male          1976
# 4  00-0046-P    Gilbert           E  Gonzales    Jr.  Male          1976
#
#        race start_date   end_date employment_type                  rank  \
# 0  Hispanic 1997-10-20 1999-06-20             NaN        Patrol Officer
# 1  Hispanic 1999-06-21 2011-10-26             NaN  [Missing Title/Rank]
# 2  Hispanic 2013-02-04 2013-06-28             NaN        Deputy Sheriff
# 3  Hispanic 2018-10-22 2021-04-16       Full Time            Lieutenant
# 4  Hispanic 2021-06-01        NaT       Full Time        Patrol Officer
#
#   employment_status                     agency_name             agency_type  \
# 0          Resigned         Acoma Police Department  Law Enforcement Agency
# 1          Resigned        Grants Police Department  Law Enforcement Agency
# 2       Termination  Cibola County Sheriff'S Office  Law Enforcement Agency
# 3       Termination         Milan Police Department  Law Enforcement Agency
# 4            Active        Gallup Police Department  Law Enforcement Agency
#
#    number_of_depts  number_of_unique_depts
# 0                5                       5
# 1                5                       5
# 2                5                       5
# 3                5                       5
# 4                5                       5
# TERMINATION INDEX:  Index([2, 3], dtype='int64')
# CURRENT TERM SPOT:  2
# AGENCY AFTER TERM:  Milan Police Department
# CURRENT TERM SPOT:  3
# AGENCY AFTER TERM:  Gallup Police Department
#   person_nbr first_name middle_name last_name suffix   sex year_of_birth  \
# 0  00-0057-P      David           A      Kube    NaN  Male          1960
# 1  00-0057-P      David           A      Kube    NaN  Male          1960
# 2  00-0057-P      David           A      Kube    NaN  Male          1960
#
#     race start_date   end_date employment_type            rank  \
# 0  white 1999-04-26 2002-05-08             NaN  Patrol Officer
# 1  white 2002-05-13 2016-06-04             NaN        Sergeant
# 2  white 2019-01-15        NaT       Full Time  Patrol Officer
#
#   employment_status                    agency_name             agency_type  \
# 0       Termination       Texico Police Department  Law Enforcement Agency
# 1          Resigned  Curry County Sheriff'S Office  Law Enforcement Agency
# 2            Active  Continuation Of Certification    Certification Status
#
#    number_of_depts  number_of_unique_depts
# 0                3                       3
# 1                3                       3
# 2                3                       3
# TERMINATION INDEX:  Index([0], dtype='int64')
# CURRENT TERM SPOT:  0
# AGENCY AFTER TERM:  Curry County Sheriff'S Office
#   person_nbr first_name middle_name last_name suffix   sex year_of_birth  \
# 0  00-0079-P      Mikel           B   Aguilar    NaN  Male          1977
# 1  00-0079-P      Mikel           B   Aguilar    NaN  Male          1977
# 2  00-0079-P      Mikel           B   Aguilar    NaN  Male          1977
# 3  00-0079-P      Mikel           B   Aguilar    NaN  Male          1977
#
#        race start_date   end_date employment_type            rank  \
# 0  Hispanic 1999-06-21 1999-08-19             NaN  Patrol Officer
# 1  Hispanic 2000-04-10 2011-01-03             NaN  Patrol Officer
# 2  Hispanic 2011-08-17 2013-01-22             NaN  Patrol Officer
# 3  Hispanic 2017-01-02        NaT       Full Time  Patrol Officer
#
#   employment_status                 agency_name             agency_type  \
# 0       Termination    Gallup Police Department  Law Enforcement Agency
# 1       Termination   Roswell Police Department  Law Enforcement Agency
# 2          Resigned  Portales Police Department  Law Enforcement Agency
# 3            Active     Elida Police Department  Law Enforcement Agency
#
#    number_of_depts  number_of_unique_depts
# 0                4                       4
# 1                4                       4
# 2                4                       4
# 3                4                       4
# TERMINATION INDEX:  Index([0, 1], dtype='int64')
# CURRENT TERM SPOT:  0
# AGENCY AFTER TERM:  Roswell Police Department
# CURRENT TERM SPOT:  1
# AGENCY AFTER TERM:  Portales Police Department
#   person_nbr first_name middle_name last_name suffix   sex year_of_birth  \
# 0  00-0080-P      Clint           B    Holmes    NaN  Male          1977
# 1  00-0080-P      Clint           B    Holmes    NaN  Male          1977
# 2  00-0080-P      Clint           B    Holmes    NaN  Male          1977
# 3  00-0080-P      Clint           B    Holmes    NaN  Male          1977
# 4  00-0080-P      Clint           B    Holmes    NaN  Male          1977
# 5  00-0080-P      Clint           B    Holmes    NaN  Male          1977
#
#     race start_date   end_date employment_type            rank  \
# 0  white 2001-07-16 2001-12-13             NaN  Patrol Officer
# 1  white 2002-01-28 2003-02-08             NaN  Deputy Sheriff
# 2  white 2003-02-14 2008-08-06             NaN  Patrol Officer
# 3  white 2009-06-19 2010-08-15             NaN  Patrol Officer
# 4  white 1999-05-25 2017-01-05             NaN        Sergeant
# 5  white 2016-11-09        NaT       Full Time        Sergeant
#
#   employment_status                        agency_name  \
# 0       Termination         Portales Police Department
# 1          Resigned      Fort Sumner Police Department
# 2          Resigned          Roswell Police Department
# 3          Resigned            Elida Police Department
# 4          Resigned        Tucumcari Police Department
# 5            Active  Roosevelt County Sheriff'S Office
#
#               agency_type  number_of_depts  number_of_unique_depts
# 0  Law Enforcement Agency                6                       6
# 1  Law Enforcement Agency                6                       6
# 2  Law Enforcement Agency                6                       6
# 3  Law Enforcement Agency                6                       6
# 4  Law Enforcement Agency                6                       6
# 5  Law Enforcement Agency                6                       6
# TERMINATION INDEX:  Index([0], dtype='int64')
# CURRENT TERM SPOT:  0
# AGENCY AFTER TERM:  Fort Sumner Police Department
#   person_nbr first_name middle_name last_name suffix   sex year_of_birth  \
# 0  00-0107-P      Lance           C    Lister    NaN  Male          1973
# 1  00-0107-P      Lance           C    Lister    NaN  Male          1973
# 2  00-0107-P      Lance           C    Lister    NaN  Male          1973
# 3  00-0107-P      Lance           C    Lister    NaN  Male          1973
# 4  00-0107-P      Lance           C    Lister    NaN  Male          1973
# 5  00-0107-P      Lance           C    Lister    NaN  Male          1973
# 6  00-0107-P      Lance           C    Lister    NaN  Male          1973
#
#     race start_date   end_date employment_type            rank  \
# 0  white 1994-10-31 1996-03-18       Full Time  Patrol Officer
# 1  white 1999-10-04 2006-01-24             NaN  Patrol Officer
# 2  white 1994-05-16 2008-04-21             NaN  Patrol Officer
# 3  white 1997-03-10 2014-09-11             NaN  Patrol Officer
# 4  white 1993-05-10 2017-08-14       Full Time        Sergeant
# 5  white 2017-09-11 2018-05-17             NaN  Deputy Sheriff
# 6  white 2018-01-18 2021-10-07       Full Time  Patrol Officer
#
#   employment_status                         agency_name  \
# 0       Termination             Milan Police Department
# 1          Resigned            Grants Police Department
# 2          Resigned             Acoma Police Department
# 3          Resigned  Pueblo Of Laguna Police Department
# 4          Resigned      Cibola County Sheriff'S Office
# 5          Resigned    Sandoval County Sheriff'S Office
# 6          Resigned  Santa Ana Tribal Police Department
#
#               agency_type  number_of_depts  number_of_unique_depts
# 0  Law Enforcement Agency                7                       7
# 1  Law Enforcement Agency                7                       7
# 2  Law Enforcement Agency                7                       7
# 3  Law Enforcement Agency                7                       7
# 4  Law Enforcement Agency                7                       7
# 5  Law Enforcement Agency                7                       7
# 6  Law Enforcement Agency                7                       7
# TERMINATION INDEX:  Index([0], dtype='int64')
# CURRENT TERM SPOT:  0
# AGENCY AFTER TERM:  Grants Police Department
#   person_nbr   first_name middle_name last_name suffix   sex year_of_birth  \
# 0  00-0127-P  Christopher           L  Luttrell    NaN  Male          1964
# 1  00-0127-P  Christopher           L  Luttrell    NaN  Male          1964
# 2  00-0127-P  Christopher           L  Luttrell    NaN  Male          1964
#
#     race start_date   end_date employment_type            rank  \
# 0  white 2000-06-23 2007-05-11             NaN  Patrol Officer
# 1  white 2007-07-07 2018-04-27             NaN  Patrol Officer
# 2  white 2022-11-28        NaT       Full Time  Deputy Sheriff
#
#   employment_status                       agency_name             agency_type  \
# 0       Termination           New Mexico State Police  Law Enforcement Agency
# 1           Retired     Albuquerque Police Department  Law Enforcement Agency
# 2            Active  Sandoval County Sheriff'S Office  Law Enforcement Agency
#
#    number_of_depts  number_of_unique_depts
# 0                3                       3
# 1                3                       3
# 2                3                       3
# TERMINATION INDEX:  Index([0], dtype='int64')
# CURRENT TERM SPOT:  0
# AGENCY AFTER TERM:  Albuquerque Police Department
#   person_nbr first_name middle_name last_name suffix   sex year_of_birth  \
# 0  00-0198-P     Daniel           D   Ramondo    NaN  Male          1966
# 1  00-0198-P     Daniel           D   Ramondo    NaN  Male          1966
# 2  00-0198-P     Daniel           D   Ramondo    NaN  Male          1966
#
#        race start_date   end_date employment_type            rank  \
# 0  Hispanic 2000-08-04 2000-10-30             NaN  Patrol Officer
# 1  Hispanic 2001-04-09 2003-01-08             NaN  Patrol Officer
# 2  Hispanic 2003-01-13 2020-12-31             NaN       Detective
#
#   employment_status                       agency_name             agency_type  \
# 0       Termination      Las Cruces Police Department  Law Enforcement Agency
# 1          Resigned    Sunland Park Police Department  Law Enforcement Agency
# 2           Retired  Dona Ana County Sheriff'S Office  Law Enforcement Agency
#
#    number_of_depts  number_of_unique_depts
# 0                3                       3
# 1                3                       3
# 2                3                       3
# TERMINATION INDEX:  Index([0], dtype='int64')
# CURRENT TERM SPOT:  0
# AGENCY AFTER TERM:  Sunland Park Police Department
#   person_nbr first_name middle_name   last_name suffix   sex year_of_birth  \
# 0  00-0222-P     Milton           G  Herrington    NaN  Male          1970
# 1  00-0222-P     Milton           G  Herrington    NaN  Male          1970
# 2  00-0222-P     Milton           G  Herrington    NaN  Male          1970
# 3  00-0222-P     Milton           G  Herrington    NaN  Male          1970
# 4  00-0222-P     Milton           G  Herrington    NaN  Male          1970
#
#     race start_date   end_date employment_type            rank  \
# 0  white 1997-05-05 1998-05-04             NaN  Patrol Officer
# 1  white 2000-04-21 2000-12-28             NaN  Patrol Officer
# 2  white 2001-05-11 2001-10-04             NaN           Chief
# 3  white 2016-05-23        NaT       Full Time  Patrol Officer
# 4  white 2001-07-01        NaT       Full Time  Patrol Officer
#
#   employment_status                               agency_name  \
# 0          Resigned               Carrizozo Police Department
# 1          Resigned                 Roswell Police Department
# 2       Termination             Lake Arthur Police Department
# 3            Active        Dexter Department Of Public Safety
# 4            Active  New Mexico Military Institute Police Dep
#
#               agency_type  number_of_depts  number_of_unique_depts
# 0  Law Enforcement Agency                5                       5
# 1  Law Enforcement Agency                5                       5
# 2  Law Enforcement Agency                5                       5
# 3  Law Enforcement Agency                5                       5
# 4  Law Enforcement Agency                5                       5
# TERMINATION INDEX:  Index([2], dtype='int64')
# CURRENT TERM SPOT:  2
# AGENCY AFTER TERM:  Dexter Department Of Public Safety
#   person_nbr first_name middle_name last_name suffix   sex year_of_birth  \
# 0  00-0286-P    Abraham           P      Baca    NaN  Male          1977
# 1  00-0286-P    Abraham           P      Baca    NaN  Male          1977
# 2  00-0286-P    Abraham           P      Baca    NaN  Male          1977
# 3  00-0286-P    Abraham           P      Baca    NaN  Male          1977
#
#        race start_date   end_date employment_type            rank  \
# 0  Hispanic 2000-12-09 2010-07-16             NaN  Patrol Officer
# 1  Hispanic 2011-06-12 2016-06-19             NaN        Sergeant
# 2  Hispanic 2017-10-23 2020-12-25       Full Time      Lieutenant
# 3  Hispanic 2021-01-04        NaT       Full Time      Lieutenant
#
#   employment_status                         agency_name  \
# 0       Termination             New Mexico State Police
# 1          Resigned  Rio Arriba County Sheriff'S Office
# 2           Retired          Espanola Police Department
# 3            Active   Pojoaque Tribal Police Department
#
#               agency_type  number_of_depts  number_of_unique_depts
# 0  Law Enforcement Agency                4                       4
# 1  Law Enforcement Agency                4                       4
# 2  Law Enforcement Agency                4                       4
# 3  Law Enforcement Agency                4                       4
# TERMINATION INDEX:  Index([0], dtype='int64')
# CURRENT TERM SPOT:  0
# AGENCY AFTER TERM:  Rio Arriba County Sheriff'S Office
#   person_nbr first_name middle_name last_name suffix   sex year_of_birth  \
# 0  00-0310-P    Stephen           M   Montoya    NaN  Male          1974
# 1  00-0310-P    Stephen           M   Montoya    NaN  Male          1974
#
#        race start_date   end_date employment_type       rank  \
# 0  Hispanic 2000-12-09 2008-08-01             NaN      Agent
# 1  Hispanic 2009-02-02 2019-07-01       Full Time  Detective
#
#   employment_status                   agency_name             agency_type  \
# 0       Termination       New Mexico State Police  Law Enforcement Agency
# 1           Retired  Las Cruces Police Department  Law Enforcement Agency
#
#    number_of_depts  number_of_unique_depts
# 0                2                       2
# 1                2                       2
# TERMINATION INDEX:  Index([0], dtype='int64')
# CURRENT TERM SPOT:  0
# AGENCY AFTER TERM:  Las Cruces Police Department
#   person_nbr first_name middle_name last_name suffix   sex year_of_birth  \
# 0  00-0374-P       Rene           R    Toledo    NaN  Male          1969
# 1  00-0374-P       Rene           R    Toledo    NaN  Male          1969
# 2  00-0374-P       Rene           R    Toledo    NaN  Male          1969
#
#        race start_date   end_date employment_type                  rank  \
# 0  Hispanic 1995-07-24 1995-11-21             NaN  [Missing Title/Rank]
# 1  Hispanic 2000-05-01 2007-04-16             NaN        Patrol Officer
# 2  Hispanic 2008-04-16        NaT       Full Time        Patrol Officer
#
#   employment_status                         agency_name  \
# 0       Termination  Bernalillo County Sheriff'S Office
# 1          Resigned         Los Lunas Police Department
# 2            Active       Albuquerque Police Department
#
#               agency_type  number_of_depts  number_of_unique_depts
# 0  Law Enforcement Agency                3                       3
# 1  Law Enforcement Agency                3                       3
# 2  Law Enforcement Agency                3                       3
# TERMINATION INDEX:  Index([0], dtype='int64')
# CURRENT TERM SPOT:  0
# AGENCY AFTER TERM:  Los Lunas Police Department
#   person_nbr first_name middle_name last_name suffix   sex year_of_birth  \
# 0  01-0016-P     George         NaN    Jojola    NaN  Male          1960
# 1  01-0016-P     George         NaN    Jojola    NaN  Male          1960
#
#               race start_date   end_date employment_type            rank  \
# 0  Native American 1994-01-10 2009-08-12             NaN           Chief
# 1  Native American 2014-02-28        NaT       Full Time  Patrol Officer
#
#   employment_status                         agency_name  \
# 0       Termination     Isleta Tribal Police Department
# 1            Active  Bernalillo County Sheriff'S Office
#
#               agency_type  number_of_depts  number_of_unique_depts
# 0  Law Enforcement Agency                2                       2
# 1  Law Enforcement Agency                2                       2
# TERMINATION INDEX:  Index([0], dtype='int64')
# CURRENT TERM SPOT:  0
# AGENCY AFTER TERM:  Bernalillo County Sheriff'S Office
#   person_nbr first_name middle_name last_name suffix   sex year_of_birth  \
# 0  01-0060-P    Bernave           R   Sedillo    NaN  Male          1970
# 1  01-0060-P    Bernave           R   Sedillo    NaN  Male          1970
# 2  01-0060-P    Bernave           R   Sedillo    NaN  Male          1970
# 3  01-0060-P    Bernave           R   Sedillo    NaN  Male          1970
#
#        race start_date   end_date employment_type            rank  \
# 0  Hispanic 1993-10-13 1994-05-06             NaN  Patrol Officer
# 1  Hispanic 2000-05-08 2003-05-03             NaN  Patrol Officer
# 2  Hispanic 2003-04-21 2010-01-20             NaN         Marshal
# 3  Hispanic 2007-05-18        NaT       Full Time          Ranger
#
#   employment_status                     agency_name             agency_type  \
# 0       Termination      Portales Police Department  Law Enforcement Agency
# 1          Resigned       Clayton Police Department  Law Enforcement Agency
# 2          Resigned      Cimarron Police Department  Law Enforcement Agency
# 3            Active  New Mexico Emnrd - State Parks  Law Enforcement Agency
#
#    number_of_depts  number_of_unique_depts
# 0                4                       4
# 1                4                       4
# 2                4                       4
# 3                4                       4
# TERMINATION INDEX:  Index([0], dtype='int64')
# CURRENT TERM SPOT:  0
# AGENCY AFTER TERM:  Clayton Police Department
#   person_nbr first_name middle_name last_name suffix   sex year_of_birth  \
# 0  01-0062-P       Troy           A  Thompson    NaN  Male          1969
# 1  01-0062-P       Troy           A  Thompson    NaN  Male          1969
# 2  01-0062-P       Troy           A  Thompson    NaN  Male          1969
#
#     race start_date   end_date employment_type            rank  \
# 0  white 2008-03-18 2009-10-04             NaN  Patrol Officer
# 1  white 2000-10-09 2015-02-05             NaN       Detective
# 2  white 2005-11-21        NaT       Full Time        Sergeant
#
#   employment_status                    agency_name             agency_type  \
# 0          Resigned   Cloudcroft Police Department  Law Enforcement Agency
# 1       Termination   Alamogordo Police Department  Law Enforcement Agency
# 2            Active  Otero County Sheriff'S Office  Law Enforcement Agency
#
#    number_of_depts  number_of_unique_depts
# 0                3                       3
# 1                3                       3
# 2                3                       3
# TERMINATION INDEX:  Index([1], dtype='int64')
# CURRENT TERM SPOT:  1
# OFFICER START DATE AT NEXT PLACE IS BEFORE END DATE AT TERMINATED PLACE
#   person_nbr first_name middle_name last_name suffix   sex year_of_birth  \
# 0  01-0069-P      Felix           I     Nunez    NaN  Male          1972
# 1  01-0069-P      Felix           I     Nunez    NaN  Male          1972
# 2  01-0069-P      Felix           I     Nunez    NaN  Male          1972
# 3  01-0069-P      Felix           I     Nunez    NaN  Male          1972
#
#        race start_date   end_date employment_type            rank  \
# 0  Hispanic 2000-03-28 2003-07-30             NaN  Patrol Officer
# 1  Hispanic 2004-03-27 2012-07-06             NaN    Investigator
# 2  Hispanic 2012-07-02 2015-07-17             NaN  Patrol Officer
# 3  Hispanic 2016-01-16        NaT       Full Time           Chief
#
#   employment_status                                agency_name  \
# 0       Termination               Bernalillo Police Department
# 1          Resigned  District Attorney'S Office, 13Th District
# 2          Resigned                 Corrales Police Department
# 3            Active            Jemez Springs Police Department
#
#               agency_type  number_of_depts  number_of_unique_depts
# 0  Law Enforcement Agency                4                       4
# 1  Law Enforcement Agency                4                       4
# 2  Law Enforcement Agency                4                       4
# 3  Law Enforcement Agency                4                       4
# TERMINATION INDEX:  Index([0], dtype='int64')
# CURRENT TERM SPOT:  0
# AGENCY AFTER TERM:  District Attorney'S Office, 13Th District
#   person_nbr first_name middle_name last_name suffix   sex year_of_birth  \
# 0  01-0070-P       Fred           M    Torres    NaN  Male          1952
# 1  01-0070-P       Fred           M    Torres    NaN  Male          1952
# 2  01-0070-P       Fred           M    Torres    NaN  Male          1952
# 3  01-0070-P       Fred           M    Torres    NaN  Male          1952
# 4  01-0070-P       Fred           M    Torres    NaN  Male          1952
# 5  01-0070-P       Fred           M    Torres    NaN  Male          1952
# 6  01-0070-P       Fred           M    Torres    NaN  Male          1952
# 7  01-0070-P       Fred           M    Torres    NaN  Male          1952
#
#        race start_date   end_date employment_type            rank  \
# 0  Hispanic 1985-09-24 1993-11-19             NaN  Deputy Sheriff
# 1  Hispanic 1998-03-30 1998-11-11             NaN  Patrol Officer
# 2  Hispanic 2001-10-29 2003-04-21             NaN  Patrol Officer
# 3  Hispanic 2003-09-27 2005-12-01             NaN   Special Agent
# 4  Hispanic 2006-10-02 2008-02-08             NaN  Deputy Sheriff
# 5  Hispanic 2008-02-09 2009-10-17             NaN    Investigator
# 6  Hispanic 2000-05-25 2020-08-07             NaN          Deputy
# 7  Hispanic 2020-08-10 2021-02-05       Full Time  Deputy Sheriff
#
#   employment_status                                agency_name  \
# 0          Resigned         Bernalillo County Sheriff'S Office
# 1       Termination                    Belen Police Department
# 2          Resigned                    New Mexico State Police
# 3           Retired        New Mexico Gaming Control Board/Isd
# 4          Resigned           Sandoval County Sheriff'S Office
# 5       Termination  District Attorney'S Office, 13Th District
# 6          Resigned           Valencia County Sheriff'S Office
# 7       Termination            Lincoln County Sheriff'S Office
#
#               agency_type  number_of_depts  number_of_unique_depts
# 0  Law Enforcement Agency                8                       8
# 1  Law Enforcement Agency                8                       8
# 2  Law Enforcement Agency                8                       8
# 3  Law Enforcement Agency                8                       8
# 4  Law Enforcement Agency                8                       8
# 5  Law Enforcement Agency                8                       8
# 6  Law Enforcement Agency                8                       8
# 7  Law Enforcement Agency                8                       8
# TERMINATION INDEX:  Index([1, 5, 7], dtype='int64')
# CURRENT TERM SPOT:  1
# AGENCY AFTER TERM:  New Mexico State Police
# CURRENT TERM SPOT:  5
# OFFICER START DATE AT NEXT PLACE IS BEFORE END DATE AT TERMINATED PLACE
# CURRENT TERM SPOT:  7
# TERMINATION IS LAST THING IN OFFICERS HISTORY
#   person_nbr first_name middle_name last_name suffix   sex year_of_birth  \
# 0  01-0084-P     Harold           W   Edwards    NaN  Male          1969
# 1  01-0084-P     Harold           W   Edwards    NaN  Male          1969
# 2  01-0084-P     Harold           W   Edwards    NaN  Male          1969
# 3  01-0084-P     Harold           W   Edwards    NaN  Male          1969
#
#     race start_date   end_date employment_type                  rank  \
# 0  white 2000-11-15 2003-05-02             NaN        Patrol Officer
# 1  white 2005-02-08 2006-07-14             NaN  [Missing Title/Rank]
# 2  white 2003-05-02 2006-07-27             NaN        Deputy Sheriff
# 3  white 2006-07-30        NaT       Full Time        Patrol Officer
#
#   employment_status                        agency_name  \
# 0          Resigned         Portales Police Department
# 1       Termination    De Baca County Sheriff'S Office
# 2          Resigned  Roosevelt County Sheriff'S Office
# 3            Active            New Mexico State Police
#
#               agency_type  number_of_depts  number_of_unique_depts
# 0  Law Enforcement Agency                4                       4
# 1  Law Enforcement Agency                4                       4
# 2  Law Enforcement Agency                4                       4
# 3  Law Enforcement Agency                4                       4
# TERMINATION INDEX:  Index([1], dtype='int64')
# CURRENT TERM SPOT:  1
# OFFICER START DATE AT NEXT PLACE IS BEFORE END DATE AT TERMINATED PLACE
#   person_nbr first_name middle_name last_name suffix   sex year_of_birth  \
# 0  01-0109-P      Terry         NaN     McCoy    NaN  Male          1970
# 1  01-0109-P      Terry         NaN     McCoy    NaN  Male          1970
# 2  01-0109-P      Terry         NaN     McCoy    NaN  Male          1970
#
#     race start_date   end_date employment_type            rank  \
# 0  white 2001-01-22 2001-08-09             NaN  Patrol Officer
# 1  white 2001-12-20 2005-01-01             NaN  Patrol Officer
# 2  white 2005-01-02 2021-09-30       Full Time        Sergeant
#
#   employment_status                       agency_name             agency_type  \
# 0       Termination      Farmington Police Department  Law Enforcement Agency
# 1          Resigned           Aztec Police Department  Law Enforcement Agency
# 2           Retired  San Juan County Sheriff'S Office  Law Enforcement Agency
#
#    number_of_depts  number_of_unique_depts
# 0                3                       3
# 1                3                       3
# 2                3                       3
# TERMINATION INDEX:  Index([0], dtype='int64')
# CURRENT TERM SPOT:  0
# AGENCY AFTER TERM:  Aztec Police Department
#   person_nbr first_name middle_name last_name suffix   sex year_of_birth  \
# 0  01-0117-P      Jesse           J    Casaus    NaN  Male          1975
# 1  01-0117-P      Jesse           J    Casaus    NaN  Male          1975
# 2  01-0117-P      Jesse           J    Casaus    NaN  Male          1975
# 3  01-0117-P      Jesse           J    Casaus    NaN  Male          1975
#
#        race start_date   end_date employment_type                  rank  \
# 0  Hispanic 2001-06-22 2008-05-02             NaN        Patrol Officer
# 1  Hispanic 2008-06-30 2016-02-26             NaN        Deputy Sheriff
# 2  Hispanic 2016-12-12 2018-12-31             NaN  [Missing Title/Rank]
# 3  Hispanic 2019-03-18        NaT       Full Time               Sheriff
#
#   employment_status                       agency_name             agency_type  \
# 0          Resigned           New Mexico State Police  Law Enforcement Agency
# 1       Termination  Sandoval County Sheriff'S Office  Law Enforcement Agency
# 2          Resigned            Cuba Police Department  Law Enforcement Agency
# 3            Active  Sandoval County Sheriff'S Office  Law Enforcement Agency
#
#    number_of_depts  number_of_unique_depts
# 0                4                       3
# 1                4                       3
# 2                4                       3
# 3                4                       3
# TERMINATION INDEX:  Index([1], dtype='int64')
# CURRENT TERM SPOT:  1
# AGENCY AFTER TERM:  Cuba Police Department
#   person_nbr first_name middle_name last_name suffix   sex year_of_birth  \
# 0  01-0183-P      James         NaN  Maiorano    III  Male          1982
# 1  01-0183-P      James         NaN  Maiorano    III  Male          1982
#
#     race start_date   end_date employment_type            rank  \
# 0  white 2000-08-21 2003-05-28             NaN  Patrol Officer
# 1  white 2004-02-18        NaT       Full Time         Sheriff
#
#   employment_status                       agency_name             agency_type  \
# 0       Termination          Gallup Police Department  Law Enforcement Agency
# 1            Active  Mckinley County Sheriff'S Office  Law Enforcement Agency
#
#    number_of_depts  number_of_unique_depts
# 0                2                       2
# 1                2                       2
# TERMINATION INDEX:  Index([0], dtype='int64')
# CURRENT TERM SPOT:  0
# AGENCY AFTER TERM:  Mckinley County Sheriff'S Office
#   person_nbr first_name middle_name last_name suffix   sex year_of_birth  \
# 0  01-0192-P       Paul           J   Colombe    NaN  Male          1975
# 1  01-0192-P       Paul           J   Colombe    NaN  Male          1975
# 2  01-0192-P       Paul           J   Colombe    NaN  Male          1975
# 3  01-0192-P       Paul           J   Colombe    NaN  Male          1975
# 4  01-0192-P       Paul           J   Colombe    NaN  Male          1975
#
#        race start_date   end_date employment_type            rank  \
# 0  Hispanic 2000-09-11 2001-09-28             NaN  Patrol Officer
# 1  Hispanic 2006-11-02 2010-04-16             NaN   Special Agent
# 2  Hispanic 2014-02-21 2020-05-01             NaN        Corporal
# 3  Hispanic 2021-01-10 2021-12-02             NaN  Deputy Sheriff
# 4  Hispanic 2021-01-10 2022-01-07       Full Time  Deputy Sheriff
#
#   employment_status                         agency_name  \
# 0          Resigned          Espanola Police Department
# 1          Resigned    Tesuque Tribal Police Department
# 2          Resigned    Santa Fe County Sheriff'S Office
# 3       Termination   Roosevelt County Sheriff'S Office
# 4       Termination  Rio Arriba County Sheriff'S Office
#
#               agency_type  number_of_depts  number_of_unique_depts
# 0  Law Enforcement Agency                5                       5
# 1  Law Enforcement Agency                5                       5
# 2  Law Enforcement Agency                5                       5
# 3  Law Enforcement Agency                5                       5
# 4  Law Enforcement Agency                5                       5
# TERMINATION INDEX:  Index([3, 4], dtype='int64')
# CURRENT TERM SPOT:  3
# OFFICER START DATE AT NEXT PLACE IS BEFORE END DATE AT TERMINATED PLACE
# CURRENT TERM SPOT:  4
# TERMINATION IS LAST THING IN OFFICERS HISTORY
#   person_nbr first_name middle_name  last_name suffix     sex year_of_birth  \
# 0  01-0206-P     Andrea           m  Gutierrez    NaN  Female          1977
# 1  01-0206-P     Andrea           m  Gutierrez    NaN  Female          1977
# 2  01-0206-P     Andrea           m  Gutierrez    NaN  Female          1977
#
#        race start_date   end_date employment_type                  rank  \
# 0  Hispanic 2007-07-23 2013-07-12             NaN        Patrol Officer
# 1  Hispanic 2013-11-25 2015-08-21             NaN  [Missing Title/Rank]
# 2  Hispanic 2001-02-24 2020-05-31       Full Time        Patrol Officer
#
#   employment_status                                        agency_name  \
# 0       Termination                         Santa Fe Police Department
# 1          Resigned  New Mexico Highlands University Police Department
# 2           Retired                        Las Vegas Police Department
#
#               agency_type  number_of_depts  number_of_unique_depts
# 0  Law Enforcement Agency                3                       3
# 1  Law Enforcement Agency                3                       3
# 2  Law Enforcement Agency                3                       3
# TERMINATION INDEX:  Index([0], dtype='int64')
# CURRENT TERM SPOT:  0
# AGENCY AFTER TERM:  New Mexico Highlands University Police Department
#   person_nbr first_name middle_name  last_name suffix   sex year_of_birth  \
# 0  01-0207-P      Jesus         NaN  Hernandez    NaN  Male          1976
# 1  01-0207-P      Jesus         NaN  Hernandez    NaN  Male          1976
#
#        race start_date   end_date employment_type            rank  \
# 0  Hispanic 2000-09-11 2009-05-28             NaN  Patrol Officer
# 1  Hispanic 2009-07-01        NaT       Full Time        Sergeant
#
#   employment_status                     agency_name             agency_type  \
# 0       Termination  Sunland Park Police Department  Law Enforcement Agency
# 1            Active   Otero County Sheriff'S Office  Law Enforcement Agency
#
#    number_of_depts  number_of_unique_depts
# 0                2                       2
# 1                2                       2
# TERMINATION INDEX:  Index([0], dtype='int64')
# CURRENT TERM SPOT:  0
# AGENCY AFTER TERM:  Otero County Sheriff'S Office
#   person_nbr first_name middle_name last_name suffix   sex year_of_birth  \
# 0  01-0263-P     Peters           B     James    NaN  Male          1962
# 1  01-0263-P     Peters           B     James    NaN  Male          1962
# 2  01-0263-P     Peters           B     James    NaN  Male          1962
# 3  01-0263-P     Peters           B     James    NaN  Male          1962
# 4  01-0263-P     Peters           B     James    NaN  Male          1962
#
#               race start_date   end_date employment_type            rank  \
# 0  Native American 1997-10-25 2002-03-21             NaN  Patrol Officer
# 1  Native American 2002-09-16 2003-01-15             NaN  Patrol Officer
# 2  Native American 2014-11-10 2015-10-10             NaN  Patrol Officer
# 3  Native American 2005-04-25 2016-09-13       Full Time  Deputy Sheriff
# 4  Native American 2016-12-13        NaT       Full Time  Patrol Officer
#
#   employment_status                         agency_name  \
# 0          Resigned     Isleta Tribal Police Department
# 1          Resigned             Acoma Police Department
# 2          Resigned             Milan Police Department
# 3       Termination      Cibola County Sheriff'S Office
# 4            Active  Pueblo Of Laguna Police Department
#
#               agency_type  number_of_depts  number_of_unique_depts
# 0  Law Enforcement Agency                5                       5
# 1  Law Enforcement Agency                5                       5
# 2  Law Enforcement Agency                5                       5
# 3  Law Enforcement Agency                5                       5
# 4  Law Enforcement Agency                5                       5
# TERMINATION INDEX:  Index([3], dtype='int64')
# CURRENT TERM SPOT:  3
# AGENCY AFTER TERM:  Pueblo Of Laguna Police Department
#   person_nbr first_name middle_name last_name suffix   sex year_of_birth  \
# 0  01-0270-P    Phillip           R  Trujillo    NaN  Male          1971
# 1  01-0270-P    Phillip           R  Trujillo    NaN  Male          1971
#
#        race start_date   end_date employment_type            rank  \
# 0  Hispanic 1993-07-04 2019-10-24             NaN        Sergeant
# 1  Hispanic 2020-01-06 2021-04-02       Full Time  Patrol Officer
#
#   employment_status                         agency_name  \
# 0       Termination  Santa Ana Tribal Police Department
# 1          Resigned          Corrales Police Department
#
#               agency_type  number_of_depts  number_of_unique_depts
# 0  Law Enforcement Agency                2                       2
# 1  Law Enforcement Agency                2                       2
# TERMINATION INDEX:  Index([0], dtype='int64')
# CURRENT TERM SPOT:  0
# AGENCY AFTER TERM:  Corrales Police Department
#    person_nbr first_name middle_name  last_name suffix   sex year_of_birth  \
# 0   01-0281-P     Victor           J  Rodriguez    NaN  Male          1981
# 1   01-0281-P     Victor           J  Rodriguez    NaN  Male          1981
# 2   01-0281-P     Victor           J  Rodriguez    NaN  Male          1981
# 3   01-0281-P     Victor           J  Rodriguez    NaN  Male          1981
# 4   01-0281-P     Victor           J  Rodriguez    NaN  Male          1981
# 5   01-0281-P     Victor           J  Rodriguez    NaN  Male          1981
# 6   01-0281-P     Victor           J  Rodriguez    NaN  Male          1981
# 7   01-0281-P     Victor           J  Rodriguez    NaN  Male          1981
# 8   01-0281-P     Victor           J  Rodriguez    NaN  Male          1981
# 9   01-0281-P     Victor           J  Rodriguez    NaN  Male          1981
# 10  01-0281-P     Victor           J  Rodriguez    NaN  Male          1981
#
#         race start_date   end_date employment_type            rank  \
# 0   Hispanic 2000-10-16 2000-12-15             NaN  Patrol Officer
# 1   Hispanic 2001-01-12 2002-01-04             NaN  Patrol Officer
# 2   Hispanic 2004-10-04 2006-12-14             NaN  Deputy Sheriff
# 3   Hispanic 2006-12-18 2008-02-29             NaN  Patrol Officer
# 4   Hispanic 2001-12-27 2008-10-15             NaN  Deputy Sheriff
# 5   Hispanic 2013-03-29 2013-03-29             NaN        Sergeant
# 6   Hispanic 2014-06-09 2015-01-03             NaN       Commander
# 7   Hispanic 2019-01-28 2020-01-06       Full Time           Chief
# 8   Hispanic 2015-03-30 2021-07-01       Full Time    Investigator
# 9   Hispanic 2021-07-06 2022-09-30       Full Time           Chief
# 10  Hispanic 2022-10-03        NaT       Full Time           Chief
#
#    employment_status                              agency_name  \
# 0        Termination                Capitan Police Department
# 1           Resigned                  Tatum Police Department
# 2           Resigned            Curry County Sheriff'S Office
# 3           Resigned                Artesia Police Department
# 4           Resigned            Otero County Sheriff'S Office
# 5           Resigned                  New Mexico State Police
# 6        Termination      New Mexico Gaming Control Board/Isd
# 7           Resigned                  Belen Police Department
# 8           Resigned         Sandoval County Sheriff'S Office
# 9            Retired  Truth Or Consequences Police Department
# 10            Active          Isleta Tribal Police Department
#
#                agency_type  number_of_depts  number_of_unique_depts
# 0   Law Enforcement Agency               11                      11
# 1   Law Enforcement Agency               11                      11
# 2   Law Enforcement Agency               11                      11
# 3   Law Enforcement Agency               11                      11
# 4   Law Enforcement Agency               11                      11
# 5   Law Enforcement Agency               11                      11
# 6   Law Enforcement Agency               11                      11
# 7   Law Enforcement Agency               11                      11
# 8   Law Enforcement Agency               11                      11
# 9   Law Enforcement Agency               11                      11
# 10  Law Enforcement Agency               11                      11
# TERMINATION INDEX:  Index([0, 6], dtype='int64')
# CURRENT TERM SPOT:  0
# AGENCY AFTER TERM:  Tatum Police Department
# CURRENT TERM SPOT:  6
# AGENCY AFTER TERM:  Belen Police Department
#   person_nbr first_name middle_name  last_name suffix   sex year_of_birth  \
# 0  01-0300-P      Kevin          L.  Gutierrez    NaN  Male          1974
# 1  01-0300-P      Kevin          L.  Gutierrez    NaN  Male          1974
# 2  01-0300-P      Kevin          L.  Gutierrez    NaN  Male          1974
#
#        race start_date   end_date employment_type            rank  \
# 0  Hispanic 2001-12-07 2006-05-17             NaN  Patrol Officer
# 1  Hispanic 2006-06-13 2020-11-30       Full Time  Patrol Officer
# 2  Hispanic 2020-12-01        NaT       Full Time           Chief
#
#   employment_status               agency_name             agency_type  \
# 0       Termination   New Mexico State Police  Law Enforcement Agency
# 1           Retired  Eunice Police Department  Law Enforcement Agency
# 2            Active   Tatum Police Department  Law Enforcement Agency
#
#    number_of_depts  number_of_unique_depts
# 0                3                       3
# 1                3                       3
# 2                3                       3
# TERMINATION INDEX:  Index([0], dtype='int64')
# CURRENT TERM SPOT:  0
# AGENCY AFTER TERM:  Eunice Police Department
#   person_nbr first_name middle_name last_name suffix   sex year_of_birth  \
# 0  01-0310-P      Frank           F   Methola    NaN  Male          1971
# 1  01-0310-P      Frank           F   Methola    NaN  Male          1971
# 2  01-0310-P      Frank           F   Methola    NaN  Male          1971
# 3  01-0310-P      Frank           F   Methola    NaN  Male          1971
# 4  01-0310-P      Frank           F   Methola    NaN  Male          1971
# 5  01-0310-P      Frank           F   Methola    NaN  Male          1971
#
#     race start_date   end_date employment_type                  rank  \
# 0  white 2001-12-07 2004-07-30             NaN        Patrol Officer
# 1  white 2004-08-02 2010-10-12             NaN        Deputy Sheriff
# 2  white 2011-05-16 2012-05-14             NaN  [Missing Title/Rank]
# 3  white 2016-08-08 2016-12-05             NaN        Patrol Officer
# 4  white 2014-04-22 2018-08-21       Part Time                 Chief
# 5  white 2021-03-01        NaT       Full Time              Director
#
#   employment_status                         agency_name  \
# 0          Resigned             New Mexico State Police
# 1          Resigned    Valencia County Sheriff'S Office
# 2       Termination        Santa Rosa Police Department
# 3          Resigned  Dexter Department Of Public Safety
# 4       Termination       Lake Arthur Police Department
# 5            Active            Loving Police Department
#
#               agency_type  number_of_depts  number_of_unique_depts
# 0  Law Enforcement Agency                6                       6
# 1  Law Enforcement Agency                6                       6
# 2  Law Enforcement Agency                6                       6
# 3  Law Enforcement Agency                6                       6
# 4  Law Enforcement Agency                6                       6
# 5  Law Enforcement Agency                6                       6
# TERMINATION INDEX:  Index([2, 4], dtype='int64')
# CURRENT TERM SPOT:  2
# AGENCY AFTER TERM:  Dexter Department Of Public Safety
# CURRENT TERM SPOT:  4
# AGENCY AFTER TERM:  Loving Police Department
#   person_nbr first_name middle_name last_name suffix   sex year_of_birth  \
# 0  01-0328-P      James           L   Aguilar    NaN  Male          1969
# 1  01-0328-P      James           L   Aguilar    NaN  Male          1969
#
#        race start_date   end_date employment_type            rank  \
# 0  Hispanic 2006-03-27 2013-03-15             NaN  Patrol Officer
# 1  Hispanic 2001-07-27        NaT       Full Time  Patrol Officer
#
#   employment_status                   agency_name             agency_type  \
# 0       Termination  Rio Rancho Police Department  Law Enforcement Agency
# 1            Active     Roswell Police Department  Law Enforcement Agency
#
#    number_of_depts  number_of_unique_depts
# 0                2                       2
# 1                2                       2
# TERMINATION INDEX:  Index([0], dtype='int64')
# CURRENT TERM SPOT:  0
# OFFICER START DATE AT NEXT PLACE IS BEFORE END DATE AT TERMINATED PLACE
# ...
# 3          Resigned                    Silver City Police Department
# 4          Resigned                 Santa Fe County Sheriff'S Office
#
#               agency_type  number_of_depts  number_of_unique_depts
# 0  Law Enforcement Agency                5                       5
# 1  Law Enforcement Agency                5                       5
# 2  Law Enforcement Agency                5                       5
# 3  Law Enforcement Agency                5                       5
# 4  Law Enforcement Agency                5                       5
# TERMINATION INDEX:  Index([2], dtype='int64')
# CURRENT TERM SPOT:  2
# OFFICER START DATE AT NEXT PLACE IS BEFORE END DATE AT TERMINATED PLACE
#   person_nbr first_name middle_name last_name suffix   sex year_of_birth  \
# 0  98-0152-P    ALFREDO           C  TURRIETA    NaN  Male          1956
# 1  98-0152-P    ALFREDO           C  TURRIETA    NaN  Male          1956
# 2  98-0152-P    ALFREDO           C  TURRIETA    NaN  Male          1956
# 3  98-0152-P    ALFREDO           C  TURRIETA    NaN  Male          1956
#
#        race start_date   end_date employment_type            rank  \
# 0  Hispanic 1997-12-02 2000-06-12             NaN  Patrol Officer
# 1  Hispanic 2000-07-24 2003-06-24             NaN  Patrol Officer
# 2  Hispanic 2003-08-25 2012-08-01             NaN  Deputy Sheriff
# 3  Hispanic 2015-10-19 2019-02-01       Full Time  Patrol Officer
#
#   employment_status                       agency_name             agency_type  \
# 0          Resigned       Tucumcari Police Department  Law Enforcement Agency
# 1          Resigned           Belen Police Department  Law Enforcement Agency
# 2       Termination  Sandoval County Sheriff'S Office  Law Enforcement Agency
# 3          Resigned     Mountainair Police Department  Law Enforcement Agency
#
#    number_of_depts  number_of_unique_depts
# 0                4                       4
# 1                4                       4
# 2                4                       4
# 3                4                       4
# TERMINATION INDEX:  Index([2], dtype='int64')
# CURRENT TERM SPOT:  2
# AGENCY AFTER TERM:  Mountainair Police Department
#   person_nbr first_name middle_name last_name suffix   sex year_of_birth  \
# 0  98-0187-P     Ernest           R    Garcia    NaN  Male          2974
# 1  98-0187-P     Ernest           R    Garcia    NaN  Male          2974
# 2  98-0187-P     Ernest           R    Garcia    NaN  Male          2974
#
#        race start_date   end_date employment_type            rank  \
# 0  Hispanic 1998-03-08 2016-10-18             NaN  Patrol Officer
# 1  Hispanic 2016-12-05 2017-12-30             NaN  Deputy Sheriff
# 2  Hispanic 2017-01-13        NaT       Full Time  Patrol Officer
#
#   employment_status                           agency_name  \
# 0       Termination               New Mexico State Police
# 1          Resigned    Rio Arriba County Sheriff'S Office
# 2            Active  Santa Clara Tribal Police Department
#
#               agency_type  number_of_depts  number_of_unique_depts
# 0  Law Enforcement Agency                3                       3
# 1  Law Enforcement Agency                3                       3
# 2  Law Enforcement Agency                3                       3
# TERMINATION INDEX:  Index([0], dtype='int64')
# CURRENT TERM SPOT:  0
# AGENCY AFTER TERM:  Rio Arriba County Sheriff'S Office
#   person_nbr first_name middle_name last_name suffix   sex year_of_birth  \
# 0  98-0285-P      Harry           S    Powers    NaN  Male          1956
# 1  98-0285-P      Harry           S    Powers    NaN  Male          1956
# 2  98-0285-P      Harry           S    Powers    NaN  Male          1956
#
#     race start_date   end_date employment_type            rank  \
# 0  white 1998-04-19 1998-12-12             NaN  Deputy Sheriff
# 1  white 2000-07-16 2021-06-04       Full Time        Sergeant
# 2  white 2022-10-17        NaT       Full Time  Patrol Officer
#
#   employment_status                         agency_name  \
# 0          Resigned  Bernalillo County Sheriff'S Office
# 1       Termination     Isleta Tribal Police Department
# 2            Active          Corrales Police Department
#
#               agency_type  number_of_depts  number_of_unique_depts
# 0  Law Enforcement Agency                3                       3
# 1  Law Enforcement Agency                3                       3
# 2  Law Enforcement Agency                3                       3
# TERMINATION INDEX:  Index([1], dtype='int64')
# CURRENT TERM SPOT:  1
# AGENCY AFTER TERM:  Corrales Police Department
#   person_nbr first_name middle_name last_name suffix   sex year_of_birth  \
# 0  98-0293-P      Lucas           B   Alvarez    NaN  Male          1972
# 1  98-0293-P      Lucas           B   Alvarez    NaN  Male          1972
# 2  98-0293-P      Lucas           B   Alvarez    NaN  Male          1972
# 3  98-0293-P      Lucas           B   Alvarez    NaN  Male          1972
#
#        race start_date   end_date employment_type            rank  \
# 0  Hispanic 1998-01-19 1999-02-11             NaN  Patrol Officer
# 1  Hispanic 1999-02-11 2000-04-23             NaN  Deputy Sheriff
# 2  Hispanic 2000-04-24 2014-01-21             NaN        Corporal
# 3  Hispanic 2015-06-22        NaT       Full Time        Sergeant
#
#   employment_status                              agency_name  \
# 0          Resigned  Truth Or Consequences Police Department
# 1          Resigned           Sierra County Sheriff'S Office
# 2       Termination         Dona Ana County Sheriff'S Office
# 3            Active           Sunland Park Police Department
#
#               agency_type  number_of_depts  number_of_unique_depts
# 0  Law Enforcement Agency                4                       4
# 1  Law Enforcement Agency                4                       4
# 2  Law Enforcement Agency                4                       4
# 3  Law Enforcement Agency                4                       4
# TERMINATION INDEX:  Index([2], dtype='int64')
# CURRENT TERM SPOT:  2
# AGENCY AFTER TERM:  Sunland Park Police Department
#   person_nbr first_name middle_name last_name suffix   sex year_of_birth  \
# 0  98-0317-P       Juan         NaN    Ortega    NaN  Male          1971
# 1  98-0317-P       Juan         NaN    Ortega    NaN  Male          1971
# 2  98-0317-P       Juan         NaN    Ortega    NaN  Male          1971
#
#        race start_date   end_date employment_type            rank  \
# 0  Hispanic 1998-08-03 2008-10-07             NaN  Patrol Officer
# 1  Hispanic 2010-09-27 2020-03-26       Full Time        Sergeant
# 2  Hispanic 2020-03-30        NaT       Full Time          Deputy
#
#   employment_status                                    agency_name  \
# 0       Termination  New Mexico State University Police Department
# 1          Resigned                 Sunland Park Police Department
# 2            Active               Dona Ana County Sheriff'S Office
#
#               agency_type  number_of_depts  number_of_unique_depts
# 0  Law Enforcement Agency                3                       3
# 1  Law Enforcement Agency                3                       3
# 2  Law Enforcement Agency                3                       3
# TERMINATION INDEX:  Index([0], dtype='int64')
# CURRENT TERM SPOT:  0
# AGENCY AFTER TERM:  Sunland Park Police Department
#   person_nbr first_name middle_name last_name suffix   sex year_of_birth  \
# 0  99-0016-P    Patrick           M  Klaurens    NaN  Male          1972
# 1  99-0016-P    Patrick           M  Klaurens    NaN  Male          1972
#
#     race start_date   end_date employment_type            rank  \
# 0  white 1998-01-19 2001-12-18             NaN  Patrol Officer
# 1  white 2002-04-29        NaT       Full Time  Patrol Officer
#
#   employment_status                                 agency_name  \
# 0       Termination                Las Cruces Police Department
# 1            Active  University Of New Mexico Police Department
#
#               agency_type  number_of_depts  number_of_unique_depts
# 0  Law Enforcement Agency                2                       2
# 1  Law Enforcement Agency                2                       2
# TERMINATION INDEX:  Index([0], dtype='int64')
# CURRENT TERM SPOT:  0
# AGENCY AFTER TERM:  University Of New Mexico Police Department
#   person_nbr first_name middle_name last_name suffix   sex year_of_birth  \
# 0  99-0125-P      David           E      Rael    Jr.  Male          1967
# 1  99-0125-P      David           E      Rael    Jr.  Male          1967
# 2  99-0125-P      David           E      Rael    Jr.  Male          1967
# 3  99-0125-P      David           E      Rael    Jr.  Male          1967
# 4  99-0125-P      David           E      Rael    Jr.  Male          1967
# 5  99-0125-P      David           E      Rael    Jr.  Male          1967
#
#        race start_date   end_date employment_type            rank  \
# 0  Hispanic 1995-03-13 1995-05-01             NaN  Deputy Sheriff
# 1  Hispanic 1998-12-26 2013-09-23             NaN  Patrol Officer
# 2  Hispanic 2014-05-19 2015-02-13             NaN   Special Agent
# 3  Hispanic 2015-09-16 2019-03-29             NaN         Officer
# 4  Hispanic 2019-09-16 2020-04-01       Full Time  Patrol Officer
# 5  Hispanic 2022-01-10        NaT       Full Time  Patrol Officer
#
#   employment_status                                   agency_name  \
# 0       Termination              Santa Fe County Sheriff'S Office
# 1          Resigned                    Santa Fe Police Department
# 2       Termination           New Mexico Gaming Control Board/Isd
# 3           Retired                Bosque Farms Police Department
# 4          Resigned          Los Lunas School Resource Department
# 5            Active  Albuquerque Public Schools Police Department
#
#               agency_type  number_of_depts  number_of_unique_depts
# 0  Law Enforcement Agency                6                       6
# 1  Law Enforcement Agency                6                       6
# 2  Law Enforcement Agency                6                       6
# 3  Law Enforcement Agency                6                       6
# 4  Law Enforcement Agency                6                       6
# 5  Law Enforcement Agency                6                       6
# TERMINATION INDEX:  Index([0, 2], dtype='int64')
# CURRENT TERM SPOT:  0
# AGENCY AFTER TERM:  Santa Fe Police Department
# CURRENT TERM SPOT:  2
# AGENCY AFTER TERM:  Bosque Farms Police Department
#   person_nbr first_name middle_name  last_name suffix   sex year_of_birth  \
# 0  99-0150-P      Peter           T  Honigmann    NaN  Male          1964
# 1  99-0150-P      Peter           T  Honigmann    NaN  Male          1964
# 2  99-0150-P      Peter           T  Honigmann    NaN  Male          1964
# 3  99-0150-P      Peter           T  Honigmann    NaN  Male          1964
#
#     race start_date   end_date employment_type            rank  \
# 0  white 1996-12-02 1997-07-01             NaN           Chief
# 1  white 1998-08-06 1999-06-01             NaN  Patrol Officer
# 2  white 2007-12-10 2019-10-17       Full Time        Sergeant
# 3  white 1999-06-10        NaT       Full Time  Deputy Sheriff
#
#   employment_status                  agency_name             agency_type  \
# 0          Resigned   Mosquero Police Department  Law Enforcement Agency
# 1       Termination        Roy Police Department  Law Enforcement Agency
# 2          Resigned  Lovington Police Department  Law Enforcement Agency
# 3            Active  Lea County Sheriff'S Office  Law Enforcement Agency
#
#    number_of_depts  number_of_unique_depts
# 0                4                       4
# 1                4                       4
# 2                4                       4
# 3                4                       4
# TERMINATION INDEX:  Index([1], dtype='int64')
# CURRENT TERM SPOT:  1
# AGENCY AFTER TERM:  Lovington Police Department
#   person_nbr first_name middle_name last_name suffix   sex year_of_birth  \
# 0  99-0151-P      James           E   Johnson    NaN  Male          1960
# 1  99-0151-P      James           E   Johnson    NaN  Male          1960
#
#                race start_date   end_date employment_type            rank  \
# 0  African American 1999-01-03 2011-12-06             NaN  Patrol Officer
# 1  African American 2018-07-31        NaT             NaN          Deputy
#
#   employment_status                     agency_name             agency_type  \
# 0       Termination       Roswell Police Department  Law Enforcement Agency
# 1            Active  Chaves County Sheriff'S Office  Law Enforcement Agency
#
#    number_of_depts  number_of_unique_depts
# 0                2                       2
# 1                2                       2
# TERMINATION INDEX:  Index([0], dtype='int64')
# CURRENT TERM SPOT:  0
# AGENCY AFTER TERM:  Chaves County Sheriff'S Office
#   person_nbr first_name middle_name  last_name suffix   sex year_of_birth  \
# 0  99-0226-P      Larry          K.  Bleimeyer    Jr.  Male          1974
# 1  99-0226-P      Larry          K.  Bleimeyer    Jr.  Male          1974
# 2  99-0226-P      Larry          K.  Bleimeyer    Jr.  Male          1974
# 3  99-0226-P      Larry          K.  Bleimeyer    Jr.  Male          1974
# 4  99-0226-P      Larry          K.  Bleimeyer    Jr.  Male          1974
#
#     race start_date   end_date employment_type            rank  \
# 0  white 1999-07-09 2000-09-27             NaN  Patrol Officer
# 1  white 2000-12-11 2002-05-15             NaN  Patrol Officer
# 2  white 2002-05-20 2013-09-04             NaN  Deputy Sheriff
# 3  white 2014-08-04 2016-01-25             NaN  Patrol Officer
# 4  white 2016-02-02 2021-06-30       Full Time  Patrol Officer
#
#   employment_status                              agency_name  \
# 0          Resigned             Las Cruces Police Department
# 1          Resigned               Tularosa Police Department
# 2       Termination         Dona Ana County Sheriff'S Office
# 3          Resigned  Truth Or Consequences Police Department
# 4           Retired                  Hatch Police Department
#
#               agency_type  number_of_depts  number_of_unique_depts
# 0  Law Enforcement Agency                5                       5
# 1  Law Enforcement Agency                5                       5
# 2  Law Enforcement Agency                5                       5
# 3  Law Enforcement Agency                5                       5
# 4  Law Enforcement Agency                5                       5
# TERMINATION INDEX:  Index([2], dtype='int64')
# CURRENT TERM SPOT:  2
# AGENCY AFTER TERM:  Truth Or Consequences Police Department
#   person_nbr first_name middle_name last_name suffix     sex year_of_birth  \
# 0  99-0376-P     Orlena           F     Hooee    NaN  Female          1960
# 1  99-0376-P     Orlena           F     Hooee    NaN  Female          1960
# 2  99-0376-P     Orlena           F     Hooee    NaN  Female          1960
#
#               race start_date   end_date employment_type            rank  \
# 0  Native American 1994-07-05 2006-07-26             NaN        Sergeant
# 1  Native American 1991-09-24 2010-07-22             NaN  Patrol Officer
# 2  Native American 2010-08-02        NaT       Full Time        Sergeant
#
#   employment_status                      agency_name             agency_type  \
# 0       Termination           Zuni Police Department  Law Enforcement Agency
# 1          Resigned   Ramah-Navajo Police Department  Law Enforcement Agency
# 2            Active  Isleta Tribal Police Department  Law Enforcement Agency
#
#    number_of_depts  number_of_unique_depts
# 0                3                       3
# 1                3                       3
# 2                3                       3
# TERMINATION INDEX:  Index([0], dtype='int64')
# CURRENT TERM SPOT:  0
# OFFICER START DATE AT NEXT PLACE IS BEFORE END DATE AT TERMINATED PLACE

# %%
nm_depts_after_term[1]
# Out:
# defaultdict(list,
#             {'Espanola Police Department': ['00-0022-P',
#               '02-0040-P',
#               '04-0050-P',
#               '08-0289-P',
#               '08-0335-P',
#               '11-0092-P',
#               '11-0141-P',
#               '14-0062-P',
#               '18-0358-P',
#               '20-0298-P',
#               '86-0161-P'],
#              'Milan Police Department': ['00-0046-P',
#               '03-0044--P',
#               '05-0157-P',
#               '14-0046-P',
#               '14-0186-P'],
#              'Gallup Police Department': ['00-0046-P'],
#              "Curry County Sheriff'S Office": ['00-0057-P'],
#              'Roswell Police Department': ['00-0079-P',
#               '03-0160-P',
#               '19-0238-P',
#               '79-0326-P',
#               '86-0124-P'],
#              'Portales Police Department': ['00-0079-P', '84-0156-P'],
#              'Fort Sumner Police Department': ['00-0080-P', '96-0039-P'],
#              'Grants Police Department': ['00-0107-P', '06-0015-P'],
#              'Albuquerque Police Department': ['00-0127-P',
#               '05-0013-P',
#               '79-0138-P',
#               '95-0331-P'],
#              'Sunland Park Police Department': ['00-0198-P',
#               '03-0098-P',
#               '03-0191-P',
#               '06-0121-P',
#               '06-0158-P',
#               '08-0022-P',
#               '09-0044-P',
#               '12-0241-P',
#               '15-0039-P',
#               '87-0279-P',
#               '98-0293-P',
#               '98-0317-P'],
#              'Dexter Department Of Public Safety': ['00-0222-P',
#               '01-0310-P',
#               '04-0284-P',
#               '09-0080-P'],
#              "Rio Arriba County Sheriff'S Office": ['00-0286-P',
#               '07-0210-P',
#               '09-0283-P',
#               '12-0296-P',
#               '12-0315-P',
#               '13-0062-P',
#               '14-0006-P',
#               '87-0331-P',
#               '89-0076-P',
#               '90-0053-P',
#               '97-0262-P',
#               '97-0312-P',
#               '98-0187-P'],
#              'Las Cruces Police Department': ['00-0310-P'],
#              'Los Lunas Police Department': ['00-0374-P', '11-0288-P'],
#              "Bernalillo County Sheriff'S Office": ['01-0016-P',
#               '13-0070-P',
#               '95-0327-P'],
#              'Clayton Police Department': ['01-0060-P',
#               '07-0218-P',
#               '10-0121-P',
#               '12-0278-P',
#               '14-0060-P'],
#              "District Attorney'S Office, 13Th District": ['01-0069-P'],
#              'New Mexico State Police': ['01-0070-P',
#               '03-0302-P',
#               '08-0005-P',
#               '08-0094-P',
#               '12-0150-P',
#               '14-0359-P',
#               '15-0428-P',
#               '80-0091-P',
#               '81-0076-P'],
#              'Aztec Police Department': ['01-0109-P', '84-0070-P'],
#              'Cuba Police Department': ['01-0117-P',
#               '09-0283-P',
#               '12-0296-P',
#               '13-0158-P',
#               '14-0198-P',
#               '15-0203-p',
#               '16-0327-P',
#               '91-0253-P'],
#              "Mckinley County Sheriff'S Office": ['01-0183-P', '01-0353-P'],
#              'New Mexico Highlands University Police Department': ['01-0206-P'],
#              "Otero County Sheriff'S Office": ['01-0207-P',
#               '03-0106-P',
#               '06-0263-P',
#               '08-0029-P'],
#              'Pueblo Of Laguna Police Department': ['01-0263-P',
#               '15-0382-P',
#               '94-0193-P'],
#              'Corrales Police Department': ['01-0270-P',
#               '03-0157-P',
#               '06-0307-P',
#               '13-0107-P',
#               '15-0426-P',
#               '91-0253-P',
#               '98-0285-P'],
#              'Tatum Police Department': ['01-0281-P',
#               '13-0251-P',
#               '18-0317-P'],
#              'Belen Police Department': ['01-0281-P',
#               '08-0047-P',
#               '89-0115-P',
#               '96-0256-P'],
#              'Eunice Police Department': ['01-0300-P',
#               '12-0332-P',
#               '13-0324-P',
#               '14-0046-P',
#               '86-0124-P'],
#              'Loving Police Department': ['01-0310-P'],
#              'Acoma Police Department': ['01-0353-P',
#               '06-0176-P',
#               '13-0090-P',
#               '19-0048-P'],
#              'New Mexico Gaming Control Board/Isd': ['01-0403-P'],
#              'Santa Rosa Police Department': ['02-0076-P',
#               '13-0057-P',
#               '21-0128-P'],
#              'University Of New Mexico Police Department': ['02-0093-P',
#               '13-0299-P',
#               '22-0169-P',
#               '95-0327-P',
#               '99-0016-P'],
#              'Pojoaque Tribal Police Department': ['02-0101-P', '08-0289-P'],
#              'Tesuque Tribal Police Department': ['02-0125-P',
#               '04-0050-P',
#               '20-0298-P',
#               '97-0270-P'],
#              'Truth Or Consequences Police Department': ['02-0165-P',
#               '14-0060-P',
#               '99-0226-P'],
#              'Albuquerque Public Schools Police Department': ['02-0165-P',
#               '11-0110-P',
#               '18-0281-P',
#               '19-0342-P',
#               '80-0100-P',
#               '88-0173-P',
#               '90-0019-P',
#               '97-0015-P'],
#              "De Baca County Sheriff'S Office": ['02-0178-P', '04-0255-P'],
#              'Mountainair Police Department': ['02-0181-P',
#               '85-0089-P',
#               '98-0152-P'],
#              'Bernalillo Police Department': ['03-0021-P',
#               '05-0061-P',
#               '18-0399-P',
#               '19-0348-P',
#               '20-0066-P',
#               '82-0114-P',
#               '93-0263-P',
#               '95-0351-P'],
#              "Sandoval County Sheriff'S Office": ['03-0063-P',
#               '06-0063-P',
#               '06-0234-P',
#               '09-0027-P',
#               '13-0063-P',
#               '15-0185-P',
#               '17-0307-P',
#               '17-0341-P'],
#              "Torrance County Sheriff'S Office": ['04-0003-P',
#               '18-0365-P',
#               '91-0253-P',
#               '92-0157-P',
#               '96-0307-P'],
#              'Zuni Police Department': ['04-0127-P', '98-0002-P'],
#              'Isleta Tribal Police Department': ['04-0214-P',
#               '14-0198-P',
#               '84-0207-P',
#               '95-0042-P'],
#              'Hatch Police Department': ['04-0224-P',
#               '07-0198-P',
#               '08-0022-P',
#               '89-0164-P'],
#              'Ruidoso Downs Police Department': ['04-0260-P', '08-0005-P'],
#              'Lovington Police Department': ['04-0273-P',
#               '12-0332-P',
#               '14-0050-P',
#               '14-0138-P',
#               '14-0140-P',
#               '16-0177-P',
#               '18-0311-P',
#               '20-0198-P',
#               '22-0187-P',
#               '99-0150-P'],
#              "Dona Ana County Sheriff'S Office": ['05-0182-P',
#               '06-0158-P',
#               '12-0224-P',
#               '16-0026-P',
#               '86-0300-P'],
#              'New Mexico Regulation And Licensing': ['05-0217-P'],
#              'Tucumcari Police Department': ['05-0228-P',
#               '10-0219-P',
#               '93-0102-P'],
#              'Bayard Police Department': ['05-0276-P'],
#              "Valencia County Sheriff'S Office": ['05-0287-P',
#               '16-0287-P',
#               '21-0036-P',
#               '85-0089-P'],
#              'Hobbs Police Department': ['06-0002-P'],
#              'Hagerman Department Of Public Safety': ['06-0037-P'],
#              'Bosque Farms Police Department': ['06-0114-P',
#               '10-0097-P',
#               '99-0125-P'],
#              'Insurance Fraud Bureau': ['06-0170-P'],
#              "Grant County Sheriff'S Office": ['06-0181-P',
#               '09-0251-P',
#               '17-0258-P',
#               '97-0225-P'],
#              'New Mexico Military Institute Police Dep': ['07-0002-P',
#               '85-0015-P'],
#              "Chaves County Sheriff'S Office": ['07-0140-P', '99-0151-P'],
#              "Mesilla Marshal'S Office": ['07-0194-P',
#               '08-0118-P',
#               '10-0002-P',
#               '11-0183-P',
#               '16-0017-P',
#               '19-0174-P',
#               '79-0012-P'],
#              "Lincoln County Sheriff'S Office": ['07-0220-P',
#               '09-0268-P',
#               '90-0287-P'],
#              'New Mexico Emnrd - State Parks': ['07-0257-P', '08-0136-P'],
#              'Cloudcroft Police Department': ['08-0014-P'],
#              'Santa Clara Police Department': ['08-0021-P',
#               '13-0200-P',
#               '90-0193-P'],
#              "Guadalupe County Sheriff'S Office": ['08-0274-P',
#               '11-0297-P',
#               '14-0070-P'],
#              'Santa Fe Police Department': ['08-0287-P',
#               '13-0321-P',
#               '18-0091-P',
#               '84-0056-P',
#               '85-0037-P',
#               '99-0125-P'],
#              'Santa Ana Tribal Police Department': ['08-0293-P', '84-0136-P'],
#              "Colfax County Sheriff'S Office": ['09-0013-P'],
#              'Alamogordo Police Department': ['09-0027-P', '17-0151-P'],
#              "Lea County Sheriff'S Office": ['09-0068-P', '94-0388-P'],
#              'Hurley Police Department': ['09-0227-P',
#               '12-0243-P',
#               '14-0060-P',
#               '90-0193-P',
#               '93-0245-P',
#               '96-0322-P'],
#              'Questa Police Department': ['09-0257-P'],
#              "District Attorney'S Office, 5Th District": ['09-0276-P'],
#              'Anthony Police Department': ['10-0005-P',
#               '11-0232-P',
#               '12-0236-P',
#               '16-0017-P',
#               '18-0052-P',
#               '18-0299-P',
#               '96-0048-P'],
#              'Sandia Pueblo Tribal Police Department': ['10-0064-P',
#               '14-0303-P',
#               '14-0338-P',
#               '16-0126-P',
#               '17-0245-P'],
#              'Las Vegas Police Department': ['10-0136-P', '13-0349-P'],
#              'Tularosa Police Department': ['10-0136-P',
#               '13-0161-P',
#               '15-0054-P'],
#              'Ramah-Navajo Police Department': ['11-0164-P', '16-0294-P'],
#              'Deming Police Department': ['11-0193-P', '85-0037-P'],
#              'Silver City Police Department': ['11-0243-P'],
#              "Eddy County Sheriff'S Office": ['11-0309-P',
#               '16-0331-P',
#               '18-0314-P',
#               '97-0228-P'],
#              "Santa Fe County Sheriff'S Office": ['12-0016-P',
#               '12-0097-P',
#               '14-0207-P',
#               '14-0375-P',
#               '14-0395-P',
#               '82-0041-P',
#               '84-0059-P',
#               '87-0098-P',
#               '90-0136-P'],
#              'Jemez Pueblo Police Department': ['12-0069-P', '97-0094-P'],
#              "Magdalena Marshal'S Office": ['12-0109-P', '14-0220-P'],
#              "San Miguel County Sheriff'S Office": ['12-0284-P'],
#              'Jicarilla Apache Tribal Police Department': ['12-0315-P'],
#              'Artesia Police Department': ['14-0271-P',
#               '21-0184-P',
#               '79-0041-P'],
#              'Rio Rancho Police Department': ['14-0347-P'],
#              'Bloomfield Police Department': ['14-0376-P', '15-0100-P'],
#              'Carrizozo Police Department': ['15-0027-P'],
#              'Edgewood Police Department': ['15-0282-p'],
#              'Western New Mexico University Police Department': ['16-0245-P',
#               '94-0024-P',
#               '95-0150-P'],
#              'Jemez Springs Police Department': ['17-0144-P',
#               '17-0145-P',
#               '82-0029-P',
#               '93-0215-P'],
#              'Estancia Police Department': ['17-0169-P'],
#              'Carlsbad Police Department': ['17-0298-P'],
#              'Jal Police Department': ['18-0310-P'],
#              "Hidalgo County Sheriff'S Office": ['19-0033-P', '20-0191-P'],
#              'Farmington Police Department': ['21-0225-P'],
#              "Luna County Sheriff'S Office": ['21-0290-P',
#               '96-0048-P',
#               '96-0108-P'],
#              'Taos Pueblo Police Department': ['22-0072-P', '89-0076-P'],
#              'New Mexico Livestock Board Inspec. Div': ['22-0193-P'],
#              'Bia-Oles District Iv Command Staff': ['79-0126-P'],
#              'Department Of Public Safety': ['82-0084-P'],
#              'Raton Police Department': ['82-0097-P'],
#              'Ohkay Owingeh Tribal Police Department': ['82-0311-P'],
#              "Socorro County Sheriff'S Office": ['86-0282-P'],
#              'Texico Police Department': ['86-0323-P'],
#              'Jicarilla Natural Resources': ['87-0087-P', '96-0113-P'],
#              'New Mexico Law Enforcement Academy': ['87-0266-P'],
#              'Albuquerque Aviation Communications': ['91-0253-P'],
#              'Chama Police Department': ['93-0029-P'],
#              "Taos County Sheriff'S Office": ['93-0215-P', '97-0132-P'],
#              'Moriarty Police Department': ['94-0296-P', '97-0120-P'],
#              'San Juan County Criminal Justice Training Authority': ['96-0019-P'],
#              'Ruidoso Police Department': ['96-0032-P'],
#              'Grant County Regional Dispatch': ['96-0322-P'],
#              'Taos Police Department': ['98-0132-P']})

# %%
rio_arriba_ids = ['00-0286-P',
              '07-0210-P',
              '09-0283-P',
              '12-0296-P',
              '12-0315-P',
              '13-0062-P',
              '14-0006-P',
              '87-0331-P',
              '89-0076-P',
              '90-0053-P',
              '97-0262-P',
              '97-0312-P',
              '98-0187-P']

# %%
rio_arriba_county = new_mexico_sorted.loc[new_mexico_sorted['person_nbr'].isin(rio_arriba_ids)].copy()

# %%
rio_arriba_county.to_excel('rio_arriba_county_sheriff_officers.xlsx', index=False)

# %%
sunland_park_ids = ['00-0198-P',
              '03-0098-P',
              '03-0191-P',
              '06-0121-P',
              '06-0158-P',
              '08-0022-P',
              '09-0044-P',
              '12-0241-P',
              '15-0039-P',
              '87-0279-P',
              '98-0293-P',
              '98-0317-P']

# %%
sunland_park = new_mexico_sorted.loc[new_mexico_sorted['person_nbr'].isin(sunland_park_ids)].copy()

# %%
sunland_park.to_excel('sunland_park_police_dept_officers.xlsx', index=False)

# %% [markdown]
# ## END OF THAT TESTING

# %%
active_new_mexico = get_active_officers(df=new_mexico, id_column='person_nbr', status_column='employment_status', active_word='Active')

# %%
# get active officers who have been at 3+ departments
nm_active_3plus = active_new_mexico.loc[active_new_mexico['number_of_unique_depts'] >= 3].copy()
nm_active_3plus['person_nbr'].nunique()
# Out:
# 811

# %%
# get active officers who have been at 5+ departments
nm_active_5plus = active_new_mexico.loc[active_new_mexico['number_of_unique_depts'] >= 5].copy()
nm_active_5plus['person_nbr'].nunique()
# Out:
# 150

# %%
active_new_mexico["person_nbr"].nunique()
# Out:
# 5185

# %% [markdown]
# There are 5185 unique currently active officers. There are 811 officers who have had 3+ unique employers. There are 150 officers who have been at 5+ departments

# %%
# seeing what are the value counts of employment_status
active_new_mexico.value_counts("employment_status")
# Out:
# employment_status
# Active           5291
# Resigned         2816
# Termination       282
# Retired           230
# Transferred        39
# Medical Leave       1
# Name: count, dtype: int64

# %%
terminated_active_new_mexico = get_terminated_active(active_df=active_new_mexico, id_column='person_nbr', status_column='employment_status', term_word='Termination')
terminated_active_new_mexico["person_nbr"].nunique()
# Out:
# 252

# %% [markdown]
# Out of the currently active officers, there are 252 officers who have been terminated from a previous department

# %% [markdown]
# ***

# %% [markdown]
# ### **North Carolina Analysis**

# %%
north_carolina = pd.read_csv('../npi_lookup/national-post-db/nc/input/north-carolina-processed.csv')

# %% [markdown]
# #### seeing how far back the data goes

# %%
north_carolina.sort_values(by='start_date').head(10)
# Out:
#         start_date    end_date        uid  \
# 88044   1900-01-01  2020-06-30  2831-2787
# 8325    1900-01-01  2002-12-31  6799-8742
# 97845   1900-01-01  2019-09-20  0056-7322
# 23250   1900-04-28  2017-02-21  0021-7413
# 109904  1911-11-11  1911-11-11  4109-3874
# 74545   1935-12-28  1979-05-25  6581-0826
# 115197  1966-11-01  1966-11-01  6350-9772
# 548     1970-12-02  1992-08-01  4309-9016
# 46834   1970-12-07  1995-12-18  6999-3201
# 78439   1970-12-07  1983-08-31  1010-2855
#
#                                               agency_name            rank  \
# 88044   Buncombe County Sheriff's Office - Deputy Sheriff  Deputy Sheriff
# 8325        Hoke County Sheriff's Office - Deputy Sheriff             NaN
# 97845   Siler City Police Department - Law Enforcement...             NaN
# 23250      Moore County Sheriff's Office - Deputy Sheriff  Deputy Sheriff
# 109904  Carteret County Sheriff's Office - Deputy Sheriff             NaN
# 74545   Union County Sheriff's Office - Law Enforcemen...             NaN
# 115197  Johnston County Sheriff's Office - Deputy Sheriff             NaN
# 548        Union County Sheriff's Office - Deputy Sheriff             NaN
# 46834   Buncombe County Sheriff's Office - Deputy Sheriff             NaN
# 78439   Buncombe County Sheriff's Office - Law Enforce...             NaN
#
#          first_name middle_name  last_name suffix
# 88044   christopher        hall     potter    NaN
# 8325       lorraine      judson      berry    NaN
# 97845          john       david  seagroves    NaN
# 23250          john      andrew     conway    NaN
# 109904        laura        dawn   thompson    NaN
# 74545           roy           b     medlin    NaN
# 115197       worley       aaron    watkins    NaN
# 548            hugh      martin     adcock    NaN
# 46834         frank       lewis     harris    NaN
# 78439        thomas    harrison  morrissey    NaN

# %%
north_carolina.columns
# Out:
# Index(['start_date', 'end_date', 'uid', 'agency_name', 'rank', 'first_name',
#        'middle_name', 'last_name', 'suffix'],
#       dtype='object')

# %% [markdown]
# #### how many currently-active officers have had 3+ emplyers? 5+? More?

# %%
get_dept_counts(df=north_carolina, id_column='uid', agency_column='agency_name')

# %%
north_carolina.head()
# Out:
#    start_date    end_date        uid  \
# 0  1999-12-01         NaN  0012-1559
# 1  1979-11-02  2005-05-01  0012-1548
# 2  2001-04-12         NaN  0012-1548
# 3  2011-05-17  2012-06-28  0012-1548
# 4  2019-12-19         NaN  2944-5526
#
#                                          agency_name                   rank  \
# 0  Asheville Police Department - Law Enforcement ...             Lieutenant
# 1  Asheville Police Department - Law Enforcement ...         Deputy Sheriff
# 2  Buncombe County Sheriff's Office - Deputy Sheriff         Deputy Sheriff
# 3  Marion Police Department - Law Enforcement Off...         Deputy Sheriff
# 4     Butner Public Safety - Law Enforcement Officer  Public Safety Officer
#
#   first_name middle_name last_name suffix  number_of_depts  \
# 0       sean      thomas   aardema    NaN                1
# 1     thomas   frederick   aardema    NaN                3
# 2     thomas   frederick   aardema    NaN                3
# 3     thomas   frederick   aardema    NaN                3
# 4     justin       wayne     aaron    NaN                1
#
#    number_of_unique_depts
# 0                       1
# 1                       3
# 2                       3
# 3                       3
# 4                       1

# %% [markdown]
# we cant get the number of active officers in the same way that we did for new mexico, since there's not status column.
# instead, will use when end_date is empty, because that implies officer is still working there.

# %%
def get_active_nc():
    # clean up the end_date column before using it
    north_carolina['end_date'] = north_carolina['end_date'].fillna('None')
    north_carolina['start_date'] = north_carolina['start_date'].fillna('None')

    # now will do similar stuff as with new mexico but using None value rather than Active in status one
    active_full_hist = pd.DataFrame()
    # making dataframe that only has officers who have 'None' in at least one of their end dates
    active_only = north_carolina.loc[(north_carolina['end_date'] == 'None') & (north_carolina['start_date'] != 'None')].copy()
    active_ids = active_only['uid'].unique()
    # looping thru list of active ids and getting full employment history of those officers
    for active in active_ids:
        temp_df = north_carolina.loc[north_carolina['uid'] == active].copy().sort_values(by='start_date')
        active_full_hist = pd.concat([active_full_hist, temp_df])
    return active_full_hist

# %%
active_north_carolina = get_active_nc()

# %%
# get active officers who have been at 3+ departments
nc_active_3plus = active_north_carolina.loc[active_north_carolina['number_of_unique_depts'] >= 3].copy()
nc_active_3plus['uid'].nunique()
# Out:
# 6630

# %%
# get active officers who have been at 5+ departments
nc_active_5plus = active_north_carolina.loc[active_north_carolina['number_of_unique_depts'] >= 5].copy()
nc_active_5plus['uid'].nunique()
# Out:
# 1151

# %%
active_north_carolina['uid'].nunique()
# Out:
# 34325

# %% [markdown]
# There are 34326 unique currently active officers. Out of these, there are 6631 officers who have had 3+ unique employers, and 1151 who have had 5+.

# %% [markdown]
# ***

# %% [markdown]
# ### **Minnesota Analysis**

# %%
minnesota = pd.read_csv('../npi_lookup/national-post-db/mn/input/minnesota_index.csv')

# %% [markdown]
# #### seeing how far back the data goes

# %%
minnesota.sort_values(by='start_date').head(20)
# Out:
#        Unnamed: 0    uid  last_name first_name middle_name  \
# 45282       68816  83283       Long     Dennis     Orville
# 46711       71164  84433      Neist     Leslie      Brooke
# 40222       60593   4380   Franklin      James    De Wayne
# 39528       59404   3296     Bailey      Larry      Robert
# 39530       59407   3297    Brotzel     Robert      Joseph
# 7777        11309   1364  Maslowski      Scott        Alan
# 41577       62923   6175     Fossen       Ivan        Owen
# 42063       63698   6616   Mc Kenna      Kevin        Paul
# 42062       63696   6615    Johnson      Roger       Keith
# 42060       63692   6613   Erspamer     Robert      Thomas
# 41984       63579   6569      Reedy   Lawrence      August
# 41982       63575   6567  Schwegman    Randall      Joseph
# 42059       63690   6611   Serfling      Leigh       Allen
# 42356       64145   6804  Van Slyke       John      Thomas
# 42057       63686   6608   Thompson      Corey    Clarence
# 42056       63684   6607  Robertson       Kimo        Roth
# 41983       63577   6568    Nielsen      Wayne       Peter
# 41979       63570   6563   Linneman     Joseph        Glen
# 41981       63573   6565    Gabriel     Thomas       Obert
# 42050       63673   6602   Schrader    Michael      Arthur
#
#                                   agency_name      status start_date  \
# 45282             Hendricks Police Department  Terminated   1/1/1900
# 46711                 Adams Police Department  Terminated   1/1/1900
# 40222  West Hennepin Public Safety Department  Terminated   1/1/1976
# 39528  West Hennepin Public Safety Department  Terminated   1/1/1979
# 39530  West Hennepin Public Safety Department  Terminated   1/1/1979
# 7777      Thief River Falls Police Department  Terminated   1/1/1979
# 41577              Glenwood Police Department  Terminated   1/1/1979
# 42063                Duluth Police Department  Terminated   1/1/1980
# 42062             Faribault Police Department  Terminated   1/1/1980
# 42060                Duluth Police Department  Terminated   1/1/1980
# 41984                   Ely Police Department  Terminated   1/1/1980
# 41982             Chisago Co. Sheriffs Office  Terminated   1/1/1980
# 42059          Grand Rapids Police Department  Terminated   1/1/1980
# 42356            Hennepin Co. Sheriffs Office  Terminated   1/1/1980
# 42057            Hennepin Co. Sheriffs Office  Terminated   1/1/1980
# 42056            Hennepin Co. Sheriffs Office  Terminated   1/1/1980
# 41983              Ramsey Co. Sheriffs Office  Terminated   1/1/1980
# 41979                Lake Co. Sheriffs Office  Terminated   1/1/1980
# 41981              Ramsey Co. Sheriffs Office  Terminated   1/1/1980
# 42050                 Eagan Police Department  Terminated   1/1/1980
#
#       agency_status    end_date
# 45282        Former    7/1/1993
# 46711        Former   10/1/2011
# 40222        Former   2/28/1991
# 39528        Former  12/31/2000
# 39530        Former   2/27/1984
# 7777         Former    4/1/1998
# 41577        Former   5/27/2000
# 42063        Former  12/31/2002
# 42062        Former    5/6/2005
# 42060        Former   7/30/2005
# 41984        Former   6/27/2005
# 41982        Former    1/6/2003
# 42059        Former   1/29/2010
# 42356        Former   8/22/2003
# 42057        Former   5/31/2002
# 42056        Former   5/31/2002
# 41983        Former   10/1/1999
# 41979        Former    1/7/2008
# 41981        Former   5/31/2000
# 42050        Former  10/31/2006

# %% [markdown]
# #### getting active officers

# %%
get_dept_counts(df=minnesota, id_column='uid', agency_column='agency_name')

# %%
minnesota.shape
# Out:
# (49509, 12)

# %%
minnesota.columns
# Out:
# Index(['Unnamed: 0', 'uid', 'last_name', 'first_name', 'middle_name',
#        'agency_name', 'status', 'start_date', 'agency_status', 'end_date',
#        'number_of_depts', 'number_of_unique_depts'],
#       dtype='object')

# %%
minnesota.head()
# Out:
#    Unnamed: 0  uid last_name first_name middle_name  \
# 0           1    1  Andersen     Steven       Peder
# 1           2    1  Andersen     Steven       Peder
# 2           3    1  Andersen     Steven       Peder
# 3           4    1  Andersen     Steven       Peder
# 4           6   10      Dahl       Gary   Frederick
#
#                             agency_name      status start_date agency_status  \
# 0            Verndale Police Department  Terminated  7/15/1973        Former
# 1          Beltrami Co. Sheriffs Office  Terminated   5/1/1994        Former
# 2  DPS, Bureau Of Criminal Apprehension  Terminated   7/1/1978        Former
# 3             Menahga Police Department  Terminated  4/15/1994        Former
# 4  DPS, Bureau Of Criminal Apprehension  Terminated   7/1/1978        Former
#
#     end_date  number_of_depts  number_of_unique_depts
# 0  4/16/1996                4                       4
# 1  4/27/2007                4                       4
# 2   1/1/1980                4                       4
# 3   3/1/1995                4                       4
# 4  6/30/1998                1                       1

# %%
active_minnesota = get_active_officers(df=minnesota, id_column='uid', status_column='status', active_word='Active')

# %%
active_minnesota.head()
# Out:
#     Unnamed: 0    uid  last_name first_name middle_name  \
# 60          95  10055   Denneson    Richard       James
# 62          99  10058     Reller    Richard     Herbert
# 63         100  10058     Reller    Richard     Herbert
# 64         101  10058     Reller    Richard     Herbert
# 97         155  10080  Cleveland       Kent        Alan
#
#                                      agency_name      status  start_date  \
# 60        West Hennepin Public Safety Department      Active  10/17/1988
# 62  Three Rivers Park District Police Department  Terminated  10/24/1988
# 63               Department Of Natural Resources  Terminated    3/2/1999
# 64                    Wright Co. Sheriffs Office      Active    4/7/2021
# 97                  Hennepin Co. Sheriffs Office  Terminated  10/31/1988
#
#    agency_status    end_date  number_of_depts  number_of_unique_depts
# 60       Primary         NaN                1                       1
# 62        Former   12/7/1998                3                       3
# 63        Former    3/3/2021                3                       3
# 64       Primary         NaN                3                       3
# 97        Former  10/27/1989                6                       6

# %%
# get active officers who have been at 3+ departments
mn_active_3plus = active_minnesota.loc[active_minnesota['number_of_unique_depts'] >= 3].copy()
mn_active_3plus['uid'].nunique()
# Out:
# 2154

# %%
# get active officers who have been at 5+ departments
mn_active_5plus = active_minnesota.loc[active_minnesota['number_of_unique_depts'] >= 5].copy()
mn_active_5plus['uid'].nunique()
# Out:
# 415

# %%
active_minnesota['uid'].nunique()
# Out:
# 10683

# %% [markdown]
# ***

# %% [markdown]
# ### **Indiana Analysis**

# %%
indiana = pd.read_csv('../npi_lookup/national-post-db/in/output/indiana_index.csv')

# %%
indiana.shape
# Out:
# (68247, 11)

# %%
indiana.sort_values(by='start_date').head(250)
# Out:
#       person_nbr                                        agency_name  \
# 533    3079-1089               Randolph County Sheriff's Department
# 55     9261-6819                  Grant County Sheriff's Department
# 80     4612-5103                   Rush County Sheriff's Department
# 17315  2964-5645                 Marion County Sheriff's Department
# 37104  2706-2578                  Indiana Department of Corrections
# 44340  4759-7476                  White County Sheriff's Department
# 43235  6015-9855                     Warren County Sheriff's Office
# 51390  6048-9612                    Columbia City Police Department
# 31706  7319-1016                 Greene County Sheriff's Department
# 33193  2605-2036                 DeKalb County Sheriff's Department
# 42806  3043-9904              Anderson University Police Department
# 60366  1208-8781                           Avilla Police Department
# 7945   1471-4106                   Vigo County Sheriff's Department
# 16131  1025-4769                        Edinburgh Police Department
# 11511  6742-5690                 DeKalb County Sheriff's Department
# 51576  7846-3587                         Anderson Police Department
# 37464  8226-7431                     Kendallville Police Department
# 25746  2858-1873                         Anderson Police Department
# 31860  6479-1262                          Milford Police Department
# 17056  4737-1884            Vanderburgh County Sheriff's Department
# 2792   4749-1504                 Fulton County Sheriff's Department
# 26613  2368-4522        Indianapolis Metropolitan Police Department
# 58141  3272-1479                        Whiteland Police Department
# 14985  7500-3289        Indianapolis Metropolitan Police Department
# 31501  3748-0443            Notre Dame University Police Department
# 66783  3263-0669        Community Health  Network Police Department
# 53865  8227-4193                          Decatur Police Department
# 28535  8102-5754                 Porter County Sheriff's Department
# 12048  1670-1743                  Clark County Sheriff's Department
# 6157   6608-5233                         Columbus Police Department
# 22890  7482-8817                       DNR Law Enforcement Division
# 29556  4835-2003                             Gary Police Department
# 27185  6185-1036                         Anderson Police Department
# 14483  1637-8903        Indianapolis Metropolitan Police Department
# 48204  7234-5302                       Evansville Police Department
# 24768  9126-6976                 Marion County Sheriff's Department
# 6618   4375-7350                             Peru Police Department
# 42524  4641-6745               Indiana University Police Department
# 27078  2021-6686                     Kendallville Police Department
# 56380  3841-4614                     Burns Harbor Police Department
# 53953  7707-2175                         Speedway Police Department
# 30690  2729-1199                     Connersville Police Department
# 40992  2805-6153                          Munster Police Department
# 48432  3728-3542                       Fort Wayne Police Department
# 32619  7665-9838                       Evansville Police Department
# 19365  8425-4894        Indianapolis Metropolitan Police Department
# 51040  5439-1424                             Gary Police Department
# 14678  6842-2026                   Lake County Sheriff's Department
# 36958  6998-4334        Indianapolis Metropolitan Police Department
# 30991  4221-5021                       Greenfield Police Department
# 4652   5532-2528         Spencer County Sheriff's Department (1345)
# 23630  8552-5464                          Oolitic Police Department
# 25521  2642-4690                  Parke County Sheriff's Department
# 18990  8624-8015                 Howard County Sheriff's Department
# 15459  1552-7847                       South Bend Police Department
# 32976  4972-3257                       Fort Wayne Police Department
# 30341  4884-1651                 Marion County Sheriff's Department
# 33226  4406-6195        Indianapolis Metropolitan Police Department
# 17390  4100-7940                        Fortville Police Department
# 40950  4461-5317               Indiana University Police Department
# 44645  1523-9616  St. Joseph Co. Airport Authority Police Depart...
# 11595  5515-2775                       South Bend Police Department
# 40834  6620-2461                          Conrail Police Department
# 14839  2186-8905        Indianapolis Metropolitan Police Department
# 16731  9808-3111        Indianapolis Metropolitan Police Department
# 15472  8519-5535                       DNR Law Enforcement Division
# 12041  4919-3877        Indianapolis Metropolitan Police Department
# 15194  6390-8777                       New Castle Police Department
# 30480  2990-0675            Bartholomew County Sheriff's Department
# 51278  2437-7558                       Evansville Police Department
# 33147  2234-7452                        Greenwood Police Department
# 36483  6888-2236               Indiana University Police Department
# 30297  6802-2118              Tippecanoe County Prosecutor's Office
# 37123  8989-1575                 Tipton County Sheriff's Department
# 6363   5226-5383                           Hobart Police Department
# 41881  8927-2925        Indianapolis Metropolitan Police Department
# 25879  1110-7102                St. Joseph County Police Department
# 8236   7356-3809                       Logansport Police Department
# 27693  6005-6861            Valparaiso University Police Department
# 15398  8618-7856                       Fort Wayne Police Department
# 8021   1983-3421        Indianapolis Metropolitan Police Department
# 19508  6081-7059               Indiana University Police Department
# 41571  2463-4980                Hancock County Sheriff's Department
# 41443  4441-2188                  Wayne County Sheriff's Department
# 19238  6424-4586                       Zionsville Police Department
# 49630  7140-0433                LaPorte County Sheriff's Department
# 20297  9400-2567                 Marion County Sheriff's Department
# 21855  7313-8432                             Gary Police Department
# 42271  5346-9474                 Monroe County Sheriff's Department
# 48865  8151-2627                         Anderson Police Department
# 45122  5188-7077                       South Bend Police Department
# 166    6428-5573        Indianapolis Metropolitan Police Department
# 56522  2591-2775        Indianapolis Metropolitan Police Department
# 15585  6510-0336                  Adams County Sheriff's Department
# 61071  6046-2494               Randolph County Sheriff's Department
# 21780  9735-9091                      Bloomington Police Department
# 45471  3348-8425                       Evansville Police Department
# 5561   3982-9619               Marshall County Sheriff's Department
# 714    2113-8094                 Shelby County Sheriff's Department
# 2259   3674-8327                Johnson County Sheriff's Department
# 45510  3911-5482                 Porter County Sheriff's Department
# 33163  6391-4494                 Howard County Sheriff's Department
# 32869  4061-8645                 Marion County Sheriff's Department
# 40679  3615-9882                 Ripley County Sheriff's Department
# 25974  2116-2861                 Starke County Sheriff's Department
# 2683   8744-7879                 Putnam County Sheriff's Department
# 21265  8915-2701        Indianapolis Metropolitan Police Department
# 1971   8438-2856                     Connersville Police Department
# 36193  6739-6877                             Gary Police Department
# 43127  5660-2876                        New Haven Police Department
# 16902  4650-5925        Indianapolis Metropolitan Police Department
# 40504  8230-2703                 Starke County Sheriff's Department
# 53463  6016-7959                       Chesterton Police Department
# 38653  5444-7576                       Chesterton Police Department
# 39599  2856-7987                          Atlanta Police Department
# 6965   6507-4417                   Cass County Sheriff's Department
# 5059   1962-7393                      Terre Haute Police Department
# 59016  2618-6309                LaPorte County Sheriff's Department
# 49414  3472-0981                          Bourbon Police Department
# 2436   7193-2313                           Carmel Police Department
# 20796  5734-2838        Indianapolis Metropolitan Police Department
# 52017  2577-8015        Indianapolis Metropolitan Police Department
# 7652   3295-6841                        Frankfort Police Department
# 34146  4401-6508                       South Bend Police Department
# 22204  6940-7798                  Allen County Sheriff's Department
# 22474  3018-1899        Indianapolis Metropolitan Police Department
# 43258  7732-1248        Indianapolis Metropolitan Police Department
# 44656  5580-1849        Indianapolis Metropolitan Police Department
# 9155   5820-5579                  Allen County Sheriff's Department
# 10116  5529-2351                  Adams County Sheriff's Department
# 50621  4803-1069                       South Bend Police Department
# 4969   9068-5160                         Richmond Police Department
# 48209  9299-6258                LaPorte County Sheriff's Department
# 36659  4205-3901                          Gosport Police Department
# 49923  7919-9052                       Brookville Police Department
# 47093  6372-2524               Indiana University Police Department
# 2985   1939-4121        Indianapolis Metropolitan Police Department
# 12386  3913-2566        Indianapolis Metropolitan Police Department
# 40254  3229-2817        Indianapolis Metropolitan Police Department
# 60815  3229-2817        Indianapolis Metropolitan Police Department
# 11025  5315-2440                        Indiana State Excise Police
# 31713  9593-4635                       South Bend Police Department
# 37837  6568-4515                LaPorte County Sheriff's Department
# 23709  8457-8588                      Beech Grove Police Department
# 48309  4570-0571             Huntington County Sheriff's Department
# 55636  6224-1865        Indianapolis Metropolitan Police Department
# 35670  2191-6185                  Noble County Sheriff's Department
# 16441  6224-1865                 Marion County Sheriff's Department
# 8968   1186-8932                 Marion County Sheriff's Department
# 56129  7178-1797        Indianapolis Metropolitan Police Department
# 51258  4927-4202                  Brown County Sheriff's Department
# 43578  5266-1174                      Indiana Department of Revenue
# 42495  4553-3116        Indianapolis Metropolitan Police Department
# 9466   9909-4523                 Marion County Sheriff's Department
# 18704  8853-3376               Indiana University Police Department
# 587    4511-6348                       South Bend Police Department
# 3261   4902-4301                       South Bend Police Department
# 49605  7911-8415                       DNR Law Enforcement Division
# 51410  6323-9158                 Marion County Sheriff's Department
# 21212  7791-2430                     Lawrenceburg Police Department
# 50982  9774-8682                 Jasper County Sheriff's Department
# 12853  2380-0867                      Bloomington Police Department
# 14054  2953-4526                          Elkhart Police Department
# 35893  2660-8243                          Elkhart Police Department
# 35372  6667-7603        Indianapolis Metropolitan Police Department
# 4929   1723-0521        Indianapolis Metropolitan Police Department
# 2300   8836-2962        Indianapolis Metropolitan Police Department
# 48937  5620-9641        Indianapolis Metropolitan Police Department
# 29507  4424-5088        Indianapolis Metropolitan Police Department
# 5030   3157-9241        Indianapolis Metropolitan Police Department
# 36894  9675-4611        Indianapolis Metropolitan Police Department
# 8945   7473-0343        Indianapolis Metropolitan Police Department
# 14209  9877-7972        Indianapolis Metropolitan Police Department
# 18505  6523-1836        Indianapolis Metropolitan Police Department
# 42456  5118-0009                      Bloomington Police Department
# 4927   8384-9180                             Gary Police Department
# 31541  2619-3555                       New Albany Police Department
# 830    2520-2936                      Parker City Police Department
# 23777  3933-6677                       Evansville Police Department
# 1706   7342-7674                           Carmel Police Department
# 39396  3696-7510                 Marion County Sheriff's Department
# 11238  2299-8914                 Shelby County Sheriff's Department
# 17398  7066-0269             Ft. Wayne Allen Co Airport Police Dept
# 1149   3929-1605                       Fort Wayne Police Department
# 68199  6601-9923                        Westville Police Department
# 45223  2489-7825                         Roseland Police Department
# 46169  9388-6291                           Muncie Police Department
# 40009  8419-3528        Indianapolis Metropolitan Police Department
# 10072  9148-1515                 Marion County Sheriff's Department
# 18884  1517-8468               Indiana University Police Department
# 41730  3368-1400                     Connersville Police Department
# 49063  3870-5494                   Jennings County Sheriff's Office
# 30187  8885-5438         Indiana State University Police Department
# 14464  2858-2204               Indiana University Police Department
# 14062  1759-9063                          LaPorte Police Department
# 9433   5624-0084             Tippecanoe County Sheriff's Department
# 31067  1341-6515               Indiana University Police Department
# 2669   2757-6869                Johnson County Sheriff's Department
# 10129  8079-5244                       Cumberland Police Department
# 44325  7725-6188                           Marion Police Department
# 15291  5321-5926                       Evansville Police Department
# 40820  8771-0662                       New Albany Police Department
# 28706  3911-4158               Indiana University Police Department
# 6855   3193-8196                        Rushville Police Department
# 29386  3081-0975        Indianapolis Metropolitan Police Department
# 31731  8371-8735                       New Albany Police Department
# 28820  7847-1503                       South Bend Police Department
# 27712  4206-6755                           Carmel Police Department
# 43479  4791-6576                    Michigan City Police Department
# 39270  9465-5283                 Howard County Sheriff's Department
# 3194   6118-5830               Indiana University Police Department
# 4660   4566-5217                 Marion County Sheriff's Department
# 41068  1804-2693                St. Joseph County Police Department
# 9725   5124-6581                     Connersville Police Department
# 58481  4122-3921                 Marion County Sheriff's Department
# 189    5517-1125  Purdue University West Lafayette Police Depart...
# 44235  3975-5486               Indiana University Police Department
# 17901  4136-9715   Indianapolis Airport Authority Police Department
# 770    2601-1976                           Marion Police Department
# 33497  2899-8249               Indiana University Police Department
# 32244  9986-1752                             Gary Police Department
# 20201  3644-2784                     Connersville Police Department
# 41251  4324-0085               Indiana University Police Department
# 18654  6408-8500                 Newton County Sheriff's Department
# 34914  4416-1917                 Marion County Sheriff's Department
# 50399  7931-6829                 Monroe County Sheriff's Department
# 29483  1099-8884             Tippecanoe County Sheriff's Department
# 1848   4506-2286                           Goshen Police Department
# 43691  6824-1394                          Portage Police Department
# 3833   6232-6675                       Valparaiso Police Department
# 24487  8030-8797        Indianapolis Metropolitan Police Department
# 46286  9872-6349        Indianapolis Metropolitan Police Department
# 54682  7759-4317        Indianapolis Metropolitan Police Department
# 48985  6951-6285        Indianapolis Metropolitan Police Department
# 10547  1987-9542        Indianapolis Metropolitan Police Department
# 4464   5873-7283        Indianapolis Metropolitan Police Department
# 46568  6185-0550        Indianapolis Metropolitan Police Department
# 8020   7753-1175        Indianapolis Metropolitan Police Department
# 25471  9866-8410                           Carmel Police Department
# 25056  3023-0006                   Knox County Sheriff's Department
# 14772  1457-0366         Indiana State University Police Department
# 37162  8899-3685              Hendricks County Sheriff's Department
# 16230  4414-6246                       Fort Wayne Police Department
# 12023  8114-2941                   Lake County Sheriff's Department
# 9404   1438-7770        Indianapolis Metropolitan Police Department
# 43134  3133-5111                           Linton Police Department
# 29463  5126-7616        Indianapolis Metropolitan Police Department
# 9925   3640-9159               Delaware County Sheriff's Department
# 15535  1256-3869                 Marion County Sheriff's Department
# 51536  3810-5535         Indiana State University Police Department
#
#           last_name        first_name  gender                    race  \
# 533       Alexander              Rick    Male                     NaN
# 55        Abernathy              Mary  Female                     NaN
# 80          Abraham                J.     NaN                     NaN
# 17315     Graffitti             Diane  Female                     NaN
# 37104     Purviance            Lester    Male                     NaN
# 44340     Stevenson              Luke    Male                     NaN
# 43235      Snedeker             Paula  Female                   White
# 51390        Wright              Nora  Female                   White
# 31706      Milligan             Logan  Female                   White
# 33193         Myers             Arien  Female                     NaN
# 42806         Smith            Walter    Male                   Other
# 60366     Rhinehart             Floyd    Male                     NaN
# 7945   Chickadaunce            Ronald    Male                     NaN
# 16131        Gaskin             Elvis    Male            Puerto Rican
# 11511        Dennis              John    Male                     NaN
# 51576        Yeskie              Mark    Male                     NaN
# 37464         Raney             Jerry    Male                     NaN
# 25746         Koons              Dale    Male                     NaN
# 31860        Miotto           Richard    Male                     NaN
# 17056         Gooch              Bart    Male                     NaN
# 2792         Beaird             Cyrus    Male                     NaN
# 26613        Lasley            Samuel    Male                     NaN
# 58141         Lucid           William    Male                   Other
# 14985     Forrester            Pamela    Male                     NaN
# 31501        Miller              Rick    Male                     NaN
# 66783     Christian             Steve    Male                     NaN
# 53865         Cloud           Michael    Male                     NaN
# 28535  Maglish-Love             Linda  Female                   Other
# 12048          Dodd            Lindon    Male                     NaN
# 6157       Burgdorf          Sterling    Male                     NaN
# 22890       Jackson             Jerry    Male                     NaN
# 29556         Mayes            Lucius    Male                     NaN
# 27185       Leonard            Edward    Male                     NaN
# 14483      Fishback            Joseph    Male                     NaN
# 48204        Walker             James    Male                     NaN
# 24768       Kennedy            Albert    Male                   White
# 6618          Butts           Jeffery    Male                     NaN
# 42524         Sloan             Frank    Male                     NaN
# 27078       Leighty               Dan    Male                     NaN
# 56380       Heckman           Michael    Male                   White
# 53953       Collins             Barry    Male                   White
# 30690       McQueen            George    Male                     NaN
# 40992    Schweitzer           Raymond    Male                     NaN
# 48432         Walsh           William    Male                     NaN
# 32619        Morris           Timothy    Male                     NaN
# 19365          Hart             David    Male                     NaN
# 51040          Wood             Brian  Female                     NaN
# 14678       Fleming             Keith    Male                     NaN
# 36958      Proffitt           Raymond    Male                     NaN
# 30991        Mercer            Clarke    Male                   White
# 4652         Bowman              Lisa  Female                     NaN
# 23630       Johnson              Troy    Male                     NaN
# 25521      Kneeland            Randel    Male                     NaN
# 18990      Hargrove           Gregory    Male                   White
# 15459        Friend            Edward    Male                     NaN
# 32976      Mungovan            Gerald    Male                     NaN
# 30341       McHenry             Julie  Female                   White
# 33226         Myers           William    Male                     NaN
# 17390         Grant           Michael    Male                     NaN
# 40950       Schutte            Robert    Male                   Other
# 44645   Stopczynski              Carl    Male                     NaN
# 11595         Deroo            Albert    Male                     NaN
# 40834  Schowengerdt              Fred    Male                   Other
# 14839         Foley            Edward    Male                     NaN
# 16731         Givan            Robert    Male                   Other
# 15472         Frink              Carl    Male                   White
# 12041          Dodd            Robert    Male                     NaN
# 15194         Frame          Lawrence    Male                   White
# 30480      McKinney            Jimmie    Male                   Other
# 51278   Worthington             Brett    Male                     NaN
# 33147         Myers              John    Male                     NaN
# 36483        Ponder             Julie  Female                   White
# 30297        McGrew            Denise  Female                   Other
# 37123          Pyke           Jeffrey    Male                     NaN
# 6363         Burris             Lance    Male                     NaN
# 41881      Shoemake             Roger    Male                     NaN
# 25879        Krause           Richard    Male                     NaN
# 8236          Clark           Michael    Male                     NaN
# 27693         Lloyd            Edward    Male                   Other
# 15398    Freiburger            Lorrie  Female                     NaN
# 8021         Christ             Louis    Male                     NaN
# 19508          Hash            Donald    Male                     NaN
# 41571          Shaw             Tracy     NaN                     NaN
# 41443       Shaffer             Anita  Female                   Other
# 19238        Harris            Gerald    Male                     NaN
# 49630         White           Bradley    Male                   Other
# 20297   Hendrickson            Robert    Male                   White
# 21855       Houston            Thomas    Male                     NaN
# 42271       Simpson             Jason    Male                   White
# 48865       Watters              Tony    Male                     NaN
# 45122          Suth           Michael    Male                     NaN
# 166           Adams            Wilbur    Male                   White
# 56522         Hiatt             Terry    Male                     NaN
# 15585      Fuhrmann           Kenneth    Male                     NaN
# 61071    Shaneyfelt           Charles    Male                   White
# 21780     Hostetler           Michael    Male                   Other
# 45471        Talsma             Brian    Male                     NaN
# 5561          Brown             James    Male                     NaN
# 714        Allender            Claude    Male                     NaN
# 2259         Barger               Joe    Male                   White
# 45510       Tapocsi             James    Male                   White
# 33163         Myers             Keith    Male                   White
# 32869      Mulinaro              John    Male                   Other
# 40679       Schmidt           Barbara  Female                     NaN
# 25974        Krulik             Frank    Male                     NaN
# 2683          Baugh             James    Male                   White
# 21265          Hoke            Robert    Male                   Other
# 1971          Baker             David    Male                   White
# 36193        Pineda               Ron    Male                     NaN
# 43127         Smith             David    Male                   White
# 16902          Goff           Kenneth    Male                     NaN
# 40504       Schacht            Donald    Male                     NaN
# 53463        Cairns           Michael    Male                   White
# 38653        Rinker           Charles    Male                     NaN
# 39599         Rouch            Gerald    Male                   White
# 6965       Campbell              Dale    Male                   White
# 5059    Brentlinger            Joseph    Male                     NaN
# 59016   Mollenhauer           Michael    Male                     NaN
# 49414          West              John    Male                   White
# 2436         Barney              Gary    Male                   White
# 20796     Highbaugh           Michael    Male                   Other
# 52017          Zunk           Michael    Male                   White
# 7652         Cesare           Michael    Male                     NaN
# 34146          Nybo            Ernest    Male                   White
# 22204        Hughes             Jerry    Male                   White
# 22474         Hurst             Larry    Male                     NaN
# 43258        Snider             Lantz    Male                     NaN
# 44656      Storkman            Thomas    Male                   White
# 9155           Cook              Alan    Male                     NaN
# 10116         Crone           William    Male                     NaN
# 50621        Wilson            Ronald    Male                   Other
# 4969        Bratton            Edward    Male                   Other
# 48209        Walker              Mike    Male  Black/African American
# 36659        powell            melvin    Male                   White
# 49923    Wietholter           Phillip    Male                   Other
# 47093        Turley            Willie    Male                   Other
# 2985            Bee            Donald    Male                   Other
# 12386         Drake            Samuel    Male                     NaN
# 40254       Sanders            Walter    Male                     NaN
# 60815       Sanders            Walter    Male                     NaN
# 11025         Davis  Patricia (Penny)  Female                   White
# 31713      Milliken           Kenneth    Male                     NaN
# 37837          Reed            Winroe    Male                   Other
# 23709       Johnson           Michael    Male                   White
# 48309          Wall             James    Male                     NaN
# 55636         Gibbs            Steven    Male                   White
# 35670         Perry              Milo     NaN                     NaN
# 16441         Gibbs            Steven    Male                   White
# 8968      Commiskey              Paul    Male                   Other
# 56129          Hann           Earnest    Male                     NaN
# 51258       Worland            Robert    Male                   White
# 43578        Sparks           Charles    Male                   White
# 42495       Slavens           Russell    Male                     NaN
# 9466      Cornelius            Ronald    Male                   Other
# 18704   Hammersmith           Richard    Male                   White
# 587           Allen             Terry    Male                   White
# 3261        Bennett             Larry    Male                   Other
# 49605      Whitaker              Gary    Male                     NaN
# 51410        Wright           Stanley    Male                     NaN
# 21212       Hoffman           William    Male                     NaN
# 50982         Wolfe              Gail  Female                     NaN
# 12853          Eads             Wayne    Male                   Other
# 14054          Faus           William    Male                   White
# 35893      Pflibsen              Dale    Male                     NaN
# 35372        Pearcy             Jerry    Male                   White
# 4929        Brannon            Joseph    Male                     NaN
# 2300         Barker             Jerry    Male                   White
# 48937        Weaver           Jeffrey    Male                   White
# 29507           May           Stephen    Male                     NaN
# 5030          Breen            Thomas    Male                     NaN
# 36894     Pridemore           Stephen    Male                     NaN
# 8945          Combs             Elmer    Male                     NaN
# 14209      Ferguson              John    Male                     NaN
# 18505          Hall             Terry    Male                     NaN
# 42456       Skirvin           Richard    Male                   Other
# 4927        Brannon         Nathaniel    Male  Black/African American
# 31541        Miller           Charles    Male                     NaN
# 830          Amburn               Rex    Male                     NaN
# 23777         Jolly           Michael    Male                     NaN
# 1706           Babb            Steven    Male                   Other
# 39396         Roney          Reginald    Male                     NaN
# 11238        Debaun            Thomas    Male                   White
# 17398         Grant              Gary    Male                   Other
# 1149        Anspach            Dennis    Male                     NaN
# 68199        Mercer             Darin    Male                   White
# 45223       Swanson            Dennis    Male                     NaN
# 46169        Thomas             James    Male                   Other
# 40009        Rynard           Kenneth    Male                   Other
# 10072       Crisler             David    Male                   White
# 18884        Hanson           Michael    Male                     NaN
# 41730        Sherck            Dennis    Male                   White
# 49063       Webster            Thomas    Male                   White
# 30187     McFarland              Jack    Male                   White
# 14464        Fiscus            Steven    Male                     NaN
# 14062         Favia             Brian    Male                   White
# 9433        Cordell            Daniel    Male                     NaN
# 31067     Messenger             David    Male                   Other
# 2669          Bauer             Scott    Male                     NaN
# 10129        Crooke           Michael    Male                   White
# 44325       Stevens           Michael    Male                   White
# 15291       Frasier            Joseph    Male                   White
# 40820        Schook             Laura  Female                   Other
# 28706        Manion           Michael    Male                     NaN
# 6855        Cameron             Floyd    Male                     NaN
# 29386      Matthews             Danny    Male                     NaN
# 31731         Mills           Michael    Male                   White
# 28820     Marciniak            Ronald    Male                     NaN
# 27712         Locke            Robert    Male                     NaN
# 43479          Sosa           Richard    Male                     NaN
# 39270        Rogers            Steven    Male                     NaN
# 3194         Benham              Carl    Male                   Other
# 4660         Bowman           Charles    Male                   White
# 41068         Scott              Fred    Male                   White
# 9725            Cox           William    Male                   Other
# 58481       McCarty             Tyler    Male                     NaN
# 189           Adams            Harold    Male                   Other
# 44235      Stephens             Larry    Male                   Other
# 17901         Grose             Larry    Male                   White
# 770           Alter          Willilam    Male                     NaN
# 33497    Neiswanger           Charles    Male                   Other
# 32244         Moore             Billy    Male                   Other
# 20201   Hendershott            Virgil    Male                   White
# 41251       Seifers           Richard    Male                     NaN
# 18654      Hamilton          Greggory    Male                     NaN
# 34914       Pankoke             David    Male                     NaN
# 50399    Williamson             Randy    Male                     NaN
# 29483        Maxson            Thomas    Male                   White
# 1848        Bainter              Lyle    Male                   White
# 43691         Spetz           Gregory    Male                   White
# 3833          Black            Robert    Male                     NaN
# 24487         Keers           Stephen    Male                     NaN
# 46286      Thompson            Robert    Male                     NaN
# 54682      Docherty           Stephen    Male                     NaN
# 48985          Webb           Jeffrey    Male                     NaN
# 10547        Dahlke           William    Male                     NaN
# 4464         Bosley           Michael    Male                   Other
# 46568          Todd            Ernest    Male                   White
# 8020         Christ            Donald    Male                     NaN
# 25471  Klingensmith             David    Male                   White
# 25056       Kimmell             James    Male                   Other
# 14772         Floyd           Russell    Male                   White
# 37162       Quearry          Marshall    Male                   White
# 16230       Gebhard             James    Male                     NaN
# 12023         Dobis              Mark    Male                     NaN
# 9404       Copeland             Grady    Male                     NaN
# 43134         Smith             James    Male                   Other
# 29463         Maxey              Gary    Male                     NaN
# 9925         Cranor           Richard    Male                   Other
# 15535           Fry              Gary    Male                   White
# 51536         Yates            Thomas    Male                   White
#
#        birth_year  start_date    end_date                         rank  \
# 533        1948.0  1900-01-01  1900-01-01                 Jail Officer
# 55         1948.0  1900-01-01  2013-08-01                 Jail Officer
# 80            NaN  1900-01-01  1998-02-15                 Jail Officer
# 17315      1976.0  1900-01-01  2003-02-15               Reserve Deputy
# 37104      1955.0  1900-01-01  2015-12-03                      Unknown
# 44340      1996.0  1900-01-01  2023-08-28                 Jail Officer
# 43235      1971.0  1900-01-01  2014-10-09                 Jail Officer
# 51390      1987.0  1921-01-02  2022-04-09                   Dispatcher
# 31706      1997.0  1921-05-10  2023-03-28                      Officer
# 33193      1978.0  1923-02-14         NaN                 Jail Officer
# 42806      1942.0  1942-02-03  2014-06-30                        Chief
# 60366      1944.0  1944-04-21  2011-09-07               Deputy Marshal
# 7945       1946.0  1946-07-09  1973-01-01                      Officer
# 16131      1947.0  1947-08-15  2010-05-27                   Lieutenant
# 11511      1949.0  1949-07-09  2014-03-01                 Jail Officer
# 51576      1949.0  1949-09-26  2008-12-31                      Officer
# 37464      1949.0  1949-12-02  2010-12-31                      Officer
# 25746      1951.0  1951-04-23         NaN                      Officer
# 31860      1951.0  1951-06-14  2020-11-03                 Investigator
# 17056      1951.0  1951-07-10  2014-07-25                 Jail Officer
# 2792       1951.0  1951-10-01  2017-08-01               Reserve Deputy
# 26613      1952.0  1952-01-02         NaN                      Officer
# 58141      1952.0  1952-08-13  2014-08-31                      Officer
# 14985      1953.0  1953-03-26         NaN                      Officer
# 31501      1953.0  1953-09-25  2023-12-31                      Officer
# 66783      1954.0  1954-08-04         NaN                      Officer
# 53865      1955.0  1955-01-23  2012-06-22                      Officer
# 28535      1949.0  1955-04-01  1996-04-27                      Unknown
# 12048      1955.0  1955-10-17  2018-11-18                 Jail Officer
# 6157       1955.0  1955-11-22  2011-03-01                      Officer
# 22890      1956.0  1956-08-15  2010-12-31                      Officer
# 29556      1956.0  1956-11-08  2013-02-14                      Officer
# 27185      1956.0  1956-12-14         NaN                      Officer
# 14483      1957.0  1957-03-16  2013-01-24                      Officer
# 48204      1957.0  1957-09-03  2014-05-01                    Detective
# 24768      1957.0  1957-09-25         NaN                      Unknown
# 6618       1958.0  1958-01-31         NaN                      Officer
# 42524      1958.0  1958-07-24  2014-04-01                      Officer
# 27078      1958.0  1958-12-12  2015-08-23                      Officer
# 56380      1959.0  1959-01-10  2022-09-01                        Chief
# 53953      1959.0  1959-01-19  2012-09-10                      Officer
# 30690      1959.0  1959-02-15  2011-07-01                    Detective
# 40992      1959.0  1959-03-31  2019-05-31                     Sergeant
# 48432      1933.0  1959-06-15  2015-08-05                      Officer
# 32619      1960.0  1960-02-05  2019-09-11                      Officer
# 19365      1960.0  1960-12-13  2015-06-06                      Officer
# 51040      1961.0  1961-01-25  2020-01-02                      Captain
# 14678      1961.0  1961-04-05  2021-01-04                      Officer
# 36958      1935.0  1961-05-01  2007-03-01                      Officer
# 30991      1940.0  1961-09-01  1961-09-01                      Unknown
# 4652       1962.0  1962-05-16  2024-04-11                   Dispatcher
# 23630      1962.0  1962-06-18  2009-12-01                      Officer
# 25521      1962.0  1962-07-06  2015-03-06               Reserve Deputy
# 18990      1962.0  1962-08-16  2023-01-31                   Lieutenant
# 15459      1936.0  1962-10-16  2006-08-04                      Officer
# 32976      1938.0  1962-12-24  2015-12-30                      Officer
# 30341      1963.0  1963-02-02  2017-01-30                      Unknown
# 33226      1939.0  1963-02-25  2016-05-12              Reserve Officer
# 17390      1963.0  1963-03-07  2013-04-15              Reserve Officer
# 40950      1939.0  1963-04-12         NaN                      Unknown
# 44645      1963.0  1963-05-04  2016-09-01                      Officer
# 11595      1932.0  1963-05-16  2011-03-01                     Sergeant
# 40834      1938.0  1963-05-18         NaN                      Unknown
# 14839      1941.0  1963-10-07  2014-04-25                      Captain
# 16731      1941.0  1963-10-17  2007-12-27                     Sergeant
# 15472      1936.0  1963-11-01         NaN                      Unknown
# 12041      1963.0  1963-11-13  2020-02-01                     Sergeant
# 15194      1963.0  1963-12-08         NaN                      Officer
# 30480      1938.0  1964-02-01  2009-10-01              Reserve Officer
# 51278      1964.0  1964-03-08  2011-02-14                      Officer
# 33147      1965.0  1964-03-28  1984-12-01                      Unknown
# 36483      1964.0  1964-05-06         NaN                      Unknown
# 30297      1964.0  1964-09-11         NaN                      Unknown
# 37123      1964.0  1964-11-20         NaN                 Jail Officer
# 6363       1938.0  1965-01-01  1988-02-11                     Sergeant
# 41881      1934.0  1965-02-02  1990-04-20                      Officer
# 25879      1965.0  1965-05-06  2017-02-17              Reserve Officer
# 8236       1965.0  1965-07-07  2016-03-04                        Chief
# 27693      1942.0  1965-08-01  2008-06-30                      Unknown
# 15398      1965.0  1965-08-14  2022-01-18                    Detective
# 8021       1943.0  1965-09-20         NaN                   Lieutenant
# 19508      1938.0  1965-10-01         NaN                      Officer
# 41571         NaN  1965-11-01         NaN               Special Deputy
# 41443      1965.0  1965-11-08         NaN                      Unknown
# 19238      1941.0  1965-11-25  2012-06-01              Reserve Officer
# 49630      1949.0  1966-01-01         NaN                      Unknown
# 20297      1939.0  1966-01-16  2017-01-30                      Unknown
# 21855      1942.0  1966-02-01         NaN                      Officer
# 42271      1974.0  1966-02-02  1966-02-02                 Jail Officer
# 48865      1966.0  1966-02-21  2020-09-13                    Detective
# 45122      1966.0  1966-03-01  2016-08-03                   Lieutenant
# 166        1944.0  1966-03-14  2008-07-16                      Unknown
# 56522      1944.0  1966-03-14  1999-07-02                      Officer
# 15585      1942.0  1966-05-01  2022-12-31              Reserve Officer
# 61071      1966.0  1966-06-24         NaN              Reserve Officer
# 21780      1942.0  1966-10-17         NaN                      Officer
# 45471      1966.0  1966-10-22  2020-05-07                     Sergeant
# 5561       1938.0  1967-01-01  2016-02-20               Reserve Deputy
# 714        1941.0  1967-01-01  2017-01-05               Special Deputy
# 2259       1942.0  1967-01-01  2004-01-21                      Unknown
# 45510      1941.0  1967-01-01  2021-12-29                 Jail Officer
# 33163      1967.0  1967-01-10         NaN               Special Deputy
# 32869      1945.0  1967-01-10  2017-01-30                      Unknown
# 40679      1967.0  1967-02-02         NaN                     Civilian
# 25974      1942.0  1967-04-01  2018-01-01               Reserve Deputy
# 2683       1943.0  1967-04-01  2004-01-02                      Captain
# 21265      1940.0  1967-04-03  2001-03-31                      Unknown
# 1971       1967.0  1967-04-26  1967-04-26                      Officer
# 36193      1967.0  1967-06-10         NaN                      Officer
# 43127      1943.0  1967-07-24         NaN                      Unknown
# 16902      1943.0  1967-09-05  2014-04-22              Reserve Officer
# 40504      1941.0  1967-09-10  2018-01-01               Reserve Deputy
# 53463      1967.0  1967-09-27  2009-12-31                      Officer
# 38653      1967.0  1967-10-23  2023-03-01                     Sergeant
# 39599      1946.0  1967-10-24  2008-09-01                      Unknown
# 6965       1967.0  1967-11-19         NaN                   Lieutenant
# 5059       1942.0  1967-12-26  2016-07-30                      Officer
# 59016      1944.0  1968-01-01  2014-12-31                      Sheriff
# 49414      1942.0  1968-01-01  2010-06-18                        Chief
# 2436       1943.0  1968-01-01  1991-11-22                      Unknown
# 20796      1946.0  1968-01-29  2000-02-28                      Unknown
# 52017      1945.0  1968-01-29  2000-01-31                      Unknown
# 7652       1968.0  1968-03-09  2022-10-03                      Officer
# 34146      1946.0  1968-03-16  2010-08-30                      Officer
# 22204      1968.0  1968-03-26  2014-10-13                 Jail Officer
# 22474      1945.0  1968-05-20  2021-06-04              Reserve Officer
# 43258      1945.0  1968-05-20         NaN                      Officer
# 44656      1946.0  1968-05-20  1999-06-11                      Unknown
# 9155       1957.0  1968-06-01  2020-05-29                     Corporal
# 10116      1947.0  1968-06-01         NaN               Special Deputy
# 50621      1942.0  1968-06-03         NaN                      Unknown
# 4969       1937.0  1968-06-17  1985-11-30                      Unknown
# 48209      1968.0  1968-06-19  2023-04-10                       Deputy
# 36659      1942.0  1968-07-26  2007-06-11                      Marshal
# 49923      1942.0  1968-09-01  2014-12-31                        Chief
# 47093      1945.0  1968-09-03         NaN                      Officer
# 2985       1944.0  1968-09-23  2007-12-21                      Captain
# 12386      1947.0  1968-09-23         NaN                      Officer
# 40254      1941.0  1968-10-21  2011-03-31              Reserve Officer
# 60815      1941.0  1968-10-21         NaN              Reserve Officer
# 11025      1946.0  1968-10-21         NaN        Unknown - inactivated
# 31713      1946.0  1968-11-01  2020-03-17                      Officer
# 37837      1943.0  1968-11-01  1999-02-18                      Unknown
# 23709      1946.0  1969-01-01         NaN                      Unknown
# 48309      1946.0  1969-01-01  2021-01-01              Reserve Officer
# 55636      1945.0  1969-01-01         NaN                      Officer
# 35670         NaN  1969-01-01  2000-01-01                      Officer
# 16441      1945.0  1969-01-01  2017-01-30                      Unknown
# 8968       1934.0  1969-01-15  2017-01-20                      Unknown
# 56129      1943.0  1969-02-09  2010-03-24              Reserve Officer
# 51258      1947.0  1969-02-10  2014-02-17                     Sergeant
# 43578      1946.0  1969-02-10         NaN                      Unknown
# 42495      1946.0  1969-02-10  2012-12-31              Reserve Officer
# 9466       1947.0  1969-02-16  2017-01-25                      Unknown
# 18704      1947.0  1969-03-01         NaN                      Officer
# 587        1943.0  1969-03-16         NaN                      Unknown
# 3261       1947.0  1969-04-16         NaN                      Unknown
# 49605      1969.0  1969-04-23  2022-11-30                      Captain
# 51410      1943.0  1969-04-24  2018-06-22               Reserve Deputy
# 21212      1947.0  1969-04-25  2011-10-31                   Lieutenant
# 50982      1969.0  1969-04-25         NaN                     Civilian
# 12853      1943.0  1969-05-15  1974-02-11                      Officer
# 14054      1946.0  1969-05-16  2005-02-24                      Unknown
# 35893      1943.0  1969-06-16  2014-09-19                        Chief
# 35372      1941.0  1969-06-23  1997-01-31                      Unknown
# 4929       1947.0  1969-06-23  2010-08-09              Reserve Officer
# 2300       1946.0  1969-06-23         NaN                      Officer
# 48937      1969.0  1969-09-11  2018-04-06              Reserve Officer
# 29507      1945.0  1969-09-22  2013-05-17              Reserve Officer
# 5030       1946.0  1969-09-22  2013-07-06              Reserve Officer
# 36894      1947.0  1969-09-22  2012-01-13                   Lieutenant
# 8945       1947.0  1969-09-22  2011-01-01              Reserve Officer
# 14209      1946.0  1969-09-22  2016-10-31              Reserve Officer
# 18505      1947.0  1969-09-22  2015-05-25              Reserve Officer
# 42456      1943.0  1969-10-01  2000-10-04                      Officer
# 4927       1945.0  1969-11-03  2007-04-17                      Officer
# 31541      1947.0  1969-11-24  2014-01-01                      Officer
# 830        1943.0  1969-12-01  2011-12-16                      Marshal
# 23777      1969.0  1969-12-01  2022-08-09                      Officer
# 1706       1946.0  1970-01-01  1993-07-16                      Unknown
# 39396      1947.0  1970-01-01         NaN       Chief Deputy (Sheriff)
# 11238      1948.0  1970-01-01  1970-01-01                      Unknown
# 17398      1945.0  1970-01-02  2010-01-04                      Captain
# 1149          NaN  1970-01-02  2015-01-03                      Officer
# 68199      1970.0  1970-01-10  2023-05-12                        Chief
# 45223      1947.0  1970-01-24  2007-04-16                      Unknown
# 46169      1941.0  1970-01-26         NaN                      Unknown
# 40009      1949.0  1970-02-09  2006-01-03                      Unknown
# 10072      1946.0  1970-02-16  2017-01-30                      Unknown
# 18884      1947.0  1970-02-16         NaN                      Officer
# 41730      1945.0  1970-03-01  2000-09-01                      Unknown
# 49063      1970.0  1970-03-03  2020-01-13                       Deputy
# 30187      1943.0  1970-03-04  2005-08-31                      Unknown
# 14464      1948.0  1970-03-20  2010-10-10                   Lieutenant
# 14062      1974.0  1970-04-01         NaN                      Officer
# 9433       1946.0  1970-04-01  2022-04-12               Special Deputy
# 31067      1948.0  1970-04-06         NaN                      Unknown
# 2669       1970.0  1970-04-08         NaN              Reserve Officer
# 10129      1949.0  1970-04-13         NaN                        Chief
# 44325      1944.0  1970-05-01  2004-09-18                      Unknown
# 15291      1946.0  1970-05-13         NaN                      Unknown
# 40820      1970.0  1970-05-13  2014-12-29                      Officer
# 28706      1946.0  1970-05-15  2012-12-12                      Officer
# 6855       1943.0  1970-06-01  2013-09-30              Reserve Officer
# 29386      1946.0  1970-06-15  2013-01-01                      Officer
# 31731      1948.0  1970-07-01  2007-12-31              Assistant Chief
# 28820      1946.0  1970-07-16  2012-03-12                      Captain
# 27712      1970.0  1970-07-19         NaN                    Detective
# 43479      1970.0  1970-08-01  2021-01-06                      Officer
# 39270      1948.0  1970-08-01  2018-12-31                      Sheriff
# 3194       1937.0  1970-08-26         NaN                      Unknown
# 4660       1946.0  1970-09-01  2017-01-20                      Unknown
# 41068      1947.0  1970-09-01  2011-01-31                      Officer
# 9725       1940.0  1970-09-15         NaN                      Unknown
# 58481      1990.0  1970-09-26  2017-09-26                 Jail Officer
# 189        1947.0  1970-09-28         NaN                      Officer
# 44235      1949.0  1970-10-05         NaN  Director of Risk Management
# 17901      1944.0  1970-11-01  2011-01-28                     Sergeant
# 770        1958.0  1970-11-17  2020-02-08                      Officer
# 33497      1949.0  1970-11-19         NaN                      Unknown
# 32244      1940.0  1970-12-01         NaN                      Officer
# 20201      1944.0  1970-12-01         NaN                      Unknown
# 41251      1949.0  1970-12-14  2016-06-01                    Detective
# 18654      1970.0  1970-12-23         NaN                 Jail Officer
# 34914      1945.0  1971-01-01  2017-01-31                      Unknown
# 50399      1949.0  1971-01-01  2010-08-03                      Officer
# 29483      1947.0  1971-01-01  1974-01-01                       Deputy
# 1848       1947.0  1971-01-05         NaN                      Unknown
# 43691      1948.0  1971-01-25         NaN                      Unknown
# 3833       1949.0  1971-01-28  1991-01-28              Assistant Chief
# 24487      1945.0  1971-02-01  2017-07-22              Reserve Officer
# 46286      1944.0  1971-02-01  2011-04-26              Reserve Officer
# 54682      1949.0  1971-02-01  2010-02-26              Reserve Officer
# 48985      1950.0  1971-02-01  2020-01-03                      Officer
# 10547      1948.0  1971-02-01  2015-02-06                      Captain
# 4464       1949.0  1971-02-01  2003-02-14                      Unknown
# 46568      1945.0  1971-02-01  2005-01-03                      Unknown
# 8020       1948.0  1971-02-02  2021-12-31                   Lieutenant
# 25471      1947.0  1971-02-15  1991-03-01                      Unknown
# 25056      1947.0  1971-03-07  2003-01-17                      Unknown
# 14772      1946.0  1971-03-22  2006-10-30                      Unknown
# 37162      1945.0  1971-04-19         NaN                      Unknown
# 16230      1948.0  1971-04-26  2018-12-28                     Sergeant
# 12023      1948.0  1971-05-01  2010-01-04                      Officer
# 9404       1946.0  1971-05-01         NaN                     Sergeant
# 43134      1950.0  1971-05-01         NaN                      Unknown
# 29463      1949.0  1971-05-01  2013-09-23                     Sergeant
# 9925       1945.0  1971-05-01  2008-02-28                      Unknown
# 15535      1949.0  1971-05-15  2017-01-30                      Unknown
# 51536      1942.0  1971-05-24  1983-06-24                      Unknown
#
#       separation_reason
# 533               Other
# 55             Deceased
# 80            Separated
# 17315         Separated
# 37104         Separated
# 44340          Resigned
# 43235        Discharged
# 51390          Resigned
# 31706          Resigned
# 33193            Active
# 42806           Retired
# 60366          Resigned
# 7945            Retired
# 16131           Retired
# 11511           Retired
# 51576         Separated
# 37464           Retired
# 25746          Deceased
# 31860          Deceased
# 17056           Retired
# 2792            Retired
# 26613            Active
# 58141           Retired
# 14985           Retired
# 31501           Retired
# 66783            Active
# 53865           Retired
# 28535           Retired
# 12048         Separated
# 6157            Retired
# 22890           Retired
# 29556           Retired
# 27185           Retired
# 14483           Retired
# 48204           Retired
# 24768             Other
# 6618            Retired
# 42524           Retired
# 27078           Retired
# 56380           Retired
# 53953           Retired
# 30690           Retired
# 40992           Retired
# 48432           Retired
# 32619           Retired
# 19365           Retired
# 51040           Retired
# 14678           Retired
# 36958          Deceased
# 30991          Resigned
# 4652           Resigned
# 23630          Resigned
# 25521          Resigned
# 18990           Retired
# 15459           Retired
# 32976           Retired
# 30341         Separated
# 33226           Retired
# 17390          Resigned
# 40950             Other
# 44645           Retired
# 11595           Retired
# 40834            Active
# 14839           Retired
# 16731           Retired
# 15472           Retired
# 12041           Retired
# 15194          Resigned
# 30480          Deceased
# 51278         Separated
# 33147           Retired
# 36483             Other
# 30297          Resigned
# 37123            Active
# 6363            Retired
# 41881           Retired
# 25879          Resigned
# 8236              Other
# 27693           Retired
# 15398           Retired
# 8021             Active
# 19508             Other
# 41571            Active
# 41443          Resigned
# 19238          Resigned
# 49630          Resigned
# 20297         Separated
# 21855           Retired
# 42271          Resigned
# 48865           Retired
# 45122           Retired
# 166             Retired
# 56522           Retired
# 15585         Separated
# 61071            Active
# 21780           Retired
# 45471           Retired
# 5561          Separated
# 714             Retired
# 2259            Retired
# 45510          Resigned
# 33163            Active
# 32869         Separated
# 40679            Active
# 25974        Discharged
# 2683           Deceased
# 21265           Retired
# 1971            Retired
# 36193            Active
# 43127          Resigned
# 16902           Retired
# 40504        Discharged
# 53463         Separated
# 38653           Retired
# 39599           Retired
# 6965             Active
# 5059            Retired
# 59016           Retired
# 49414           Retired
# 2436            Retired
# 20796           Retired
# 52017          Resigned
# 7652            Retired
# 34146           Retired
# 22204          Resigned
# 22474          Resigned
# 43258           Retired
# 44656           Retired
# 9155            Retired
# 10116            Active
# 50621         Separated
# 4969           Deceased
# 48209           Retired
# 36659          Resigned
# 49923           Retired
# 47093           Retired
# 2985            Retired
# 12386           Retired
# 40254           Retired
# 60815             Other
# 11025           Retired
# 31713           Retired
# 37837           Retired
# 23709           Retired
# 48309          Resigned
# 55636           Retired
# 35670          Resigned
# 16441         Separated
# 8968          Separated
# 56129         Separated
# 51258           Retired
# 43578            Active
# 42495           Retired
# 9466          Separated
# 18704           Retired
# 587             Retired
# 3261          Separated
# 49605           Retired
# 51410           Retired
# 21212           Retired
# 50982            Active
# 12853          Resigned
# 14054           Retired
# 35893           Retired
# 35372           Retired
# 4929          Separated
# 2300            Retired
# 48937          Resigned
# 29507          Resigned
# 5030           Resigned
# 36894           Retired
# 8945            Retired
# 14209          Deceased
# 18505          Resigned
# 42456           Retired
# 4927            Retired
# 31541           Retired
# 830             Retired
# 23777           Retired
# 1706            Retired
# 39396            Active
# 11238           Retired
# 17398           Retired
# 1149            Retired
# 68199          Resigned
# 45223           Revoked
# 46169         Separated
# 40009           Retired
# 10072         Separated
# 18884             Other
# 41730           Retired
# 49063          Resigned
# 30187           Retired
# 14464           Retired
# 14062            Active
# 9433            Retired
# 31067             Other
# 2669             Active
# 10129            Active
# 44325           Retired
# 15291          Resigned
# 40820         Separated
# 28706           Retired
# 6855            Retired
# 29386           Retired
# 31731           Retired
# 28820          Deceased
# 27712            Active
# 43479           Retired
# 39270           Retired
# 3194              Other
# 4660          Separated
# 41068         Separated
# 9725            Retired
# 58481          Resigned
# 189             Retired
# 44235             Other
# 17901           Retired
# 770             Retired
# 33497             Other
# 32244           Retired
# 20201           Retired
# 41251           Retired
# 18654            Active
# 34914         Separated
# 50399           Retired
# 29483         Separated
# 1848            Retired
# 43691          Resigned
# 3833            Retired
# 24487          Resigned
# 46286           Retired
# 54682         Separated
# 48985           Retired
# 10547           Retired
# 4464            Retired
# 46568           Retired
# 8020            Retired
# 25471           Retired
# 25056           Retired
# 14772           Retired
# 37162          Resigned
# 16230           Retired
# 12023           Retired
# 9404             Active
# 43134         Separated
# 29463           Retired
# 9925            Retired
# 15535         Separated
# 51536         Separated

# %% [markdown]
# data isnt great for determining exactly how far back it goes

# %% [markdown]
# #### getting active officers

# %%
get_dept_counts(df=indiana, id_column='person_nbr', agency_column='agency_name')

# %%
indiana.shape
# Out:
# (68247, 13)

# %%
indiana.columns
# Out:
# Index(['person_nbr', 'agency_name', 'last_name', 'first_name', 'gender',
#        'race', 'birth_year', 'start_date', 'end_date', 'rank',
#        'separation_reason', 'number_of_depts', 'number_of_unique_depts'],
#       dtype='object')

# %%
active_indiana = get_active_officers(df=indiana, id_column='person_nbr', status_column='separation_reason', active_word='Active')

# %%
active_indiana.to_excel('indiana/active_indiana.xlsx', index=False)

# %%
active_indiana['person_nbr'].nunique()
# Out:
# 20507

# %% [markdown]
# there's 20507 currently active officers in indiana

# %%
# get active officers who have been at 3+ departments
in_active_3plus = active_indiana.loc[active_indiana['number_of_unique_depts'] >= 3].copy()
in_active_3plus['person_nbr'].nunique()
# Out:
# 2074

# %%
# get active officers who have been at 5+ departments
in_active_5plus = active_indiana.loc[active_indiana['number_of_unique_depts'] >= 5].copy()
in_active_5plus['person_nbr'].nunique()
# Out:
# 206

# %%
in_active_3plus.to_excel('indiana/in_active_3plus.xlsx', index=False)
in_active_5plus.to_excel('indiana/in_active_5plus.xlsx', index=False)

# %% [markdown]
# There are 20507 unique currently active officers. Out of these, there are 2074 officers who have had 3+ unique employers, and 206 who have had 5+.

# %%
active_indiana.value_counts('separation_reason')
# Out:
# separation_reason
# Active                     21445
# Resigned                    6732
# Separated                   1436
# Retired                      804
# Other                        546
# Discharged                   290
# Never with Organization       22
# Deceased                      10
# Revoked                        8
# On Leave                       3
# Name: count, dtype: int64

# %%
terminated_active_indiana = get_terminated_active(active_df=active_indiana, id_column='person_nbr', status_column='separation_reason', term_word='Discharged')
terminated_active_indiana['person_nbr'].nunique()
# Out:
# 271

# %% [markdown]
# Out of the currently active officers, there are 271 officers who have been terminated from a previous department

# %% [markdown]
# ### **Kansas Analysis**

# %%
kansas = pd.read_csv('../npi_lookup/national-post-db/ks/output/ks-2024-index.csv')

# %%
kansas.head(5)
# Out:
#    person_nbr         full_name last_name first_name middle_name  \
# 0       18468   Jeffery Ridgway   Ridgway    Jeffery         NaN
# 1       34726  Clayton Philpott  Philpott    Clayton         NaN
# 2       33426       Juliet Gray      Gray     Juliet         NaN
# 3       21555        Joe Sutton    Sutton        Joe         NaN
# 4       31520     Justin Wunder    Wunder     Justin         NaN
#
#   middle_initial suffix                             agency_name  \
# 0            NaN    NaN           Ellis County Sheriff's Office
# 1            NaN    NaN          Marion County Sheriff's Office
# 2            NaN    NaN            Linn County Sheriff's Office
# 3            NaN    NaN              Cherokee Police Department
# 4            NaN    NaN  Auburn-Washburn USD #437 School Police
#
#              rank status  start_date end_date
# 0       Detective      F  12/31/2023      NaN
# 1          Deputy      F  12/29/2023      NaN
# 2          Deputy      F  12/29/2023      NaN
# 3  Patrol Officer      F  12/28/2023      NaN
# 4  Patrol Officer      F  12/27/2023      NaN

# %%
kansas.sort_values(by='start_date').head(40)
# Out:
#        person_nbr             full_name   last_name   first_name middle_name  \
# 21899       13427         Bradley Ricke       Ricke      Bradley         NaN
# 21714       15863          Jason Sutton      Sutton        Jason         NaN
# 21472       13605      William Robinson    Robinson      William         NaN
# 21293       21262           Sheri Staab       Staab        Sheri         NaN
# 21294       11034        Travis Mishler     Mishler       Travis         NaN
# 21163       15803       Shelby Sturgeon    Sturgeon       Shelby         NaN
# 21055       14151  Christopher Scheuber    Scheuber  Christopher         NaN
# 21054       19523     Darrin Littlepage  Littlepage       Darrin         NaN
# 20878        3236          William Cory        Cory      William         NaN
# 20877       23065            Todd Walsh       Walsh         Todd         NaN
# 20879        9678       Charles Lowther     Lowther      Charles         NaN
# 20551       22807         Larry Godfrey     Godfrey        Larry         NaN
# 9921        22811         Donald Jacobs      Jacobs       Donald         NaN
# 9919         1629           Paul Bowman      Bowman         Paul         NaN
# 9918        26168         Rick Williams    Williams         Rick         NaN
# 9920         1956          Ronald Brown       Brown       Ronald         NaN
# 8703        19543       Burton Pianalto    Pianalto       Burton         NaN
# 8700        21032           Brian Welsh       Welsh        Brian         NaN
# 8701        12941            Mack Pryor       Pryor         Mack         NaN
# 8702        19873            Chad Hodge       Hodge         Chad         NaN
# 8699        19543       Burton Pianalto    Pianalto       Burton         NaN
# 8704        13392          Jay Richards    Richards          Jay         NaN
# 5896        26624       Tyler Pettigrew   Pettigrew        Tyler         NaN
# 5883        25479     Arthur Buckingham  Buckingham       Arthur         NaN
# 5884        11496            Gary Myers       Myers         Gary         NaN
# 5885        22271           Brian Miles       Miles        Brian         NaN
# 5886        18906          Kelly Rummel      Rummel        Kelly         NaN
# 5887        23263     Christopher Smith       Smith  Christopher         NaN
# 5888        10451          Robert McGee       McGee       Robert         NaN
# 5889        26185          James Mercer      Mercer        James         NaN
# 5895        26628        Scott Galloway    Galloway        Scott         NaN
# 5890        12630       Michael Pickens     Pickens      Michael         NaN
# 5882        26603        Chance Hartner     Hartner       Chance         NaN
# 5891        26627          Harold Brown       Brown       Harold         NaN
# 5892        26594           Thomas Maue        Maue       Thomas         NaN
# 5898        22198         Lucas Sanders     Sanders        Lucas         NaN
# 5894        21255         Thomas Reazin      Reazin       Thomas         NaN
# 5897        26100         John Epperson    Epperson         John         NaN
# 5893        23670        Jessie Woodrow     Woodrow       Jessie         NaN
# 7412        26117         Bret Marietta    Marietta         Bret         NaN
#
#       middle_initial suffix                                agency_name  \
# 21899            NaN    NaN              Ellis County Sheriff's Office
# 21714            NaN    NaN       Kansas City Kansas Police Department
# 21472            NaN    NaN              Clay Center Police Department
# 21293            NaN    NaN             Thomas County Sheriff's Office
# 21294            NaN    NaN               Lyon County Sheriff's Office
# 21163            NaN    NaN                   Topeka Police Department
# 21055            NaN    NaN        Augusta Department of Public Safety
# 21054            NaN    NaN                      Kansas Highway Patrol
# 20878            NaN    NaN                 Lawrence Police Department
# 20877            NaN    NaN             Saline County Sheriff's Office
# 20879            NaN    NaN                   Lenexa Police Department
# 20551            NaN    NaN              Grant County Sheriff's Office
# 9921             NaN    NaN             Jewell County Sheriff's Office
# 9919             NaN    NaN  Kansas City KS Comm College Campus Police
# 9918             NaN    NaN                    Lewis Police Department
# 9920             NaN    NaN    Topeka Public Schools Police Department
# 8703             NaN    NaN            Sherman County Sheriff's Office
# 8700             NaN    NaN            Kansas Dept of Wildlife & Parks
# 8701             NaN    NaN            Kansas Dept of Wildlife & Parks
# 8702             NaN    NaN                 Westwood Police Department
# 8699             NaN    NaN           Sherman County Attorney's Office
# 8704             NaN    NaN                   Lenexa Police Department
# 5896             NaN    NaN               Lyon County Sheriff's Office
# 5883             NaN    NaN                 Highland Police Department
# 5884             NaN    NaN                    Pratt Police Department
# 5885             NaN    NaN                    Kechi Police Department
# 5886             NaN    NaN               Gove County Sheriff's Office
# 5887             NaN    NaN               Tonganoxie Police Department
# 5888             NaN    NaN               Clay County Sheriff's Office
# 5889             NaN    NaN            Jackson County Sheriff's Office
# 5895             NaN    NaN                   Benton Police Department
# 5890             NaN    NaN                  Mulvane Police Department
# 5882             NaN    NaN           Marshall County Sheriff's Office
# 5891             NaN    NaN                   Benton Police Department
# 5892             NaN    NaN          Wabaunsee County Sheriff's Office
# 5898             NaN    NaN            Lincoln County Sheriff's Office
# 5894             NaN    NaN                 Sterling Police Department
# 5897             NaN    NaN                   Galena Police Department
# 5893             NaN    NaN                    Kechi Police Department
# 7412             NaN    NaN            Decatur County Sheriff's Office
#
#                  rank status start_date    end_date
# 21899          Deputy      F   1/1/1996         NaN
# 21714       Detective      F   1/1/1999         NaN
# 21472           Chief      F   1/1/2002         NaN
# 21293          Deputy      P   1/1/2004         NaN
# 21294       Detective      F   1/1/2004         NaN
# 21163      Lieutenant      F   1/1/2005         NaN
# 21055        Sergeant      F   1/1/2006         NaN
# 21054            trpr      F   1/1/2006         NaN
# 20878         Captain      F   1/1/2007         NaN
# 20877          Deputy      F   1/1/2007         NaN
# 20879        Sergeant      F   1/1/2007         NaN
# 20551          Deputy      F   1/1/2009         NaN
# 9921           Deputy      F   1/1/2010   9/27/2011
# 9919   Patrol Officer      F   1/1/2010   1/22/2010
# 9918   Patrol Officer      P   1/1/2010    9/1/2010
# 9920         Director      F   1/1/2010    8/1/2020
# 8703             INVR      P   1/1/2011   3/19/2012
# 8700   Patrol Officer      P   1/1/2011    1/1/2015
# 8701             PRGR      P   1/1/2011    6/1/2013
# 8702   Patrol Officer      F   1/1/2011   6/22/2012
# 8699             INVR      F   1/1/2011   1/13/2013
# 8704         Sergeant      F   1/1/2011         NaN
# 5896           Deputy      F   1/1/2012   6/22/2016
# 5883   Patrol Officer      F   1/1/2012    3/6/2012
# 5884            Chief      F   1/1/2012   9/24/2018
# 5885   Patrol Officer      P   1/1/2012   3/31/2017
# 5886     Undersheriff      F   1/1/2012    2/1/2018
# 5887   Patrol Officer      F   1/1/2012    4/5/2015
# 5888           Deputy      F   1/1/2012   9/30/2012
# 5889           Deputy      F   1/1/2012   8/17/2020
# 5895   Patrol Officer      P   1/1/2012    1/1/2013
# 5890   Patrol Officer      F   1/1/2012   4/16/2014
# 5882           Deputy      F   1/1/2012    3/1/2019
# 5891   Patrol Officer      P   1/1/2012    7/9/2012
# 5892           Deputy      F   1/1/2012   9/13/2015
# 5898           Deputy      P   1/1/2012   5/12/2014
# 5894   Patrol Officer      P   1/1/2012   10/9/2017
# 5897   Patrol Officer      F   1/1/2012   3/11/2013
# 5893   Patrol Officer      F   1/1/2012   4/13/2017
# 7412           Deputy      F   1/1/2013  11/14/2014

# %%
kansas.columns
# Out:
# Index(['person_nbr', 'full_name', 'last_name', 'first_name', 'middle_name',
#        'middle_initial', 'suffix', 'agency_name', 'rank', 'status',
#        'start_date', 'end_date'],
#       dtype='object')

# %%
get_dept_counts(df=kansas, id_column='person_nbr', agency_column='agency_name')

# %% [markdown]
# we cant get the number of active officers in the same way that we did for new mexico, since there's not status column.
# instead, will use when end_date is empty, because that implies officer is still working there.

# %%
active_kansas = get_active_officers_no_status(df=kansas, id_column='person_nbr')

# %%
active_kansas['person_nbr'].nunique()
# Out:
# 9812

# %%
# get active officers who have been at 3+ departments
ks_active_3plus = active_kansas.loc[active_kansas['number_of_unique_depts'] >= 3].copy()
ks_active_3plus['person_nbr'].nunique()
# Out:
# 836

# %%
# get active officers who have been at 3+ departments
ks_active_5plus = active_kansas.loc[active_kansas['number_of_unique_depts'] >= 5].copy()
ks_active_5plus['person_nbr'].nunique()
# Out:
# 112

# %% [markdown]
# ### **Mississippi Analysis**

# %%
mississippi = pd.read_csv('../npi_lookup/national-post-db/ms/output/mississippi-processed.csv')

# %%
mississippi.head()
# Out:
#   first_name  last_name      Agency   TYPE employment_status  start_date  \
# 0    Timothy     Pruitt   Abbeville  Chief        Part-Time   2010-04-01
# 1      Jimmy     Easley  Abbeville   Chief        Part-Time   1995-05-15
# 2      Jacob       Abel         ABC  State        Full-Time   2022-05-02
# 3       Kurt  Alexander         ABC  State        Full-Time   2010-09-13
# 4    William  Alexander         ABC  State        Full-Time   2002-07-01
#
#      end_date  person_nbr      agency_name
# 0         NaN       13792  abbeville chief
# 1  2009-11-30       14876  abbeville chief
# 2         NaN       19785        abc state
# 3         NaN       21028        abc state
# 4  2019-09-03       15761        abc state

# %%
mississippi.sort_values(by='start_date').head(20)
# Out:
#       first_name   last_name          Agency     TYPE employment_status  \
# 28708       Olaf      Raybon        Picayune       PD        Part-Time
# 36984    William       Lloyd        Wildlife    State        Full-Time
# 763      Michael     Kingdom         Arcola        PD        Part-Time
# 592       Milton      Bishop       Alcorn Co       SO        Part-Time
# 16849     Hilman  Wedgeworth        Jones Co       SO        Part-Time
# 36623     Hubert      Nabors      West Point       PD        Part-Time
# 26046    Robert      Germany  Ocean Springs        PD        Full-Time
# 22783    Robert      Tinsley        Meridian       PD        Full-Time
# 27430    Thomas      Ruspoli  Pass Christian       PD        Full-Time
# 24812        Abe       Banks     Moss Point        PD        Part-Time
# 26024       Gary     Demaree  Ocean Springs        PD        Full-Time
# 5871    Clifford       Olson      Courtland        PD        Part-Time
# 22009       Rudy     Burnett            MDOT    State        Full-Time
# 17270      Buddy        East    Lafayette Co  Sheriff        Full-Time
# 35211    Michael      Bryant       Vicksburg       PD        Full-Time
# 27285    Michael    Whitmore      Pascagoula    Chief        Full-Time
# 22007    William     Bridges            MDOT    State        Full-Time
# 9518       Brian      Payne       Greenville       PD        Full-Time
# 24124     Ronald       Turan             MHP    State        Full-Time
# 29014    Robert        Poole        Pontotoc    Chief        Full-Time
#
#        start_date    end_date  person_nbr                        agency_name
# 28708  1962-10-15         NaN       13218         picayune police department
# 36984  1966-09-23  2007-06-30        2973                     wildlife state
# 763    1970-01-18  2008-06-30       19589           arcola police department
# 592    1970-01-20  2012-02-01       13277     alcorn county sheriff's office
# 16849  1970-06-20  2008-01-07       13211      jones county sheriff's office
# 36623  1970-11-07  2008-12-05        5170       west point police department
# 26046  1970-12-01  2005-01-27        4285    ocean springs police department
# 22783  1971-05-24  2013-10-01        1184         meridian police department
# 27430  1971-12-07  2011-12-08        1702   pass christian police department
# 24812  1972-03-29  2010-11-10       14980       moss point police department
# 26024  1972-05-31  2007-01-03        4278    ocean springs police department
# 5871   1972-07-01  2018-09-04       17473        courtland police department
# 22009  1972-07-10  2010-06-30        2788                         mdot state
# 17270  1972-08-22  2018-09-08        2802  lafayette county sheriff's office
# 35211  1972-09-22         NaN        8356        vicksburg police department
# 27285  1972-10-02  2007-06-29        1750                   pascagoula chief
# 22007  1973-01-15  2011-04-30        2778                         mdot state
# 9518   1973-03-06  2014-06-20       11961       greenville police department
# 24124  1973-04-20  2009-04-30        3549                          mhp state
# 29014  1973-05-01  2014-07-01        1835                     pontotoc chief

# %%
mississippi.columns
# Out:
# Index(['first_name', 'last_name', 'Agency', 'TYPE', 'employment_status',
#        'start_date', 'end_date', 'person_nbr', 'agency_name'],
#       dtype='object')

# %%
get_dept_counts(df=mississippi, id_column='person_nbr', agency_column='agency_name')

# %%
active_mississippi = get_active_officers_no_status(df=mississippi, id_column='person_nbr')

# %%
active_mississippi['person_nbr'].nunique()
# Out:
# 9657

# %%
# get active officers who have been at 3+ departments
ms_active_3plus = active_mississippi.loc[active_mississippi['number_of_unique_depts'] >= 3].copy()
ms_active_3plus['person_nbr'].nunique()
# Out:
# 2413

# %%
# get active officers who have been at 3+ departments
ms_active_5plus = active_mississippi.loc[active_mississippi['number_of_unique_depts'] >= 5].copy()
ms_active_5plus['person_nbr'].nunique()
# Out:
# 421

# %% [markdown]
# ***

# %% [markdown]
# ### __Illinois Analysis__

# %%
illinois = pd.read_csv('../npi_lookup/national-post-db/il/input/illinois_index.csv')

# %%
illinois_sorted = illinois.sort_values(by=['person_nbr', 'end_date'])

# %%
illinois_sorted.head()
# Out:
#         person_nbr  last_name first_name middle_name   race     sex  \
# 174985    65000001    A'Hearn     Daniel        John  White    Male
# 174986    65000002    A'Hearn         Jo         Ann  White  Female
# 174987    65000003      Aalto      Brian        John  White    Male
# 174988    65000004   Aanonsen      Linda         Kay  White  Female
# 174989    65000004   Aanonsen      Linda         Kay  White  Female
#
#         year_of_birth                     agency_name  start_date    end_date  \
# 174985           1944    Will County Sheriff's Office  1986-01-07  1986-10-06
# 174986           1946    Knox County Sheriff's Office  1979-04-09  2010-01-01
# 174987           1978       McHenry Police Department  2001-01-05         NaN
# 174988           1954  DuPage County Sheriff's Office  1998-12-28  2011-09-26
# 174989           1954  DuPage County Sheriff's Office  2011-09-26  2019-06-03
#
#        separation_reason             type     status                    rank  \
# 174985          Resigned  Law Enforcement  Full-Time                  Deputy
# 174986          Resigned  Law Enforcement  Full-Time                  Deputy
# 174987               NaN  Law Enforcement  Full-Time                Sergeant
# 174988   Other (Explain)     Correctional  Full-Time                  Deputy
# 174989           Retired   Court Security  Full-Time  Court Security Officer
#
#         number_of_depts  number_of_unique_depts
# 174985                1                       1
# 174986                1                       1
# 174987                1                       1
# 174988                2                       1
# 174989                2                       1

# %% [markdown]
# #### getting active officers

# %%
# using previously written function to get # of departments officer has been a part of
get_dept_counts(df=illinois_sorted, id_column='person_nbr', agency_column='agency_name')

# %%
active_illinois = get_active_officers_no_status(df=illinois, id_column='person_nbr')

# %%
active_illinois['person_nbr'].nunique()
# Out:
# 44892

# %% [markdown]
# there's 44,892 currently active officers in Illinois

# %%
# get active officers who have been at 3+ departments
il_active_3plus = active_illinois.loc[active_illinois['number_of_unique_depts'] >= 3].copy()
il_active_3plus['person_nbr'].nunique()
# Out:
# 6106

# %%
# get active officers who have been at 3+ departments
il_active_5plus = active_illinois.loc[active_illinois['number_of_unique_depts'] >= 5].copy()
il_active_5plus['person_nbr'].nunique()
# Out:
# 1466

# %% [markdown]
# Out of the 44,892 currently active officers in Illinois, 6,106 of them have had 3+ unique employers, and 1,466 have had 5+ unique employers.

# %%
active_illinois.value_counts('separation_reason')
# Out:
# separation_reason
# Resigned                             19595
# Other (Explain)                       8532
# Unknown                               2606
# Left For New Job                      1961
# Retired                               1956
# Terminated For Cause                  1169
# No Separation On File At Board         464
# Removed From Roster By Department      175
# Agency Disbanded                       156
# Automated                               71
# Deceased                                11
# Charged/Convicted Of Crime               9
# Disabled                                 1
# Name: count, dtype: int64

# %%
terminated_active_illinois = get_terminated_active(active_df=active_illinois, id_column='person_nbr', status_column='separation_reason', term_word='Terminated For Cause')
terminated_active_illinois['person_nbr'].nunique()
# Out:
# 1005

# %%
illinois.sort_values(by='start_date').head(10)
# Out:
#         person_nbr  last_name first_name middle_name  \
# 225912    65162444     Clover      Bryce           A
# 6739      65007833      Blake       Chad     Anthony
# 108493    65003915      Baker       Rolf      Fedder
# 223773    65105589   Williams     Eloise         NaN
# 121698    65066962      Moore    Michael       Shane
# 182850    65049657      Kando      Danny           E
# 167482    65030127   Fletcher      Brian      Joseph
# 9052      65025334     Draper      Jason           E
# 171632    65105959   Williams     Thomas         Lee
# 6308      65003487   Backshis       John           N
#
#                                     race   sex  year_of_birth  \
# 225912                             White  Male           2001
# 6739                               White  Male           1972
# 108493                             White  Male           1974
# 223773  Native American or Alaska Native  Male           1901
# 121698                             White  Male           1975
# 182850                             White  Male           1900
# 167482                             White  Male           1977
# 9052                               White  Male           1975
# 171632                             White  Male           1977
# 6308                               White  Male           1957
#
#                                         agency_name  start_date    end_date  \
# 225912              Jackson County Sheriff's Office  0203-07-24  2024-06-18
# 6739                             PTB Intern Program  1900-01-01  2010-01-01
# 108493                           PTB Intern Program  1900-01-01  2010-01-01
# 223773  Chicago Housing Authority Police Department  1900-01-01  1999-09-01
# 121698                           PTB Intern Program  1900-01-01  2010-01-01
# 182850                           PTB Intern Program  1900-01-01  2010-01-01
# 167482                           PTB Intern Program  1900-01-01  2010-01-01
# 9052                             PTB Intern Program  1900-01-01  2010-01-01
# 171632                           PTB Intern Program  1900-01-01  2010-01-01
# 6308                      Maywood Police Department  1900-01-01  2019-01-01
#
#                      separation_reason             type     status  \
# 225912                        Resigned     Correctional  Part-Time
# 6739                   Other (Explain)            Other    Unknown
# 108493                 Other (Explain)            Other    Unknown
# 223773                Agency Disbanded  Law Enforcement  Full-Time
# 121698                 Other (Explain)            Other    Unknown
# 182850                 Other (Explain)            Other    Unknown
# 167482                 Other (Explain)            Other    Unknown
# 9052                   Other (Explain)            Other    Unknown
# 171632                 Other (Explain)            Other    Unknown
# 6308    No Separation On File At Board            Other    Unknown
#
#                         rank
# 225912  Correctional Officer
# 6739                  Intern
# 108493                Intern
# 223773        Police Officer
# 121698                Intern
# 182850                Intern
# 167482                Intern
# 9052                  Intern
# 171632                Intern
# 6308             Unspecified

# %%
illinois_sorted.head()
# Out:
#         person_nbr  last_name first_name middle_name   race     sex  \
# 174985    65000001    A'Hearn     Daniel        John  White    Male
# 174986    65000002    A'Hearn         Jo         Ann  White  Female
# 174987    65000003      Aalto      Brian        John  White    Male
# 174988    65000004   Aanonsen      Linda         Kay  White  Female
# 174989    65000004   Aanonsen      Linda         Kay  White  Female
#
#         year_of_birth                     agency_name  start_date    end_date  \
# 174985           1944    Will County Sheriff's Office  1986-01-07  1986-10-06
# 174986           1946    Knox County Sheriff's Office  1979-04-09  2010-01-01
# 174987           1978       McHenry Police Department  2001-01-05         NaN
# 174988           1954  DuPage County Sheriff's Office  1998-12-28  2011-09-26
# 174989           1954  DuPage County Sheriff's Office  2011-09-26  2019-06-03
#
#        separation_reason             type     status                    rank  \
# 174985          Resigned  Law Enforcement  Full-Time                  Deputy
# 174986          Resigned  Law Enforcement  Full-Time                  Deputy
# 174987               NaN  Law Enforcement  Full-Time                Sergeant
# 174988   Other (Explain)     Correctional  Full-Time                  Deputy
# 174989           Retired   Court Security  Full-Time  Court Security Officer
#
#         number_of_depts  number_of_unique_depts
# 174985                1                       1
# 174986                1                       1
# 174987                1                       1
# 174988                2                       1
# 174989                2                       1

# %%
illinois_sorted.value_counts('separation_reason')
# Out:
# separation_reason
# Resigned                             60026
# Unknown                              44590
# Retired                              27362
# Other (Explain)                      19373
# Terminated For Cause                  7684
# No Separation On File At Board        7105
# Left For New Job                      6285
# Automated                             2788
# Agency Disbanded                      2518
# Deceased                              1546
# Removed From Roster By Department     1306
# Charged/Convicted Of Crime             181
# Disabled                                41
# Disqualified Part Time L. E.             4
# Decertified By Board                     1
# Name: count, dtype: int64

# %%
ill_test = terminated_active_5yrs_ill(illinois_sorted)

# %%
ill_test.head(20)
# Out:
#         person_nbr   last_name first_name middle_name  \
# 54417     65000149  Abukhudair      Gamal         NaN
# 54418     65000149  Abukhudair      Gamal         NaN
# 161890    65000264        Adam   Clifford           L
# 161888    65000264        Adam   Clifford           L
# 161891    65000264        Adam   Clifford           L
# 161889    65000264        Adam   Clifford           L
# 161896    65000264        Adam   Clifford           L
# 161898    65000264        Adam   Clifford           L
# 161899    65000264        Adam   Clifford           L
# 161892    65000264        Adam   Clifford           L
# 161901    65000264        Adam   Clifford           L
# 161897    65000264        Adam   Clifford           L
# 161893    65000264        Adam   Clifford           L
# 161894    65000264        Adam   Clifford           L
# 161900    65000264        Adam   Clifford           L
# 161895    65000264        Adam   Clifford           L
# 54876     65000452      Adcock      Brian       Keith
# 54878     65000452      Adcock      Brian       Keith
# 54877     65000452      Adcock      Brian       Keith
# 54879     65000452      Adcock      Brian       Keith
#
#                              race   sex  year_of_birth  \
# 54417                       White  Male           1982
# 54418                       White  Male           1982
# 161890  Black or African American  Male           1959
# 161888  Black or African American  Male           1959
# 161891  Black or African American  Male           1959
# 161889  Black or African American  Male           1959
# 161896  Black or African American  Male           1959
# 161898  Black or African American  Male           1959
# 161899  Black or African American  Male           1959
# 161892  Black or African American  Male           1959
# 161901  Black or African American  Male           1959
# 161897  Black or African American  Male           1959
# 161893  Black or African American  Male           1959
# 161894  Black or African American  Male           1959
# 161900  Black or African American  Male           1959
# 161895  Black or African American  Male           1959
# 54876                       White  Male           1975
# 54878                       White  Male           1975
# 54877                       White  Male           1975
# 54879                       White  Male           1975
#
#                                               agency_name start_date  \
# 54417             University Of Chicago Police Department 2011-12-30
# 54418   University of Illinois at Chicago Campus Polic... 2022-01-06
# 161890                         Abingdon Police Department 1998-12-07
# 161888                     Warren County Sheriff's Office 1992-06-29
# 161891                        Knoxville Police Department 2001-11-19
# 161889                           Alexis Police Department 1997-03-25
# 161896                     Warren County Sheriff's Office 2008-03-19
# 161898                          Oquawka Police Department 2016-10-23
# 161899                          Oquawka Police Department 2017-12-11
# 161892                  Henderson County Sheriff's Office 2022-08-05
# 161901                            Aledo Police Department 2021-07-08
# 161897                         Monmouth Police Department 1993-08-16
# 161893                  Henderson County Sheriff's Office 2022-09-07
# 161894                            Aledo Police Department 2023-01-06
# 161900                     Warren County Sheriff's Office 1993-08-16
# 161895                            Aledo Police Department 2023-01-27
# 54876                         Crestwood Police Department 1999-05-06
# 54878                        Bridgeview Police Department 2001-09-11
# 54877                        Palos Park Police Department 2001-01-02
# 54879                Moraine Valley C C Police Department 2004-02-02
#
#          end_date     separation_reason             type  \
# 54417  2012-04-24  Terminated For Cause  Law Enforcement
# 54418  2022-12-13              Resigned  Law Enforcement
# 161890 2001-12-14      Left For New Job  Law Enforcement
# 161888 2010-01-01               Unknown  Law Enforcement
# 161891 2013-05-17       Other (Explain)  Law Enforcement
# 161889 2015-02-10  Terminated For Cause  Law Enforcement
# 161896 2016-10-13              Resigned  Law Enforcement
# 161898 2017-10-10       Other (Explain)  Law Enforcement
# 161899 2021-07-01       Other (Explain)  Law Enforcement
# 161892 2022-09-06       Other (Explain)  Law Enforcement
# 161901 2022-09-06              Resigned  Law Enforcement
# 161897 2022-12-31              Resigned        Auxiliary
# 161893 2023-01-04       Other (Explain)  Law Enforcement
# 161894 2023-01-27       Other (Explain)  Law Enforcement
# 161900 2023-02-02              Resigned        Auxiliary
# 161895        NaT                   NaN  Law Enforcement
# 54876  2001-10-01              Resigned  Law Enforcement
# 54878  2002-03-20  Terminated For Cause  Law Enforcement
# 54877  2003-08-01              Resigned  Law Enforcement
# 54879  2005-09-09              Resigned  Law Enforcement
#
#                          status               rank  number_of_depts  \
# 54417                 Full-Time     Police Officer                2
# 54418                 Full-Time     Police Officer                2
# 161890                Part-Time     Police Officer               14
# 161888                Full-Time           Sergeant               14
# 161891                Part-Time     Police Officer               14
# 161889                Part-Time     Police Officer               14
# 161896                Part-Time             Deputy               14
# 161898                Part-Time     Police Officer               14
# 161899                Full-Time              Chief               14
# 161892                Part-Time             Deputy               14
# 161901                Full-Time     Police Officer               14
# 161897  Auxiliary with Firearms  Auxiliary Officer               14
# 161893                Full-Time           Sergeant               14
# 161894                Part-Time     Police Officer               14
# 161900  Auxiliary with Firearms  Auxiliary Officer               14
# 161895                Full-Time     Police Officer               14
# 54876                 Part-Time           Sergeant               10
# 54878                 Part-Time     Police Officer               10
# 54877                 Part-Time     Police Officer               10
# 54879                 Part-Time     Police Officer               10
#
#         number_of_unique_depts
# 54417                        2
# 54418                        2
# 161890                       8
# 161888                       8
# 161891                       8
# 161889                       8
# 161896                       8
# 161898                       8
# 161899                       8
# 161892                       8
# 161901                       8
# 161897                       8
# 161893                       8
# 161894                       8
# 161900                       8
# 161895                       8
# 54876                        7
# 54878                        7
# 54877                        7
# 54879                        7

# %%
ill_depts_after_term = departments_after_termination_ill(ill_test)
# Out:
#    person_nbr   last_name first_name middle_name   race   sex  year_of_birth  \
# 0    65000149  Abukhudair      Gamal         NaN  White  Male           1982
# 1    65000149  Abukhudair      Gamal         NaN  White  Male           1982
#
#                                          agency_name start_date   end_date  \
# 0            University Of Chicago Police Department 2011-12-30 2012-04-24
# 1  University of Illinois at Chicago Campus Polic... 2022-01-06 2022-12-13
#
#       separation_reason             type     status            rank  \
# 0  Terminated For Cause  Law Enforcement  Full-Time  Police Officer
# 1              Resigned  Law Enforcement  Full-Time  Police Officer
#
#    number_of_depts  number_of_unique_depts
# 0                2                       2
# 1                2                       2
# TERMINATION INDEX:  Index([0], dtype='int64')
# CURRENT TERM SPOT:  0
# AGENCY AFTER TERM:  University of Illinois at Chicago Campus Police Department
#     person_nbr  last_name first_name middle_name                       race  \
# 0     65000264       Adam   Clifford           L  Black or African American
# 1     65000264       Adam   Clifford           L  Black or African American
# 2     65000264       Adam   Clifford           L  Black or African American
# 3     65000264       Adam   Clifford           L  Black or African American
# 4     65000264       Adam   Clifford           L  Black or African American
# 5     65000264       Adam   Clifford           L  Black or African American
# 6     65000264       Adam   Clifford           L  Black or African American
# 7     65000264       Adam   Clifford           L  Black or African American
# 8     65000264       Adam   Clifford           L  Black or African American
# 9     65000264       Adam   Clifford           L  Black or African American
# 10    65000264       Adam   Clifford           L  Black or African American
# 11    65000264       Adam   Clifford           L  Black or African American
# 12    65000264       Adam   Clifford           L  Black or African American
# 13    65000264       Adam   Clifford           L  Black or African American
#
#      sex  year_of_birth                        agency_name start_date  \
# 0   Male           1959         Abingdon Police Department 1998-12-07
# 1   Male           1959     Warren County Sheriff's Office 1992-06-29
# 2   Male           1959        Knoxville Police Department 2001-11-19
# 3   Male           1959           Alexis Police Department 1997-03-25
# 4   Male           1959     Warren County Sheriff's Office 2008-03-19
# 5   Male           1959          Oquawka Police Department 2016-10-23
# 6   Male           1959          Oquawka Police Department 2017-12-11
# 7   Male           1959  Henderson County Sheriff's Office 2022-08-05
# 8   Male           1959            Aledo Police Department 2021-07-08
# 9   Male           1959         Monmouth Police Department 1993-08-16
# 10  Male           1959  Henderson County Sheriff's Office 2022-09-07
# 11  Male           1959            Aledo Police Department 2023-01-06
# 12  Male           1959     Warren County Sheriff's Office 1993-08-16
# 13  Male           1959            Aledo Police Department 2023-01-27
#
#      end_date     separation_reason             type                   status  \
# 0  2001-12-14      Left For New Job  Law Enforcement                Part-Time
# 1  2010-01-01               Unknown  Law Enforcement                Full-Time
# 2  2013-05-17       Other (Explain)  Law Enforcement                Part-Time
# 3  2015-02-10  Terminated For Cause  Law Enforcement                Part-Time
# 4  2016-10-13              Resigned  Law Enforcement                Part-Time
# 5  2017-10-10       Other (Explain)  Law Enforcement                Part-Time
# 6  2021-07-01       Other (Explain)  Law Enforcement                Full-Time
# 7  2022-09-06       Other (Explain)  Law Enforcement                Part-Time
# 8  2022-09-06              Resigned  Law Enforcement                Full-Time
# 9  2022-12-31              Resigned        Auxiliary  Auxiliary with Firearms
# 10 2023-01-04       Other (Explain)  Law Enforcement                Full-Time
# 11 2023-01-27       Other (Explain)  Law Enforcement                Part-Time
# 12 2023-02-02              Resigned        Auxiliary  Auxiliary with Firearms
# 13        NaT                   NaN  Law Enforcement                Full-Time
#
#                  rank  number_of_depts  number_of_unique_depts
# 0      Police Officer               14                       8
# 1            Sergeant               14                       8
# 2      Police Officer               14                       8
# 3      Police Officer               14                       8
# 4              Deputy               14                       8
# 5      Police Officer               14                       8
# 6               Chief               14                       8
# 7              Deputy               14                       8
# 8      Police Officer               14                       8
# 9   Auxiliary Officer               14                       8
# 10           Sergeant               14                       8
# 11     Police Officer               14                       8
# 12  Auxiliary Officer               14                       8
# 13     Police Officer               14                       8
# TERMINATION INDEX:  Index([3], dtype='int64')
# CURRENT TERM SPOT:  3
# OFFICER START DATE AT NEXT PLACE IS BEFORE END DATE AT TERMINATED PLACE
#    person_nbr  last_name first_name middle_name   race   sex  year_of_birth  \
# 0    65000452     Adcock      Brian       Keith  White  Male           1975
# 1    65000452     Adcock      Brian       Keith  White  Male           1975
# 2    65000452     Adcock      Brian       Keith  White  Male           1975
# 3    65000452     Adcock      Brian       Keith  White  Male           1975
# 4    65000452     Adcock      Brian       Keith  White  Male           1975
# 5    65000452     Adcock      Brian       Keith  White  Male           1975
# 6    65000452     Adcock      Brian       Keith  White  Male           1975
# 7    65000452     Adcock      Brian       Keith  White  Male           1975
# 8    65000452     Adcock      Brian       Keith  White  Male           1975
# 9    65000452     Adcock      Brian       Keith  White  Male           1975
#
#                             agency_name start_date   end_date  \
# 0           Crestwood Police Department 1999-05-06 2001-10-01
# 1          Bridgeview Police Department 2001-09-11 2002-03-20
# 2          Palos Park Police Department 2001-01-02 2003-08-01
# 3  Moraine Valley C C Police Department 2004-02-02 2005-09-09
# 4  Moraine Valley C C Police Department 2007-01-29 2012-05-18
# 5         Forest View Police Department 2013-12-24 2017-05-04
# 6   College of DuPage Police Department 2013-09-23 2018-01-29
# 7           Manhattan Police Department 2017-05-02 2019-08-19
# 8           Crestwood Police Department 2019-07-18 2021-09-30
# 9          Palos Park Police Department 2021-10-05        NaT
#
#       separation_reason             type     status            rank  \
# 0              Resigned  Law Enforcement  Part-Time        Sergeant
# 1  Terminated For Cause  Law Enforcement  Part-Time  Police Officer
# 2              Resigned  Law Enforcement  Part-Time  Police Officer
# 3              Resigned  Law Enforcement  Part-Time  Police Officer
# 4              Resigned  Law Enforcement  Part-Time  Police Officer
# 5              Resigned  Law Enforcement  Part-Time  Police Officer
# 6              Resigned  Law Enforcement  Part-Time  Police Officer
# 7              Resigned  Law Enforcement  Part-Time  Police Officer
# 8              Resigned  Law Enforcement  Part-Time  Police Officer
# 9                   NaN  Law Enforcement  Part-Time  Police Officer
#
#    number_of_depts  number_of_unique_depts
# 0               10                       7
# 1               10                       7
# 2               10                       7
# 3               10                       7
# 4               10                       7
# 5               10                       7
# 6               10                       7
# 7               10                       7
# 8               10                       7
# 9               10                       7
# TERMINATION INDEX:  Index([1], dtype='int64')
# CURRENT TERM SPOT:  1
# OFFICER START DATE AT NEXT PLACE IS BEFORE END DATE AT TERMINATED PLACE
#    person_nbr  last_name first_name middle_name   race   sex  year_of_birth  \
# 0    65000574       Agee    Russell           D  White  Male           1960
# 1    65000574       Agee    Russell           D  White  Male           1960
# 2    65000574       Agee    Russell           D  White  Male           1960
# 3    65000574       Agee    Russell           D  White  Male           1960
#
#                        agency_name start_date   end_date  \
# 0     Brownstown Police Department 1999-11-01 2000-02-15
# 1  Fayette County Sheriff's Office 1999-11-01 2000-04-01
# 2    Bourbonnais Police Department 1985-04-01 2010-01-01
# 3  Fayette County Sheriff's Office 2000-04-01 2019-06-10
#
#       separation_reason             type     status                  rank  \
# 0  Terminated For Cause  Law Enforcement  Part-Time        Police Officer
# 1       Other (Explain)            Other  Part-Time      Telecommunicator
# 2              Resigned  Law Enforcement  Part-Time        Police Officer
# 3               Retired     Correctional  Full-Time  Correctional Officer
#
#    number_of_depts  number_of_unique_depts
# 0                4                       3
# 1                4                       3
# 2                4                       3
# 3                4                       3
# TERMINATION INDEX:  Index([0], dtype='int64')
# CURRENT TERM SPOT:  0
# OFFICER START DATE AT NEXT PLACE IS BEFORE END DATE AT TERMINATED PLACE
#    person_nbr  last_name first_name middle_name   race   sex  year_of_birth  \
# 0    65000667    Agustin     Donald      Joseph  White  Male           1963
# 1    65000667    Agustin     Donald      Joseph  White  Male           1963
# 2    65000667    Agustin     Donald      Joseph  White  Male           1963
# 3    65000667    Agustin     Donald      Joseph  White  Male           1963
#
#                       agency_name start_date   end_date     separation_reason  \
# 0  DuPage County Sheriff's Office 2009-01-05 2011-06-10       Other (Explain)
# 1  DuPage County Sheriff's Office 2011-06-13 2011-12-09  Terminated For Cause
# 2  DuPage County Sheriff's Office 2011-12-09 2017-09-24       Other (Explain)
# 3  DuPage County Sheriff's Office 2017-09-25 2024-05-13  Terminated For Cause
#
#               type     status                    rank  number_of_depts  \
# 0     Correctional  Full-Time                  Deputy                4
# 1  Law Enforcement  Full-Time                  Deputy                4
# 2     Correctional  Full-Time    Correctional Officer                4
# 3   Court Security  Full-Time  Court Security Officer                4
#
#    number_of_unique_depts
# 0                       1
# 1                       1
# 2                       1
# 3                       1
# TERMINATION INDEX:  Index([1, 3], dtype='int64')
# CURRENT TERM SPOT:  1
# OFFICER START DATE AT NEXT PLACE IS BEFORE END DATE AT TERMINATED PLACE
# CURRENT TERM SPOT:  3
# TERMINATION IS LAST THING IN OFFICERS HISTORY
#    person_nbr  last_name first_name middle_name   race   sex  year_of_birth  \
# 0    65000690     Ahlers       Kent     William  White  Male           1967
# 1    65000690     Ahlers       Kent     William  White  Male           1967
# 2    65000690     Ahlers       Kent     William  White  Male           1967
# 3    65000690     Ahlers       Kent     William  White  Male           1967
# 4    65000690     Ahlers       Kent     William  White  Male           1967
# 5    65000690     Ahlers       Kent     William  White  Male           1967
# 6    65000690     Ahlers       Kent     William  White  Male           1967
# 7    65000690     Ahlers       Kent     William  White  Male           1967
# 8    65000690     Ahlers       Kent     William  White  Male           1967
# 9    65000690     Ahlers       Kent     William  White  Male           1967
#
#                            agency_name start_date   end_date  \
# 0                 Pre-Service Training 1901-01-01 1998-02-11
# 1             Shiloh Police Department 1901-01-01 1998-02-11
# 2   Washington County Sheriff's Office 1999-02-01 2000-12-13
# 3          Okawville Police Department 1996-02-29 2001-06-08
# 4           Freeburg Police Department 2001-06-18 2001-11-29
# 5           Smithton Police Department 1992-03-19 2010-01-01
# 6           Freeburg Police Department 2001-11-30 2011-03-07
# 7   Washington County Sheriff's Office 2013-01-28 2020-04-12
# 8          Nashville Police Department 2011-08-10 2020-07-02
# 9  Saint Clair County Sheriff's Office 2020-04-12        NaT
#
#       separation_reason             type     status                    rank  \
# 0               Unknown  Law Enforcement  Full-Time          Police Officer
# 1               Unknown  Law Enforcement  Full-Time          Police Officer
# 2       Other (Explain)  Law Enforcement  Part-Time                  Deputy
# 3       Other (Explain)  Law Enforcement  Full-Time                Sergeant
# 4       Other (Explain)  Law Enforcement  Part-Time          Police Officer
# 5              Resigned  Law Enforcement  Full-Time          Police Officer
# 6  Terminated For Cause  Law Enforcement  Full-Time          Police Officer
# 7              Resigned   Court Security  Full-Time  Court Security Officer
# 8              Resigned  Law Enforcement  Part-Time          Police Officer
# 9                   NaN  Law Enforcement  Full-Time                  Deputy
#
#    number_of_depts  number_of_unique_depts
# 0               10                       8
# 1               10                       8
# 2               10                       8
# 3               10                       8
# 4               10                       8
# 5               10                       8
# 6               10                       8
# 7               10                       8
# 8               10                       8
# 9               10                       8
# TERMINATION INDEX:  Index([6], dtype='int64')
# CURRENT TERM SPOT:  6
# AGENCY AFTER TERM:  Washington County Sheriff's Office
#    person_nbr  last_name first_name middle_name   race   sex  year_of_birth  \
# 0    65000744     Ainley       Troy           P  White  Male           1970
# 1    65000744     Ainley       Troy           P  White  Male           1970
# 2    65000744     Ainley       Troy           P  White  Male           1970
# 3    65000744     Ainley       Troy           P  White  Male           1970
# 4    65000744     Ainley       Troy           P  White  Male           1970
# 5    65000744     Ainley       Troy           P  White  Male           1970
# 6    65000744     Ainley       Troy           P  White  Male           1970
# 7    65000744     Ainley       Troy           P  White  Male           1970
#
#                                agency_name start_date   end_date  \
# 0  Kewanee Park District Police Department 1995-07-01 1997-06-22
# 1               Atkinson Police Department 1997-03-05 1997-07-31
# 2                Kewanee Police Department 1995-08-19 2010-01-01
# 3                Kewanee Police Department 1997-06-22 2010-01-01
# 4                Kewanee Police Department 1997-11-01 2020-11-03
# 5     Black Hawk College Police Department 2020-11-16 2021-06-30
# 6     Black Hawk College Police Department 2021-10-17 2022-03-19
# 7     Black Hawk College Police Department 2022-03-20        NaT
#
#       separation_reason             type  \
# 0  Terminated For Cause  Law Enforcement
# 1      Left For New Job  Law Enforcement
# 2               Unknown        Auxiliary
# 3       Other (Explain)  Law Enforcement
# 4               Retired  Law Enforcement
# 5       Other (Explain)  Law Enforcement
# 6       Other (Explain)  Law Enforcement
# 7                   NaN  Law Enforcement
#
#                                   status               rank  number_of_depts  \
# 0                              Part-Time     Police Officer                8
# 1                              Part-Time     Police Officer                8
# 2  Auxiliary (Used prior to P.A. 94-984)  Auxiliary Officer                8
# 3                              Part-Time     Police Officer                8
# 4                              Full-Time              Chief                8
# 5                              Part-Time     Police Officer                8
# 6                              Part-Time     Police Officer                8
# 7                              Full-Time     Police Officer                8
#
#    number_of_unique_depts
# 0                       4
# 1                       4
# 2                       4
# 3                       4
# 4                       4
# 5                       4
# 6                       4
# 7                       4
# TERMINATION INDEX:  Index([0], dtype='int64')
# CURRENT TERM SPOT:  0
# OFFICER START DATE AT NEXT PLACE IS BEFORE END DATE AT TERMINATED PLACE
#    person_nbr  last_name first_name middle_name   race   sex  year_of_birth  \
# 0    65000889  Alblinger    Patrick           K  White  Male           1962
# 1    65000889  Alblinger    Patrick           K  White  Male           1962
# 2    65000889  Alblinger    Patrick           K  White  Male           1962
# 3    65000889  Alblinger    Patrick           K  White  Male           1962
# 4    65000889  Alblinger    Patrick           K  White  Male           1962
# 5    65000889  Alblinger    Patrick           K  White  Male           1962
#
#                          agency_name start_date   end_date  \
# 0        Westville Police Department 1998-05-11 1998-10-06
# 1          Oakwood Police Department 2000-10-21 2001-12-29
# 2           Catlin Police Department 2001-01-23 2002-07-31
# 3        Westville Police Department 1901-01-01 2010-01-01
# 4      Vermilion Co State's Attorney 2003-03-25 2019-02-26
# 5  Vermilion County Sheriff's Office 1993-08-23        NaT
#
#       separation_reason             type     status            rank  \
# 0  Terminated For Cause  Law Enforcement  Part-Time  Police Officer
# 1              Resigned  Law Enforcement  Part-Time  Police Officer
# 2              Resigned  Law Enforcement  Part-Time  Police Officer
# 3               Unknown  Law Enforcement  Full-Time  Police Officer
# 4              Resigned            Other  Part-Time             NaN
# 5                   NaN  Law Enforcement  Full-Time          Deputy
#
#    number_of_depts  number_of_unique_depts
# 0                6                       5
# 1                6                       5
# 2                6                       5
# 3                6                       5
# 4                6                       5
# 5                6                       5
# TERMINATION INDEX:  Index([0], dtype='int64')
# CURRENT TERM SPOT:  0
# AGENCY AFTER TERM:  Oakwood Police Department
#    person_nbr  last_name first_name middle_name   race   sex  year_of_birth  \
# 0    65000893   Albrecht     Andrew     Gilbert  White  Male           1987
# 1    65000893   Albrecht     Andrew     Gilbert  White  Male           1987
# 2    65000893   Albrecht     Andrew     Gilbert  White  Male           1987
#
#                           agency_name start_date   end_date  \
# 0      DuPage County Sheriff's Office 2010-04-12 2010-05-21
# 1          Berkeley Police Department 2012-12-26 2022-02-15
# 2  Round Lake Beach Police Department 2022-02-21        NaT
#
#       separation_reason             type     status                  rank  \
# 0  Terminated For Cause     Correctional  Full-Time  Correctional Officer
# 1              Resigned  Law Enforcement  Full-Time        Police Officer
# 2                   NaN  Law Enforcement  Full-Time        Police Officer
#
#    number_of_depts  number_of_unique_depts
# 0                3                       3
# 1                3                       3
# 2                3                       3
# TERMINATION INDEX:  Index([0], dtype='int64')
# CURRENT TERM SPOT:  0
# AGENCY AFTER TERM:  Berkeley Police Department
#    person_nbr  last_name first_name middle_name   race   sex  year_of_birth  \
# 0    65000909   Albright    Michael        Kent  White  Male           1960
# 1    65000909   Albright    Michael        Kent  White  Male           1960
# 2    65000909   Albright    Michael        Kent  White  Male           1960
# 3    65000909   Albright    Michael        Kent  White  Male           1960
# 4    65000909   Albright    Michael        Kent  White  Male           1960
# 5    65000909   Albright    Michael        Kent  White  Male           1960
#
#                           agency_name start_date   end_date  \
# 0           Pulaski Police Department 2004-12-03 2005-01-10
# 1            Mounds Police Department 2005-05-06 2005-06-30
# 2             Ullin Police Department 2004-12-30 2006-05-18
# 3             Ullin Police Department 1901-01-01 2010-01-01
# 4  Williamson County Sheriff's Office 2022-11-07 2023-01-23
# 5     Johnston City Police Department 2001-05-22        NaT
#
#       separation_reason             type                   status  \
# 0  Terminated For Cause  Law Enforcement                Part-Time
# 1              Resigned  Law Enforcement                Part-Time
# 2       Other (Explain)  Law Enforcement                Part-Time
# 3               Unknown  Law Enforcement                Full-Time
# 4              Resigned   Court Security                Part-Time
# 5                   NaN        Auxiliary  Auxiliary with Firearms
#
#                      rank  number_of_depts  number_of_unique_depts
# 0          Police Officer                6                       5
# 1          Police Officer                6                       5
# 2          Police Officer                6                       5
# 3          Police Officer                6                       5
# 4  Court Security Officer                6                       5
# 5       Auxiliary Officer                6                       5
# TERMINATION INDEX:  Index([0], dtype='int64')
# CURRENT TERM SPOT:  0
# AGENCY AFTER TERM:  Mounds Police Department
#     person_nbr  last_name first_name middle_name   race   sex  year_of_birth  \
# 0     65001415     Allsup    Michael       Scott  White  Male           1969
# 1     65001415     Allsup    Michael       Scott  White  Male           1969
# 2     65001415     Allsup    Michael       Scott  White  Male           1969
# 3     65001415     Allsup    Michael       Scott  White  Male           1969
# 4     65001415     Allsup    Michael       Scott  White  Male           1969
# 5     65001415     Allsup    Michael       Scott  White  Male           1969
# 6     65001415     Allsup    Michael       Scott  White  Male           1969
# 7     65001415     Allsup    Michael       Scott  White  Male           1969
# 8     65001415     Allsup    Michael       Scott  White  Male           1969
# 9     65001415     Allsup    Michael       Scott  White  Male           1969
# 10    65001415     Allsup    Michael       Scott  White  Male           1969
# 11    65001415     Allsup    Michael       Scott  White  Male           1969
# 12    65001415     Allsup    Michael       Scott  White  Male           1969
# 13    65001415     Allsup    Michael       Scott  White  Male           1969
# 14    65001415     Allsup    Michael       Scott  White  Male           1969
# 15    65001415     Allsup    Michael       Scott  White  Male           1969
# 16    65001415     Allsup    Michael       Scott  White  Male           1969
#
#                       agency_name start_date   end_date     separation_reason  \
# 0      Washburn Police Department 1999-01-03 1999-10-01              Resigned
# 1         Lacon Police Department 1999-06-14 2000-03-30  Terminated For Cause
# 2   Bloomington Police Department 2005-08-01 2005-12-22  Terminated For Cause
# 3        Toluca Police Department 2006-01-28 2006-06-21              Resigned
# 4         Lacon Police Department 1999-05-10 2010-01-01               Unknown
# 5        Minonk Police Department 2010-10-15 2011-09-20              Resigned
# 6        Chenoa Police Department 2006-02-03 2014-12-02              Resigned
# 7        Colfax Police Department 2013-05-07 2015-04-09              Resigned
# 8        Manito Police Department 2018-02-16 2018-06-12              Resigned
# 9          Avon Police Department 2017-03-14 2019-01-02              Resigned
# 10   Farmington Police Department 2018-09-13 2019-01-25       Other (Explain)
# 11   Farmington Police Department 2019-01-26 2019-10-04       Other (Explain)
# 12     Fairview Police Department 2018-07-02 2020-07-17       Other (Explain)
# 13       Manito Police Department 2020-05-18 2023-04-03  Terminated For Cause
# 14  Forest City Police Department 2022-11-28 2024-01-18              Resigned
# 15   Deer Creek Police Department 2023-08-30 2024-04-18              Resigned
# 16      Astoria Police Department 2024-01-04        NaT                   NaN
#
#                type     status            rank  number_of_depts  \
# 0   Law Enforcement  Part-Time  Police Officer               17
# 1   Law Enforcement  Full-Time  Police Officer               17
# 2   Law Enforcement  Full-Time  Police Officer               17
# 3   Law Enforcement  Part-Time  Police Officer               17
# 4   Law Enforcement  Part-Time  Police Officer               17
# 5   Law Enforcement  Part-Time  Police Officer               17
# 6   Law Enforcement  Part-Time  Police Officer               17
# 7   Law Enforcement  Part-Time  Police Officer               17
# 8   Law Enforcement  Part-Time  Police Officer               17
# 9   Law Enforcement  Part-Time  Police Officer               17
# 10  Law Enforcement  Part-Time  Police Officer               17
# 11  Law Enforcement  Full-Time  Police Officer               17
# 12  Law Enforcement  Part-Time  Police Officer               17
# 13  Law Enforcement  Part-Time  Police Officer               17
# 14  Law Enforcement  Part-Time  Police Officer               17
# 15  Law Enforcement  Part-Time  Police Officer               17
# 16  Law Enforcement  Full-Time           Chief               17
#
#     number_of_unique_depts
# 0                       14
# 1                       14
# 2                       14
# 3                       14
# 4                       14
# 5                       14
# 6                       14
# 7                       14
# 8                       14
# 9                       14
# 10                      14
# 11                      14
# 12                      14
# 13                      14
# 14                      14
# 15                      14
# 16                      14
# TERMINATION INDEX:  Index([1, 2, 13], dtype='int64')
# CURRENT TERM SPOT:  1
# AGENCY AFTER TERM:  Bloomington Police Department
# CURRENT TERM SPOT:  2
# AGENCY AFTER TERM:  Toluca Police Department
# CURRENT TERM SPOT:  13
# OFFICER START DATE AT NEXT PLACE IS BEFORE END DATE AT TERMINATED PLACE
#    person_nbr  last_name first_name middle_name                race   sex  \
# 0    65001450    Almeida       Pete         NaN  Hispanic or Latino  Male
# 1    65001450    Almeida       Pete         NaN  Hispanic or Latino  Male
# 2    65001450    Almeida       Pete         NaN  Hispanic or Latino  Male
#
#    year_of_birth                 agency_name start_date   end_date  \
# 0           1964     Elgin Police Department 1990-07-30 2009-06-01
# 1           1964  Bartlett Police Department 1901-01-01 2010-01-01
# 2           1964  Cortland Police Department 2020-01-27 2021-10-04
#
#       separation_reason             type     status            rank  \
# 0  Terminated For Cause  Law Enforcement  Full-Time        Sergeant
# 1               Unknown  Law Enforcement  Full-Time  Police Officer
# 2              Resigned  Law Enforcement  Part-Time  Police Officer
#
#    number_of_depts  number_of_unique_depts
# 0                3                       3
# 1                3                       3
# 2                3                       3
# TERMINATION INDEX:  Index([0], dtype='int64')
# CURRENT TERM SPOT:  0
# OFFICER START DATE AT NEXT PLACE IS BEFORE END DATE AT TERMINATED PLACE
#    person_nbr  last_name first_name middle_name   race     sex  year_of_birth  \
# 0    65001594    Alvarez      Robin     Heather  White  Female           1980
# 1    65001594    Alvarez      Robin     Heather  White  Female           1980
#
#                     agency_name start_date   end_date     separation_reason  \
# 0  Lake County Sheriff's Office 2003-12-29 2014-09-15  Terminated For Cause
# 1  Lake County Sheriff's Office 2015-08-12 2024-01-10  Terminated For Cause
#
#            type     status                  rank  number_of_depts  \
# 0  Correctional  Full-Time  Correctional Officer                2
# 1  Correctional  Full-Time  Correctional Officer                2
#
#    number_of_unique_depts
# 0                       1
# 1                       1
# TERMINATION INDEX:  Index([0, 1], dtype='int64')
# CURRENT TERM SPOT:  0
# AGENCY AFTER TERM:  Lake County Sheriff's Office
# CURRENT TERM SPOT:  1
# TERMINATION IS LAST THING IN OFFICERS HISTORY
#    person_nbr  last_name first_name middle_name   race   sex  year_of_birth  \
# 0    65001740     Amschl    Garrick           K  White  Male           1973
# 1    65001740     Amschl    Garrick           K  White  Male           1973
# 2    65001740     Amschl    Garrick           K  White  Male           1973
# 3    65001740     Amschl    Garrick           K  White  Male           1973
#
#                                agency_name start_date   end_date  \
# 0               Freeport Police Department 1996-01-08 1996-04-29
# 1  Joliet Junior College Police Department 1996-09-01 1997-02-12
# 2           Sauk Village Police Department 1997-01-28 2010-01-01
# 3         Olympia Fields Police Department 1998-01-16 2021-10-05
#
#       separation_reason             type     status             rank  \
# 0              Resigned  Law Enforcement  Full-Time   Police Officer
# 1  Terminated For Cause  Law Enforcement  Part-Time   Police Officer
# 2      Left For New Job  Law Enforcement  Part-Time  Reserve Officer
# 3               Retired  Law Enforcement  Full-Time         Corporal
#
#    number_of_depts  number_of_unique_depts
# 0                4                       4
# 1                4                       4
# 2                4                       4
# 3                4                       4
# TERMINATION INDEX:  Index([1], dtype='int64')
# CURRENT TERM SPOT:  1
# OFFICER START DATE AT NEXT PLACE IS BEFORE END DATE AT TERMINATED PLACE
#    person_nbr  last_name first_name middle_name                       race  \
# 0    65001818   Anderson    Antoine       Lavon  Black or African American
# 1    65001818   Anderson    Antoine       Lavon  Black or African American
# 2    65001818   Anderson    Antoine       Lavon  Black or African American
# 3    65001818   Anderson    Antoine       Lavon  Black or African American
# 4    65001818   Anderson    Antoine       Lavon  Black or African American
# 5    65001818   Anderson    Antoine       Lavon  Black or African American
# 6    65001818   Anderson    Antoine       Lavon  Black or African American
#
#     sex  year_of_birth                           agency_name start_date  \
# 0  Male           1986  Country Club Hills Police Department 2009-08-03
# 1  Male           1986             Markham Police Department 2012-03-28
# 2  Male           1986             Dixmoor Police Department 2015-01-01
# 3  Male           1986              Harvey Police Department 2015-03-24
# 4  Male           1986             Phoenix Police Department 2018-04-24
# 5  Male           1986      Chicago Heights Park District PD 2021-01-19
# 6  Male           1986              Harvey Police Department 2022-01-24
#
#     end_date     separation_reason             type     status  \
# 0 2011-09-30  Terminated For Cause  Law Enforcement  Part-Time
# 1 2015-03-30              Resigned  Law Enforcement  Part-Time
# 2 2015-04-17              Resigned  Law Enforcement  Full-Time
# 3 2018-05-23              Resigned  Law Enforcement  Full-Time
# 4 2020-07-28  Terminated For Cause  Law Enforcement  Part-Time
# 5 2021-09-02       Other (Explain)  Law Enforcement  Part-Time
# 6        NaT                   NaN  Law Enforcement  Full-Time
#
#              rank  number_of_depts  number_of_unique_depts
# 0  Police Officer                7                       6
# 1  Police Officer                7                       6
# 2  Police Officer                7                       6
# 3  Police Officer                7                       6
# 4    Deputy Chief                7                       6
# 5  Police Officer                7                       6
# 6       Commander                7                       6
# TERMINATION INDEX:  Index([0, 4], dtype='int64')
# CURRENT TERM SPOT:  0
# AGENCY AFTER TERM:  Markham Police Department
# CURRENT TERM SPOT:  4
# AGENCY AFTER TERM:  Chicago Heights Park District PD
#    person_nbr  last_name first_name middle_name   race   sex  year_of_birth  \
# 0    65001845   Anderson      Craig        Alan  White  Male           1967
# 1    65001845   Anderson      Craig        Alan  White  Male           1967
#
#                  agency_name start_date   end_date     separation_reason  \
# 0   Newman Police Department 1996-09-10 1997-04-23  Terminated For Cause
# 1  Bradley Police Department 2000-03-26 2022-03-31               Retired
#
#               type     status            rank  number_of_depts  \
# 0  Law Enforcement  Part-Time  Police Officer                2
# 1  Law Enforcement  Full-Time    Deputy Chief                2
#
#    number_of_unique_depts
# 0                       2
# 1                       2
# TERMINATION INDEX:  Index([0], dtype='int64')
# CURRENT TERM SPOT:  0
# AGENCY AFTER TERM:  Bradley Police Department
#    person_nbr  last_name first_name middle_name   race   sex  year_of_birth  \
# 0    65001865   Anderson       Dean       Allen  White  Male           1987
# 1    65001865   Anderson       Dean       Allen  White  Male           1987
# 2    65001865   Anderson       Dean       Allen  White  Male           1987
# 3    65001865   Anderson       Dean       Allen  White  Male           1987
# 4    65001865   Anderson       Dean       Allen  White  Male           1987
# 5    65001865   Anderson       Dean       Allen  White  Male           1987
# 6    65001865   Anderson       Dean       Allen  White  Male           1987
#
#                          agency_name start_date   end_date  \
# 0          Alorton Police Department 2008-10-21 2010-03-07
# 1          Alorton Police Department 2010-03-07 2012-03-28
# 2       New Athens Police Department 2011-10-26 2013-03-06
# 3         Brooklyn Police Department 2012-04-01 2013-03-25
# 4  Washington Park Police Department 2013-08-13 2014-01-15
# 5           Tilden Police Department 2020-07-24 2021-12-30
# 6        Gillespie Police Department 2022-01-10 2022-05-04
#
#       separation_reason             type     status            rank  \
# 0       Other (Explain)  Law Enforcement  Part-Time  Police Officer
# 1  Terminated For Cause  Law Enforcement  Full-Time  Police Officer
# 2              Resigned  Law Enforcement  Part-Time  Police Officer
# 3              Resigned  Law Enforcement  Full-Time  Police Officer
# 4              Resigned  Law Enforcement  Part-Time  Police Officer
# 5              Resigned  Law Enforcement  Part-Time  Police Officer
# 6              Resigned  Law Enforcement  Full-Time  Police Officer
#
#    number_of_depts  number_of_unique_depts
# 0                7                       6
# 1                7                       6
# 2                7                       6
# 3                7                       6
# 4                7                       6
# 5                7                       6
# 6                7                       6
# TERMINATION INDEX:  Index([1], dtype='int64')
# CURRENT TERM SPOT:  1
# OFFICER START DATE AT NEXT PLACE IS BEFORE END DATE AT TERMINATED PLACE
#     person_nbr  last_name first_name middle_name   race   sex  year_of_birth  \
# 0     65001938   Anderson      Jason           A  White  Male           1975
# 1     65001938   Anderson      Jason           A  White  Male           1975
# 2     65001938   Anderson      Jason           A  White  Male           1975
# 3     65001938   Anderson      Jason           A  White  Male           1975
# 4     65001938   Anderson      Jason           A  White  Male           1975
# 5     65001938   Anderson      Jason           A  White  Male           1975
# 6     65001938   Anderson      Jason           A  White  Male           1975
# 7     65001938   Anderson      Jason           A  White  Male           1975
# 8     65001938   Anderson      Jason           A  White  Male           1975
# 9     65001938   Anderson      Jason           A  White  Male           1975
# 10    65001938   Anderson      Jason           A  White  Male           1975
# 11    65001938   Anderson      Jason           A  White  Male           1975
# 12    65001938   Anderson      Jason           A  White  Male           1975
#
#                      agency_name start_date   end_date     separation_reason  \
# 0      Potomac Police Department 2000-10-12 2001-05-14  Terminated For Cause
# 1       Rankin Police Department 2000-02-07 2001-10-17              Resigned
# 2    Hoopeston Police Department 1901-01-01 2001-11-04              Resigned
# 3       Paxton Police Department 2002-02-04 2006-08-03              Resigned
# 4       Rankin Police Department 2006-10-25 2007-05-03       Other (Explain)
# 5       Rankin Police Department 2007-05-03 2007-05-30              Resigned
# 6      Gifford Police Department 2007-01-02 2007-06-30      Left For New Job
# 7    Rossville Police Department 2007-05-25 2008-04-21       Other (Explain)
# 8    Rossville Police Department 2008-04-21 2011-07-25              Resigned
# 9       Paxton Police Department 2011-07-23 2014-08-05              Resigned
# 10      Gilman Police Department 2014-08-04 2020-08-07       Other (Explain)
# 11      Onarga Police Department 2019-08-24 2021-04-29              Resigned
# 12  Georgetown Police Department 2020-08-03        NaT                   NaN
#
#                type                                 status            rank  \
# 0   Law Enforcement                              Part-Time  Police Officer
# 1   Law Enforcement                              Part-Time  Police Officer
# 2   Law Enforcement  Auxiliary (Used prior to P.A. 94-984)  Police Officer
# 3   Law Enforcement                              Full-Time  Police Officer
# 4   Law Enforcement                              Part-Time           Chief
# 5   Law Enforcement                              Full-Time           Chief
# 6   Law Enforcement                              Part-Time  Police Officer
# 7   Law Enforcement                              Part-Time  Police Officer
# 8   Law Enforcement                              Full-Time      Lieutenant
# 9   Law Enforcement                              Full-Time  Police Officer
# 10  Law Enforcement                              Full-Time           Chief
# 11  Law Enforcement                              Part-Time  Police Officer
# 12  Law Enforcement                              Full-Time         Captain
#
#     number_of_depts  number_of_unique_depts
# 0                13                       9
# 1                13                       9
# 2                13                       9
# 3                13                       9
# 4                13                       9
# 5                13                       9
# 6                13                       9
# 7                13                       9
# 8                13                       9
# 9                13                       9
# 10               13                       9
# 11               13                       9
# 12               13                       9
# TERMINATION INDEX:  Index([0], dtype='int64')
# CURRENT TERM SPOT:  0
# OFFICER START DATE AT NEXT PLACE IS BEFORE END DATE AT TERMINATED PLACE
#    person_nbr  last_name first_name middle_name                       race  \
# 0    65002025   Anderson    Michael           O  Black or African American
# 1    65002025   Anderson    Michael           O  Black or African American
# 2    65002025   Anderson    Michael           O  Black or African American
# 3    65002025   Anderson    Michael           O  Black or African American
# 4    65002025   Anderson    Michael           O  Black or African American
#
#     sex  year_of_birth                          agency_name start_date  \
# 0  Male           1964           Cook County Court Services 1987-10-05
# 1  Male           1964  Oakton C C Public Safety Department 2007-01-17
# 2  Male           1964         Lake County Sheriff's Office 2019-08-28
# 3  Male           1964           Virginia Police Department 2022-02-11
# 4  Male           1964         Lake County Sheriff's Office 2019-10-08
#
#     end_date     separation_reason             type     status  \
# 0 2002-12-31              Resigned   Court Security  Full-Time
# 1 2007-09-18  Terminated For Cause  Law Enforcement  Full-Time
# 2 2019-10-08       Other (Explain)   Court Security  Part-Time
# 3 2022-07-04       Other (Explain)  Law Enforcement  Part-Time
# 4        NaT                   NaN   Court Security  Full-Time
#
#                      rank  number_of_depts  number_of_unique_depts
# 0                  Deputy                5                       4
# 1          Police Officer                5                       4
# 2  Court Security Officer                5                       4
# 3          Police Officer                5                       4
# 4  Court Security Officer                5                       4
# TERMINATION INDEX:  Index([1], dtype='int64')
# CURRENT TERM SPOT:  1
# AGENCY AFTER TERM:  Lake County Sheriff's Office
#    person_nbr  last_name first_name middle_name   race   sex  year_of_birth  \
# 0    65002277      Angel    Michael           J  White  Male           1980
# 1    65002277      Angel    Michael           J  White  Male           1980
# 2    65002277      Angel    Michael           J  White  Male           1980
# 3    65002277      Angel    Michael           J  White  Male           1980
# 4    65002277      Angel    Michael           J  White  Male           1980
# 5    65002277      Angel    Michael           J  White  Male           1980
#
#                        agency_name start_date   end_date  \
# 0      Calhoun Co Coroner's Office 2002-05-22 2005-01-30
# 1  Calhoun County Sheriff's Office 2002-05-22 2005-10-05
# 2  Calhoun County Sheriff's Office 2006-12-02 2009-07-27
# 3         Hardin Police Department 2011-04-08 2015-06-01
# 4        Grafton Police Department 2013-01-28 2019-04-16
# 5        Grafton Police Department 2019-04-16        NaT
#
#       separation_reason             type     status            rank  \
# 0       Other (Explain)          Coroner  Full-Time  Deputy Coroner
# 1      Left For New Job  Law Enforcement  Full-Time          Deputy
# 2  Terminated For Cause  Law Enforcement  Full-Time          Deputy
# 3              Resigned  Law Enforcement  Part-Time  Police Officer
# 4       Other (Explain)  Law Enforcement  Part-Time  Police Officer
# 5                   NaN  Law Enforcement  Full-Time  Police Officer
#
#    number_of_depts  number_of_unique_depts
# 0                6                       4
# 1                6                       4
# 2                6                       4
# 3                6                       4
# 4                6                       4
# 5                6                       4
# TERMINATION INDEX:  Index([2], dtype='int64')
# CURRENT TERM SPOT:  2
# AGENCY AFTER TERM:  Hardin Police Department
#    person_nbr  last_name first_name middle_name   race   sex  year_of_birth  \
# 0    65002297   Angelton      Terry           K  White  Male           1948
# 1    65002297   Angelton      Terry           K  White  Male           1948
# 2    65002297   Angelton      Terry           K  White  Male           1948
# 3    65002297   Angelton      Terry           K  White  Male           1948
#
#                       agency_name start_date   end_date     separation_reason  \
# 0  Hardin County Sheriff's Office 1901-01-01 2010-01-01               Unknown
# 1  Hardin County Sheriff's Office 2010-12-21 2014-07-08              Resigned
# 2  Hardin County Sheriff's Office 2014-07-09 2018-03-05  Terminated For Cause
# 3  Hardin County Sheriff's Office 2018-06-13 2023-08-01       Other (Explain)
#
#               type                                 status               rank  \
# 0  Law Enforcement  Auxiliary (Used prior to P.A. 94-984)     Police Officer
# 1        Auxiliary                Auxiliary with Firearms   Auxiliary Deputy
# 2        Auxiliary                Auxiliary with Firearms   Auxiliary Deputy
# 3        Auxiliary                Auxiliary with Firearms  Auxiliary Officer
#
#    number_of_depts  number_of_unique_depts
# 0                4                       1
# 1                4                       1
# 2                4                       1
# 3                4                       1
# TERMINATION INDEX:  Index([2], dtype='int64')
# CURRENT TERM SPOT:  2
# AGENCY AFTER TERM:  Hardin County Sheriff's Office
#    person_nbr  last_name first_name middle_name                       race  \
# 0    65002681  Armstrong       Eric      Dwayne  Black or African American
# 1    65002681  Armstrong       Eric      Dwayne  Black or African American
# 2    65002681  Armstrong       Eric      Dwayne  Black or African American
#
#     sex  year_of_birth                        agency_name start_date  \
# 0  Male           1970  University Park Police Department 2003-01-02
# 1  Male           1970           Harvey Police Department 2004-08-16
# 2  Male           1970          Dixmoor Police Department 2023-09-18
#
#     end_date     separation_reason             type     status  \
# 0 2004-12-10      Left For New Job  Law Enforcement  Full-Time
# 1 2021-06-25  Terminated For Cause  Law Enforcement  Full-Time
# 2        NaT                   NaN  Law Enforcement  Part-Time
#
#              rank  number_of_depts  number_of_unique_depts
# 0  Police Officer                3                       3
# 1       Detective                3                       3
# 2  Police Officer                3                       3
# TERMINATION INDEX:  Index([1], dtype='int64')
# CURRENT TERM SPOT:  1
# AGENCY AFTER TERM:  Dixmoor Police Department
#    person_nbr  last_name first_name middle_name   race   sex  year_of_birth  \
# 0    65002724     Arnett     Darren         Max  White  Male           1975
# 1    65002724     Arnett     Darren         Max  White  Male           1975
#
#                    agency_name start_date   end_date     separation_reason  \
# 0  Lewistown Police Department 2002-03-12 2002-03-27  Terminated For Cause
# 1     Canton Police Department 2010-09-14 2019-01-01              Resigned
#
#               type                   status               rank  \
# 0  Law Enforcement                Full-Time     Police Officer
# 1        Auxiliary  Auxiliary with Firearms  Auxiliary Officer
#
# ...
# 0    65158298     Bahena     Julian           J  Hispanic or Latino  Male
# 1    65158298     Bahena     Julian           J  Hispanic or Latino  Male
#
#    year_of_birth                 agency_name start_date   end_date  \
# 0           1999   Addison Police Department 2022-09-12 2022-11-03
# 1           1999  Wheeling Police Department 2023-03-06        NaT
#
#       separation_reason             type     status            rank  \
# 0  Terminated For Cause  Law Enforcement  Full-Time  Police Officer
# 1                   NaN  Law Enforcement  Full-Time  Police Officer
#
#    number_of_depts  number_of_unique_depts
# 0                2                       2
# 1                2                       2
# TERMINATION INDEX:  Index([0], dtype='int64')
# CURRENT TERM SPOT:  0
# AGENCY AFTER TERM:  Wheeling Police Department
#    person_nbr   last_name first_name middle_name  \
# 0    65158657  Al Sultani        Ali         NaN
# 1    65158657  Al Sultani        Ali         NaN
#
#                                race   sex  year_of_birth  \
# 0  Native American or Alaska Native  Male           2000
# 1  Native American or Alaska Native  Male           2000
#
#                 agency_name start_date   end_date     separation_reason  \
# 0  Harvey Police Department 2022-11-28 2023-05-12  Terminated For Cause
# 1  Harvey Police Department 2023-02-01 2023-05-23       Other (Explain)
#
#               type     status            rank  number_of_depts  \
# 0  Law Enforcement  Part-Time  Police Officer                2
# 1  Law Enforcement  Part-Time  Police Officer                2
#
#    number_of_unique_depts
# 0                       1
# 1                       1
# TERMINATION INDEX:  Index([0], dtype='int64')
# CURRENT TERM SPOT:  0
# OFFICER START DATE AT NEXT PLACE IS BEFORE END DATE AT TERMINATED PLACE
#    person_nbr   last_name first_name middle_name                       race  \
# 0    65158747  Pennington     Edward     Dashaun  Black or African American
# 1    65158747  Pennington     Edward     Dashaun  Black or African American
#
#     sex  year_of_birth                        agency_name start_date  \
# 0  Male           1997          Chicago Police Department 2022-11-04
# 1  Male           1997  Chicago Heights Police Department 2023-05-15
#
#     end_date     separation_reason             type     status  \
# 0 2023-01-20  Terminated For Cause  Law Enforcement  Full-Time
# 1        NaT                   NaN  Law Enforcement  Full-Time
#
#              rank  number_of_depts  number_of_unique_depts
# 0  Police Officer                2                       2
# 1  Police Officer                2                       2
# TERMINATION INDEX:  Index([0], dtype='int64')
# CURRENT TERM SPOT:  0
# AGENCY AFTER TERM:  Chicago Heights Police Department
#    person_nbr  last_name first_name middle_name   race     sex  year_of_birth  \
# 0    65158970   Gonzalez   Jennifer       Marie  White  Female           1982
# 1    65158970   Gonzalez   Jennifer       Marie  White  Female           1982
# 2    65158970   Gonzalez   Jennifer       Marie  White  Female           1982
#
#                        agency_name start_date   end_date  \
# 0  McHenry County Sheriff's Office 2022-12-19 2023-07-06
# 1       Gilberts Police Department 2023-08-10        NaT
# 2     Kane County Sheriff's Office 2023-09-11        NaT
#
#       separation_reason             type     status                    rank  \
# 0  Terminated For Cause  Law Enforcement  Full-Time                  Deputy
# 1                   NaN  Law Enforcement  Part-Time          Police Officer
# 2                   NaN   Court Security  Full-Time  Court Security Officer
#
#    number_of_depts  number_of_unique_depts
# 0                3                       3
# 1                3                       3
# 2                3                       3
# TERMINATION INDEX:  Index([0], dtype='int64')
# CURRENT TERM SPOT:  0
# AGENCY AFTER TERM:  Gilberts Police Department
#    person_nbr  last_name first_name middle_name                       race  \
# 0    65159103     Birris      Kylia         NaN  Black or African American
# 1    65159103     Birris      Kylia         NaN  Black or African American
#
#       sex  year_of_birth               agency_name start_date   end_date  \
# 0  Female           1997  Peoria Police Department 2023-01-03 2023-01-13
# 1  Female           1997  Peoria Police Department 2023-05-01        NaT
#
#       separation_reason             type     status            rank  \
# 0  Terminated For Cause  Law Enforcement  Full-Time  Police Officer
# 1                   NaN  Law Enforcement  Full-Time  Police Officer
#
#    number_of_depts  number_of_unique_depts
# 0                2                       1
# 1                2                       1
# TERMINATION INDEX:  Index([0], dtype='int64')
# CURRENT TERM SPOT:  0
# AGENCY AFTER TERM:  Peoria Police Department
#    person_nbr  last_name first_name middle_name                       race  \
# 0    65159225       Bell     Jarron     Deshawn  Black or African American
# 1    65159225       Bell     Jarron     Deshawn  Black or African American
#
#     sex  year_of_birth                      agency_name start_date   end_date  \
# 0  Male           1993  South Holland Police Department 2023-01-09 2023-05-05
# 1  Male           1993        Chicago Police Department 2023-08-07        NaT
#
#       separation_reason             type     status            rank  \
# 0  Terminated For Cause  Law Enforcement  Full-Time  Police Officer
# 1                   NaN  Law Enforcement  Full-Time  Police Officer
#
#    number_of_depts  number_of_unique_depts
# 0                2                       2
# 1                2                       2
# TERMINATION INDEX:  Index([0], dtype='int64')
# CURRENT TERM SPOT:  0
# AGENCY AFTER TERM:  Chicago Police Department
#    person_nbr  last_name first_name middle_name   race   sex  year_of_birth  \
# 0    65159538    Dawkins    Clayton           D  White  Male           1988
# 1    65159538    Dawkins    Clayton           D  White  Male           1988
#
#                     agency_name start_date   end_date     separation_reason  \
# 0  Monticello Police Department 2023-02-13 2023-04-10  Terminated For Cause
# 1     Mahomet Police Department 2024-01-02        NaT                   NaN
#
#               type     status            rank  number_of_depts  \
# 0  Law Enforcement  Full-Time  Police Officer                2
# 1  Law Enforcement  Full-Time  Police Officer                2
#
#    number_of_unique_depts
# 0                       2
# 1                       2
# TERMINATION INDEX:  Index([0], dtype='int64')
# CURRENT TERM SPOT:  0
# AGENCY AFTER TERM:  Mahomet Police Department
#    person_nbr  last_name first_name middle_name                       race  \
# 0    65159591     Moorer    Trumain           L  Black or African American
# 1    65159591     Moorer    Trumain           L  Black or African American
#
#     sex  year_of_birth                      agency_name start_date   end_date  \
# 0  Male           1995        Chicago Police Department 2023-02-01 2023-03-22
# 1  Male           1995  South Holland Police Department 2023-09-11        NaT
#
#       separation_reason             type     status            rank  \
# 0  Terminated For Cause  Law Enforcement  Full-Time  Police Officer
# 1                   NaN  Law Enforcement  Full-Time  Police Officer
#
#    number_of_depts  number_of_unique_depts
# 0                2                       2
# 1                2                       2
# TERMINATION INDEX:  Index([0], dtype='int64')
# CURRENT TERM SPOT:  0
# AGENCY AFTER TERM:  South Holland Police Department
#    person_nbr  last_name first_name middle_name   race   sex  year_of_birth  \
# 0    65159609      Alden      James           L  White  Male           1993
# 1    65159609      Alden      James           L  White  Male           1993
#
#                      agency_name start_date   end_date     separation_reason  \
# 0  Edgar County Sheriff's Office 2023-02-17 2023-03-16  Terminated For Cause
# 1  Edgar County Sheriff's Office 2023-04-18 2023-05-16  Terminated For Cause
#
#            type     status                  rank  number_of_depts  \
# 0  Correctional  Full-Time  Correctional Officer                2
# 1  Correctional  Full-Time  Correctional Officer                2
#
#    number_of_unique_depts
# 0                       1
# 1                       1
# TERMINATION INDEX:  Index([0, 1], dtype='int64')
# CURRENT TERM SPOT:  0
# AGENCY AFTER TERM:  Edgar County Sheriff's Office
# CURRENT TERM SPOT:  1
# TERMINATION IS LAST THING IN OFFICERS HISTORY
#    person_nbr         last_name first_name middle_name                race  \
# 0    65159673  Velenzuela Mejia      Hever       Ariel  Hispanic or Latino
# 1    65159673  Velenzuela Mejia      Hever       Ariel  Hispanic or Latino
#
#     sex  year_of_birth                   agency_name start_date   end_date  \
# 0  Male           1996     Chicago Police Department 2023-02-01 2024-01-04
# 1  Male           1996  Bridgeview Police Department 2024-07-03        NaT
#
#       separation_reason             type     status            rank  \
# 0  Terminated For Cause  Law Enforcement  Full-Time  Police Officer
# 1                   NaN  Law Enforcement  Part-Time  Police Officer
#
#    number_of_depts  number_of_unique_depts
# 0                2                       2
# 1                2                       2
# TERMINATION INDEX:  Index([0], dtype='int64')
# CURRENT TERM SPOT:  0
# AGENCY AFTER TERM:  Bridgeview Police Department
#    person_nbr  last_name first_name middle_name   race   sex  year_of_birth  \
# 0    65159770  Vantassel      Keith           A  White  Male           1993
# 1    65159770  Vantassel      Keith           A  White  Male           1993
#
#                           agency_name start_date   end_date  \
# 0       Coles County Sheriff's Office 2022-08-16 2023-06-08
# 1  Cumberland County Sheriff's Office 2023-06-22        NaT
#
#       separation_reason          type     status                  rank  \
# 0  Terminated For Cause  Correctional  Full-Time  Correctional Officer
# 1                   NaN  Correctional  Full-Time  Correctional Officer
#
#    number_of_depts  number_of_unique_depts
# 0                2                       2
# 1                2                       2
# TERMINATION INDEX:  Index([0], dtype='int64')
# CURRENT TERM SPOT:  0
# AGENCY AFTER TERM:  Cumberland County Sheriff's Office
#    person_nbr  last_name first_name middle_name                race   sex  \
# 0    65160066      Ramos      Jacob        Raul  Hispanic or Latino  Male
# 1    65160066      Ramos      Jacob        Raul  Hispanic or Latino  Male
#
#    year_of_birth                         agency_name start_date   end_date  \
# 0           1999   Rolling Meadows Police Department 2023-04-17 2024-01-19
# 1           1999  Glendale Heights Police Department 2024-04-09        NaT
#
#       separation_reason             type     status            rank  \
# 0  Terminated For Cause  Law Enforcement  Full-Time  Police Officer
# 1                   NaN  Law Enforcement  Full-Time  Police Officer
#
#    number_of_depts  number_of_unique_depts
# 0                2                       2
# 1                2                       2
# TERMINATION INDEX:  Index([0], dtype='int64')
# CURRENT TERM SPOT:  0
# AGENCY AFTER TERM:  Glendale Heights Police Department
#    person_nbr  last_name first_name middle_name                race   sex  \
# 0    65160072     Garcia      Jaime      Javier  Hispanic or Latino  Male
# 1    65160072     Garcia      Jaime      Javier  Hispanic or Latino  Male
#
#    year_of_birth                             agency_name start_date  \
# 0           1999           Murphysboro Police Department 2023-04-12
# 1           1999  John A Logan College Police Department 2023-11-15
#
#     end_date     separation_reason             type     status  \
# 0 2023-09-25  Terminated For Cause  Law Enforcement  Full-Time
# 1        NaT                   NaN  Law Enforcement  Full-Time
#
#              rank  number_of_depts  number_of_unique_depts
# 0  Police Officer                2                       2
# 1  Police Officer                2                       2
# TERMINATION INDEX:  Index([0], dtype='int64')
# CURRENT TERM SPOT:  0
# AGENCY AFTER TERM:  John A Logan College Police Department
#    person_nbr  last_name first_name middle_name                       race  \
# 0    65160885       Ford       Jade           A  Black or African American
# 1    65160885       Ford       Jade           A  Black or African American
#
#       sex  year_of_birth                    agency_name start_date   end_date  \
# 0  Female           1999  Rock Island Police Department 2023-07-31 2024-04-23
# 1  Female           1999        Aledo Police Department 2024-05-07        NaT
#
#       separation_reason             type     status            rank  \
# 0  Terminated For Cause  Law Enforcement  Full-Time  Police Officer
# 1                   NaN  Law Enforcement  Full-Time  Police Officer
#
#    number_of_depts  number_of_unique_depts
# 0                2                       2
# 1                2                       2
# TERMINATION INDEX:  Index([0], dtype='int64')
# CURRENT TERM SPOT:  0
# AGENCY AFTER TERM:  Aledo Police Department
#    person_nbr  last_name first_name middle_name   race     sex  year_of_birth  \
# 0    65161196    Ruttman    Makayla         Ann  White  Female           2002
# 1    65161196    Ruttman    Makayla         Ann  White  Female           2002
#
#                           agency_name start_date   end_date  \
# 0          Freeport Police Department 2023-08-28 2023-11-01
# 1  Stephenson County Sheriff's Office 2024-04-30        NaT
#
#       separation_reason             type     status            rank  \
# 0  Terminated For Cause  Law Enforcement  Full-Time  Police Officer
# 1                   NaN  Law Enforcement  Full-Time          Deputy
#
#    number_of_depts  number_of_unique_depts
# 0                2                       2
# 1                2                       2
# TERMINATION INDEX:  Index([0], dtype='int64')
# CURRENT TERM SPOT:  0
# AGENCY AFTER TERM:  Stephenson County Sheriff's Office
#    person_nbr  last_name first_name middle_name   race     sex  year_of_birth  \
# 0    65161303      Lemon     Brooke      Lauren  White  Female           2002
# 1    65161303      Lemon     Brooke      Lauren  White  Female           2002
#
#                          agency_name start_date   end_date  \
# 0  Vermilion County Sheriff's Office 2023-09-01 2024-04-30
# 1       Georgetown Police Department 2024-05-20        NaT
#
#       separation_reason             type     status            rank  \
# 0  Terminated For Cause  Law Enforcement  Full-Time          Deputy
# 1                   NaN  Law Enforcement  Full-Time  Police Officer
#
#    number_of_depts  number_of_unique_depts
# 0                2                       2
# 1                2                       2
# TERMINATION INDEX:  Index([0], dtype='int64')
# CURRENT TERM SPOT:  0
# AGENCY AFTER TERM:  Georgetown Police Department
#    person_nbr  last_name first_name middle_name   race     sex  year_of_birth  \
# 0    65161550    Poulsen       Dana           M  White  Female           1984
# 1    65161550    Poulsen       Dana           M  White  Female           1984
#
#                     agency_name start_date   end_date     separation_reason  \
# 0     Chicago Police Department 2023-08-07 2024-03-01  Terminated For Cause
# 1  Bridgeview Police Department 2024-05-15        NaT                   NaN
#
#               type     status            rank  number_of_depts  \
# 0  Law Enforcement  Full-Time  Police Officer                2
# 1  Law Enforcement  Part-Time  Police Officer                2
#
#    number_of_unique_depts
# 0                       2
# 1                       2
# TERMINATION INDEX:  Index([0], dtype='int64')
# CURRENT TERM SPOT:  0
# AGENCY AFTER TERM:  Bridgeview Police Department

# %%
ill_depts_after_term[1]
# Out:
# defaultdict(list,
#             {'University of Illinois at Chicago Campus Police Department': [65000149],
#              "Washington County Sheriff's Office": [65000690, 65110655],
#              'Oakwood Police Department': [65000889, 65022657],
#              'Berkeley Police Department': [65000893,
#               65003334,
#               65021824,
#               65151295],
#              'Mounds Police Department': [65000909,
#               65033991,
#               65072714,
#               65098800,
#               65104535,
#               65119816,
#               65120112],
#              'Bloomington Police Department': [65001415],
#              'Toluca Police Department': [65001415, 65006749, 65118640],
#              "Lake County Sheriff's Office": [65001594,
#               65002025,
#               65009144,
#               65011218,
#               65040396,
#               65063382],
#              'Markham Police Department': [65001818,
#               65011135,
#               65033406,
#               65044544,
#               65046158,
#               65092855,
#               65104739,
#               65136562],
#              'Chicago Heights Park District PD': [65001818,
#               65046057,
#               65048883,
#               65106788,
#               65125062],
#              'Bradley Police Department': [65001845],
#              'Hardin Police Department': [65002277],
#              "Hardin County Sheriff's Office": [65002297,
#               65057598,
#               65082674,
#               65094265],
#              'Dixmoor Police Department': [65002681,
#               65005628,
#               65012197,
#               65012197,
#               65012198,
#               65012645,
#               65033927,
#               65036239,
#               65038177,
#               65040126,
#               65045290,
#               65046359,
#               65046644,
#               65064009,
#               65066795,
#               65082037,
#               65084128,
#               65084128,
#               65084558,
#               65087282,
#               65090921,
#               65098037,
#               65098384,
#               65112930,
#               65114578,
#               65125986,
#               65144416,
#               65144416,
#               65148595,
#               65152011],
#              'Canton Police Department': [65002724],
#              'Cook County Forest Pres District Police': [65002916,
#               65042462,
#               65048011,
#               65058977,
#               65069637,
#               65121119],
#              'Stewardson Police Department': [65002919],
#              'Altamont Police Department': [65002919],
#              "Henderson County Sheriff's Office": [65002985],
#              'Oakwood Hills Police Department': [65003499,
#               65062786,
#               65084568,
#               65084568,
#               65125491,
#               65127337,
#               65136744,
#               65143496,
#               65145925],
#              "Iroquois Co Coroner's Office": [65003614],
#              'East Dundee Police Department': [65003719],
#              'Olmsted Police Department': [65003954],
#              "DuPage County Sheriff's Office": [65004429,
#               65027158,
#               65061928,
#               65110447,
#               65152513],
#              'Farmington Police Department': [65004520, 65069429, 65157470],
#              'Crainville Police Department': [65004708],
#              'Zeigler Police Department': [65005092, 65027438, 65152238],
#              'Washington Park Police Department': [65005435,
#               65005435,
#               65009367,
#               65068447,
#               65098164,
#               65112299,
#               65116986,
#               65132902,
#               65144050,
#               65148975,
#               65149517],
#              'Roanoke Police Department': [65005508],
#              'Momence Police Department': [65006377,
#               65079174,
#               65092143,
#               65100654,
#               65110026,
#               65148219],
#              'DePue Police Department': [65006467, 65147315],
#              'Earlville Police Department': [65006672],
#              'Herscher Police Department': [65006690, 65127833],
#              'Crestwood Police Department': [65006828,
#               65019142,
#               65022449,
#               65044829,
#               65048883,
#               65059778,
#               65147974,
#               65148544,
#               65156768],
#              'Murphysboro Police Department': [65006919],
#              "Pulaski County Sheriff's Office": [65007345,
#               65025074,
#               65080949,
#               65128085,
#               65128085,
#               65139620],
#              'Mason City Police Department': [65007430, 65088682, 65125394],
#              'Joliet Police Department': [65007745],
#              'East Hazel Crest Police Department': [65008380, 65036239],
#              'Brooklyn Police Department': [65008588,
#               65039590,
#               65054577,
#               65071832,
#               65090932,
#               65093747,
#               65119866],
#              'Dupo Police Department': [65008588, 65120238],
#              'Phoenix Police Department': [65008604,
#               65023929,
#               65033927,
#               65039318,
#               65040487,
#               65043950,
#               65044042,
#               65046158,
#               65047848,
#               65047848,
#               65054508,
#               65054508,
#               65074481,
#               65079334,
#               65083068,
#               65090434,
#               65090943,
#               65102848,
#               65110005,
#               65110005,
#               65110562,
#               65114005,
#               65128218,
#               65139798,
#               65148011,
#               65152011],
#              'Johnston City Police Department': [65008618, 65110037],
#              "Cook County Sheriff's Police": [65009268],
#              'Fairmont City Police Department': [65009564],
#              'Arthur Police Department': [65009615, 65139727],
#              'Waubonsee College Police Department': [65009948, 65055677],
#              'Washburn Police Department': [65009994],
#              'Witt Police Department': [65010006],
#              'Bellwood Police Department': [65010129,
#               65106361,
#               65144363,
#               65145218],
#              'Metamora Police Department': [65010302, 65041369, 65086753],
#              'Cook County Hospital System Police': [65010693,
#               65081755,
#               65150616],
#              "Will Co State's Attorney": [65010710],
#              'Henry Police Department': [65010881],
#              'Atwood Police Department': [65011313],
#              'Wonder Lake Police Department': [65011563, 65120328],
#              'Galva Police Department': [65011770,
#               65030155,
#               65077858,
#               65135046],
#              'Wyoming Police Department': [65011770],
#              'Elkhart Police Department': [65011770],
#              'Des Plaines Police Department': [65011906],
#              'Robbins Police Department': [65012109,
#               65012645,
#               65020431,
#               65021939,
#               65027433,
#               65027433,
#               65034100,
#               65034553,
#               65036239,
#               65039318,
#               65040820,
#               65041386,
#               65042854,
#               65042854,
#               65044203,
#               65046082,
#               65046644,
#               65048011,
#               65058014,
#               65058977,
#               65060277,
#               65063489,
#               65064009,
#               65066566,
#               65071669,
#               65071691,
#               65081823,
#               65088136,
#               65089719,
#               65092119,
#               65099664,
#               65101198,
#               65103216,
#               65107929,
#               65108470,
#               65116556,
#               65120504,
#               65148218,
#               65150616,
#               65152739,
#               65158037],
#              'Markham Park District Police Department': [65012177, 65059873],
#              'Forest View Police Department': [65014601, 65037762, 65098631],
#              'Vernon Hills Police Department': [65014726],
#              'Brocton Police Department': [65014940],
#              'Marine Police Department': [65015668],
#              'Bridgeport Police Department': [65015986],
#              'Sumner Police Department': [65015986],
#              'Wauconda Police Department': [65016124, 65032342, 65146336],
#              'Milford Police Department': [65016210],
#              'Lyons Police Department': [65016244,
#               65060536,
#               65109333,
#               65116450],
#              'Sleepy Hollow Police Department': [65016376,
#               65028848,
#               65037793,
#               65072152,
#               65102229,
#               65104416],
#              'Springfield Park District Police Department': [65017004],
#              'Arcola Police Department': [65017128],
#              'McCullom Lake Police Department': [65017651, 65041918, 65081996],
#              'Hebron Police Department': [65017651,
#               65086508,
#               65105472,
#               65146336,
#               65150916],
#              "McHenry County Sheriff's Office": [65017828,
#               65033947,
#               65042475,
#               65083813],
#              "Coles County Sheriff's Office": [65017901,
#               65038334,
#               65142401,
#               65148242],
#              "Jefferson County Sheriff's Office": [65018306,
#               65145465,
#               65153179],
#              'Posen Police Department': [65018798,
#               65033406,
#               65089298,
#               65113843],
#              'Chenoa Police Department': [65019041, 65054215],
#              'Harvey Police Department': [65019142,
#               65046360,
#               65107404,
#               65114570,
#               65127630,
#               65128183,
#               65152175,
#               65152731],
#              'San Jose Police Department': [65020655, 65064878],
#              'Glen Ellyn Police Department': [65020820],
#              'Indian Head Park Police Department': [65020995],
#              'Crystal Lake Park District Police Department': [65021213,
#               65120692],
#              'Steger Police Department': [65021488],
#              'Ullin Police Department': [65021912,
#               65072714,
#               65105111,
#               65143694],
#              "Livingston County Sheriff's Office": [65021945,
#               65116123,
#               65120303,
#               65145246,
#               65148945],
#              'Cook County Department Of Corrections': [65021999,
#               65098649,
#               65112147,
#               65116604,
#               65144418,
#               65148508,
#               65151771,
#               65152346,
#               65152738],
#              'Merrionette Park Police Department': [65022104,
#               65057697,
#               65057847,
#               65084558,
#               65137993],
#              'Cahokia Heights Police Department': [65022117],
#              'South Chicago Heights Police Department': [65023130],
#              'Maywood Police Department': [65023396,
#               65054439,
#               65063065,
#               65072009,
#               65096309,
#               65104416],
#              'Island Lake Police Department': [65023732, 65059480],
#              'South Suburban College Police Department': [65023929,
#               65060428,
#               65068114,
#               65117314],
#              'Winnebago Police Department': [65024060],
#              'Sandoval Police Department': [65024351],
#              "Will County Sheriff's Office": [65024374,
#               65089169,
#               65125953,
#               65151691,
#               65151713],
#              'Bayview Gardens Police Department': [65024844],
#              'Pocahontas Police Department': [65026005],
#              'Woodstock Police Department': [65026599],
#              'Cutler Police Department': [65026939],
#              'Anna Police Department': [65026956, 65147660],
#              'Buda Police Department': [65026966],
#              'Divernon Police Department': [65027191, 65063593],
#              'Palmyra Police Department': [65027191],
#              'Roodhouse Police Department': [65027239],
#              'Mount Zion Police Department': [65028050],
#              'Mount Olive Police Department': [65028472],
#              'Peoria Heights Police Department': [65028759, 65100503],
#              'Berwyn Police Department': [65029038, 65147859],
#              'Norwood Police Department': [65029127],
#              'Cahokia Police Department': [65029357],
#              'Moline Police Department': [65029363],
#              'Crete Police Department': [65029882, 65063842],
#              'Grandview Police Department': [65029987,
#               65042259,
#               65063593,
#               65076886,
#               65110699,
#               65113879,
#               65135511],
#              'Kane Co Forest Pres Police Department': [65030021, 65068249],
#              'Worden Police Department': [65030617, 65157962],
#              'Centreville Police Department': [65030845,
#               65065487,
#               65072501,
#               65087478,
#               65097045,
#               65100540,
#               65104526,
#               65112299,
#               65112615,
#               65120044],
#              'Beecher Police Department': [65031048],
#              'Seneca Police Department': [65031417, 65158094],
#              'Oak Park Police Department': [65031459, 65132861, 65144563],
#              "DeKalb County Sheriff's Office": [65031569],
#              "Lawrence County Sheriff's Office": [65031870],
#              'Hampton Police Department': [65033492,
#               65033595,
#               65115882,
#               65120027],
#              'Cairo Police Department': [65033991,
#               65072714,
#               65075404,
#               65112492,
#               65125567,
#               65139942,
#               65146528,
#               65147648],
#              'Shannon Police Department': [65034318],
#              'AG Valley Railroad Police Department': [65034329],
#              'Lockport Township Park District Police': [65034341],
#              'Stone Park Police Department': [65034342, 65070340, 65127062],
#              'Morton College Police Department': [65034342,
#               65034685,
#               65035072,
#               65035649,
#               65070340,
#               65074688],
#              'Cook County Court Services': [65034454, 65105966],
#              'Lynwood Police Department': [65034553,
#               65049828,
#               65103216,
#               65107502,
#               65114078,
#               65151919],
#              'Hometown Police Department': [65034685,
#               65061683,
#               65063687,
#               65121327,
#               65136637,
#               65147099,
#               65156687,
#               65158048],
#              'University Park Police Department': [65034685,
#               65079334,
#               65145191,
#               65153726],
#              'Holiday Hills Police Department': [65034969, 65076459, 65145629],
#              'Oak Brook Police Department': [65035403],
#              "Winnebago County Sheriff's Office": [65035954, 65147440],
#              "Sangamon County Sheriff's Office": [65036818, 65077235],
#              'Calumet Park Police Department': [65036826,
#               65036826,
#               65094569,
#               65103216],
#              'Blue Island Police Department': [65037381,
#               65054750,
#               65054750,
#               65074653,
#               65156704],
#              'Energy Police Department': [65037593,
#               65054539,
#               65114603,
#               65149566],
#              'Fox River Grove Police Department': [65038154, 65152296],
#              'Southern Illinois Airport Authorityority': [65038567, 65098797],
#              "Vermilion Co Coroner's Office": [65039203],
#              'Franklin Grove Police Department': [65039389],
#              'East St. Louis Police Department': [65039590,
#               65063597,
#               65093747],
#              'Elwood Police Department': [65040007],
#              "Schuyler County Sheriff's Office": [65040464],
#              'Irvington Police Department': [65040862],
#              "Brown Co Coroner's Office": [65041434],
#              "Macon County Sheriff's Office": [65041441,
#               65050681,
#               65112779,
#               65151671,
#               65152548],
#              'Goreville Police Department': [65042020],
#              'Rockdale Police Department': [65042257, 65078806, 65089032],
#              'Governors State University Police Department': [65042631,
#               65051396,
#               65151199],
#              "Knox County Sheriff's Office": [65042727, 65145033],
#              'Buffalo-Mechanicsburg Police Department': [65042751],
#              'Illinois Gaming Board Police': [65043024, 65087652],
#              'Colona Police Department': [65043040, 65086251],
#              'Girard Police Department': [65043192, 65089656],
#              'Metra Police Department': [65043329, 65067322, 65148035],
#              'Pecatonica Police Department': [65043662],
#              'Elgin Police Department': [65043899],
#              'Okawville Police Department': [65043957, 65065876, 65110405],
#              'Riverdale Police Department': [65044192, 65107502, 65138146],
#              'West Salem Police Department': [65044319],
#              "Mercer County Sheriff's Office": [65044420, 65095544, 65157212],
#              'Summit Police Department': [65044829],
#              'Hampshire Police Department': [65044829],
#              'Prairie Grove Police Department': [65045162, 65127612],
#              "Bureau County Sheriff's Office": [65045771],
#              'Lostant Police Department': [65045816],
#              'Williamsville Police Department': [65046072],
#              'Fox Valley Park District Police Department': [65046137,
#               65068249,
#               65092700],
#              'Chesterfield Police Department': [65046404],
#              "Calhoun Co Coroner's Office": [65046404],
#              'Hecker Police Department': [65047066],
#              'Triton College Police Department': [65047175,
#               65067948,
#               65127499],
#              'Willow Springs Police Department': [65047193],
#              'Oakbrook Terrace Police Department': [65048237],
#              'Montgomery Police Department': [65049132],
#              "Union County Sheriff's Office": [65049635],
#              'Wenona Police Department': [65050333],
#              'Ridgway Police Department': [65050771],
#              "Monroe County Sheriff's Office": [65051069, 65061525],
#              'Belgium Police Department': [65051776],
#              'East Peoria Police Department': [65051933],
#              'Bradley University Police Department': [65052178],
#              'Glasford Police Department': [65052178],
#              'Campton Hills Police Department': [65053964, 65078042],
#              'Atkinson Police Department': [65054406],
#              'Galena Police Department': [65054935],
#              'McLean Police Department': [65054946],
#              'Chicago Housing Authority Police Department': [65055433],
#              'Hopedale Police Department': [65055750],
#              'Auburn Police Department': [65055882],
#              'Pittsfield Police Department': [65056362, 65110525],
#              'Downs Police Department': [65056719],
#              'Effingham Water Authority Police Department': [65057429],
#              "Hardin Co Coroner's Office": [65057570],
#              'Fondulac Park District Police Department': [65058237],
#              'Staunton Police Department': [65059143, 65105959],
#              'Tilden Police Department': [65060047],
#              'Grayville Police Department': [65060264],
#              'New Berlin Police Department': [65060267],
#              'Calumet City Police Department': [65060536],
#              'Petersburg Police Department': [65060665, 65089570],
#              'Illinois Department of Revenue': [65060809],
#              'New Lenox Police Department': [65060831],
#              'Riverton Police Department': [65061014, 65105912],
#              'University Of Chicago Police Department': [65061174,
#               65073346,
#               65099341,
#               65150963],
#              'Dolton Police Department': [65061174,
#               65069637,
#               65080137,
#               65087282,
#               65088471,
#               65097133,
#               65138146],
#              "Brown County Sheriff's Office": [65061451, 65066819, 65080524],
#              'South Elgin Police Department': [65061493],
#              'Bull Valley Police Department': [65061493],
#              "DeWitt County Sheriff's Office": [65061530],
#              'Black Hawk College Police Department': [65061895],
#              "Lawrence Co Coroner's Office": [65061901],
#              'Saint Anne Police Department': [65063382],
#              'Metropolitan Airport Authority Police': [65063537, 65137980],
#              "Greene Co Coroner's Office": [65063893],
#              "Iroquois County Sheriff's Office": [65063926,
#               65095054,
#               65145397],
#              'Greenfield Police Department': [65064441],
#              'Carrollton Police Department': [65064441],
#              'Karnak Police Department': [65064477],
#              'Southern View Police Department': [65065112, 65120081],
#              'Grantfork Police Department': [65065347],
#              "Franklin County Sheriff's Office": [65066044],
#              'Mansfield Police Department': [65066776],
#              'Somonauk Police Department': [65066776, 65147978],
#              'Sesser Police Department': [65068194],
#              "LaSalle County Sheriff's Office": [65068824],
#              'East St. Louis Park District Police': [65069908],
#              'Mound City Police Department': [65070421],
#              'Heyworth Police Department': [65071017],
#              'Aurora Police Department': [65071722, 65152130],
#              'Alorton Police Department': [65072501,
#               65072501,
#               65093747,
#               65105435,
#               65125841],
#              "Alexander County Sheriff's Office": [65072714, 65079336],
#              'Gillespie Police Department': [65073327, 65092015, 65146637],
#              'Lacon Police Department': [65073337],
#              'Morrisonville Police Department': [65073356],
#              'Marissa Police Department': [65074883, 65148621],
#              'Round Lake Heights Police Department': [65075350,
#               65112148,
#               65134390,
#               65134433,
#               65135261],
#              'Thebes Police Department': [65075404, 65089674],
#              'Prairie State College Police Department': [65075460],
#              'Chicago Police Department': [65076049,
#               65082036,
#               65092662,
#               65151701,
#               65159225],
#              'Fisher Police Department': [65077634, 65151609],
#              'Hurst Police Department': [65077834, 65102050],
#              'Mount Sterling Police Department': [65077858],
#              'Creal Springs Police Department': [65078931],
#              'Benton Police Department': [65078942],
#              'Polo Police Department': [65078995],
#              'Zion Police Department': [65079319],
#              'Geneva Police Department': [65079435],
#              'Lakemoor Police Department': [65079621, 65116100, 65149310],
#              'Venice Police Department': [65080223,
#               65112489,
#               65138143,
#               65143672],
#              'Beardstown Police Department': [65080524],
#              'Lakewood Police Department': [65080839, 65092236],
#              'Highwood Police Department': [65081996],
#              'Newman Police Department': [65082713],
#              'Ford Heights Police Department': [65083068],
#              'Norfolk Southern Railroad Police': [65083815],
#              "Woodford County Sheriff's Office": [65086084],
#              'Park Forest Police Department': [65087129],
#              'Will Co Forest Pres Police Department': [65087135],
#              'Spaulding Police Department': [65087458],
#              'Aroma Park Police Department': [65087550, 65105265],
#              'Rockford Police Department': [65087652, 65091782],
#              'McKendree University Public Safety': [65088043],
#              "Christian County Sheriff's Office": [65088124, 65096552],
#              'Thayer Police Department': [65089354, 65110699],
#              'Stronghurst Police Department': [65090668],
#              'Moraine Valley C C Police Department': [65091315, 65107929],
#              "Sangamon Co Coroner's Office": [65091437],
#              'Bath Police Department': [65091949],
#              'Kankakee Community College Police': [65094024,
#               65110723,
#               65115841],
#              'Pulaski Police Department': [65094265],
#              "Pope County Sheriff's Office": [65094265],
#              'North Chicago Police Department': [65094704, 65146481],
#              'Evanston Police Department': [65095908, 65147081],
#              "Champaign Co Coroner's Office": [65097642],
#              'Vandalia Police Department': [65097869],
#              "Edwards County Sheriff's Office": [65097915],
#              'Downers Grove Police Department': [65098631],
#              "Kendall County Sheriff's Office": [65098691],
#              'Winthrop Harbor Police Department': [65098788, 65105389],
#              'South Roxana Police Department': [65099244],
#              'Loyola University Police Department': [65100350, 65145137],
#              'Sherman Police Department': [65100923],
#              'Franklin Park Police Department': [65101111, 65114231, 65120033],
#              "Kankakee County Sheriff's Office": [65101169, 65112763],
#              'Lake Co Sheriff Offc. Marine Unit': [65102229],
#              'Bridgeview Police Department': [65103862,
#               65106981,
#               65156829,
#               65159673,
#               65161550],
#              'Rankin Police Department': [65104544, 65104544],
#              'Buckley Police Department': [65104544],
#              'Lake Co Forest Pres Police Department': [65104694],
#              'Viola Police Department': [65104809, 65121499],
#              'Mount Morris Police Department': [65105124],
#              'Grant Park Police Department': [65105209, 65127561],
#              'New Athens Police Department': [65105959],
#              'Lebanon Police Department': [65105959],
#              'Wamac Police Department': [65105972, 65121267],
#              'Coulterville Police Department': [65106413],
#              'Potomac Police Department': [65106508],
#              'Indianola Police Department': [65106508],
#              "Cumberland County Sheriff's Office": [65107381, 65159770],
#              'Belt Railway Police Department': [65108164],
#              'Woodhull Police Department': [65110010],
#              "Jasper County Sheriff's Office": [65110477, 65128220],
#              'WIU Office Of Public Safety': [65110685],
#              'Gilberts Police Department': [65110685,
#               65128105,
#               65149083,
#               65158970],
#              'Northern Illinois University Police': [65110763],
#              'Dana Police Department': [65111277],
#              'Decatur Park Police Department': [65111617],
#              'West City Police Department': [65112175],
#              'Ramsey Police Department': [65112873],
#              'Cook County Probation': [65113094],
#              'Waukegan Police Department': [65113148, 65113359, 65153621],
#              'Darien Police Department': [65113258],
#              'Minonk Police Department': [65114149],
#              'Winchester Police Department': [65114232],
#              'Wyanet Police Department': [65114450],
#              'Fayetteville Police Department': [65114475],
#              'Athens Police Department': [65115771],
#              'Fithian Police Department': [65115780],
#              'Oakton C C Public Safety Department': [65116676, 65119803],
#              'Grand Tower Police Department': [65117135],
#              'Rosemont Police Department': [65117209],
#              'Eureka College Police Department.': [65118565],
#              'Stickney Police Department': [65118599,
#               65128063,
#               65148450,
#               65158069],
#              "Champaign County Sheriff's Office": [65120647, 65152957],
#              "Kane County Sheriff's Office": [65120692, 65125364],
#              "Logan County Sheriff's Office": [65121206],
#              'Peoria Police Department': [65121321, 65147442, 65159103],
#              'Ladd Police Department': [65121422],
#              'Bluffs Police Department': [65122620],
#              "Marion County Sheriff's Office": [65122650],
#              'Carbondale Police Department': [65122771],
#              'Jerome Police Department': [65122831],
#              'Rantoul Police Department': [65122872],
#              'Matteson Police Department': [65125495],
#              'Royalton Police Department': [65125858],
#              'Smithton Police Department': [65127482],
#              'Plainfield Police Department': [65127729],
#              'Fox Lake Police Department': [65127879, 65137840],
#              'Avon Police Department': [65127930],
#              'Fairview Police Department': [65127930],
#              "Warren County Sheriff's Office": [65131543],
#              'Tolono Police Department': [65134168],
#              'Lena Police Department': [65134341],
#              'Rockford Park District Police Department': [65134397],
#              'Ava Police Department': [65135490],
#              "Whiteside County Sheriff's Office": [65135510],
#              'Kinmundy Police Department': [65136675],
#              'Centralia Police Department': [65138352],
#              "Perry County Sheriff's Office": [65138353],
#              'Rushville Police Department': [65138438],
#              'Villa Park Police Department': [65139865],
#              "Edgar County Sheriff's Office": [65141057, 65146186, 65159609],
#              'Villa Grove Police Department': [65142410],
#              "Moultrie County Sheriff's Office": [65143984],
#              'Niles Police Department': [65144091, 65147276],
#              'Chicago Heights Police Department': [65144419, 65158747],
#              'Southwestern Illinois College Police Department': [65144484,
#               65147380],
#              "Boone County Sheriff's Office": [65145485],
#              'Findlay Police Department': [65145727],
#              'Oswego Police Department': [65145809],
#              "Saint Clair County Sheriff's Office": [65145836],
#              'Tazewell County Probation': [65146314],
#              'Spillertown Police Department': [65146512, 65147632, 65157986],
#              "Saline County Sheriff's Office": [65146917],
#              'Mahomet Police Department': [65147298, 65159538],
#              'Decatur Police Department': [65147311],
#              "Williamson County Sheriff's Office": [65147417],
#              'Kankakee Police Department': [65147434],
#              "Mason County Sheriff's Office": [65148473],
#              'Woodford County Probation': [65148708],
#              'Champaign Police Department': [65149084],
#              'Round Lake Park PD': [65149296],
#              'Harvard Police Department': [65149564],
#              'Illinois Central College Police Department': [65151145],
#              'Milledgeville Police Department': [65151632],
#              'Chicago Ridge Police Department': [65151698],
#              'Paxton Police Department': [65151965],
#              'Leland Grove Police Department': [65152247],
#              'Richmond Police Department': [65152609],
#              'Grayslake Police Department': [65152765],
#              'Peotone Police Department': [65152838],
#              'Lomax Police Department': [65153699],
#              'Lombard Police Department': [65154859],
#              'Woodridge Police Department': [65156526],
#              'Wilmington Police Department': [65156722],
#              'Farmer City Police Department': [65156882],
#              'Lincoln Police Department': [65156889],
#              'Hazel Crest Police Department': [65157821],
#              'Bloomingdale Police Department': [65158007],
#              'Wheeling Police Department': [65158298],
#              'South Holland Police Department': [65159591],
#              'Glendale Heights Police Department': [65160066],
#              'John A Logan College Police Department': [65160072],
#              'Aledo Police Department': [65160885],
#              "Stephenson County Sheriff's Office": [65161196],
#              'Georgetown Police Department': [65161303]})

# %%
dixmoo_ids = [65002681,
              65005628,
              65012197,
              65012197,
              65012198,
              65012645,
              65033927,
              65036239,
              65038177,
              65040126,
              65045290,
              65046359,
              65046644,
              65064009,
              65066795,
              65082037,
              65084128,
              65084128,
              65084558,
              65087282,
              65090921,
              65098037,
              65098384,
              65112930,
              65114578,
              65125986,
              65144416,
              65144416,
              65148595,
              65152011]

# %%
dixmoor_officers = illinois_sorted.loc[illinois_sorted['person_nbr'].isin(dixmoo_ids)].copy()

# %%
dixmoor_officers.to_excel('illinois/dixmoor_officers.xlsx', index=False)

# %%
riverdale_ids = [65044192, 65107502, 65138146]

# %%
riverdale_officers = illinois_sorted.loc[illinois_sorted['person_nbr'].isin(riverdale_ids)].copy()

# %%
riverdale_officers.to_excel('illinois/riverdale_officers.xlsx')

# %%
dolton_ids = [65061174,
              65069637,
              65080137,
              65087282,
              65088471,
              65097133,
              65138146]

dolton_officers = illinois_sorted.loc[illinois_sorted['person_nbr'].isin(dolton_ids)].copy()
